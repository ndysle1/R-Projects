# %% [markdown]
# # Data Preparation

# %% [markdown]
# ### Settings/Functions
# Read in settings and functions.

# %%
libraries <-c('here','missForest','stringr','imputeMissings','regclass'
             ,'purrr','DescTools')
suppressWarnings(lapply(libraries, require, character.only = TRUE))
suppressWarnings(source(here::here('Stock Estimation', 'settings.R')))
# Out:
# [[1]]
# [1] TRUE
#
# [[2]]
# [1] TRUE
#
# [[3]]
# [1] TRUE
#
# [[4]]
# [1] TRUE
#
# [[5]]
# [1] TRUE
#
# [[6]]
# [1] TRUE
#
# [[7]]
# [1] TRUE

# %% [markdown]
# ### Data
# Read in the final data set from the data preparation notebook.

# %%
data <- fread(paste0(dir$final_data,'combined_financial.csv'))

# %% [markdown]
# ## More Cleaning

# %% [markdown]
# ### Duplicates

# %%
#Checking for duplicate column sums
dups <- data[ , which(duplicated(t(data)))]
dups <- names(dups)
dups
# Out:
#  [1] "nIperEBT"                  "eBTperEBIT"
#  [3] "eBITperRevenue"            "cashFlowCoverageRatios"
#  [5] "Debt to Equity"            "Debt to Assets"
#  [7] "ROIC"                      "Return on Tangible Assets"
#  [9] "Payables Turnover"         "Inventory Turnover"

# %%
#Removing any duplicate column sums after verifying them
data <- data %>% dplyr::select(-c(dups))
dim(data)
# Out:
# [1] 22073   209

# %%
#Looking for missing values & evaluating list of variable names
na <- apply(is.na(data),2,sum)
max(na)
# NOTE: The following code has been commmented out due to the length of its output.
#print(na)
head(sort(na, decreasing = TRUE), n=25)
# Out:
# [1] 10744
#                    shortTermCoverageRatios
#                                      10744
# 10Y Shareholders Equity Growth (per Share)
#                                       9680
#             10Y Revenue Growth (per Share)
#                                       9532
#          10Y Net Income Growth (per Share)
#                                       9532
#        10Y Operating CF Growth (per Share)
#                                       9478
#  10Y Dividend per Share Growth (per Share)
#                                       9177
#                 priceEarningsToGrowthRatio
#                                       9079
#                        dividendPayoutRatio
#                                       9079
#                                   niperEBT
#                                       8595
#                           effectiveTaxRate
#                                       8595
#                                 ebtperEBIT
#                                       8007
#                         Net Debt to EBITDA
#                                       7715
#                         priceCashFlowRatio
#                                       7064
#                    enterpriseValueMultiple
#                                       6944
#                                   Net Debt
#                                       6859
#                               Other Assets
#                                       6756
#  5Y Shareholders Equity Growth (per Share)
#                                       6610
#         freeCashFlowOperatingCashFlowRatio
#                                       6588
#                             returnOnAssets
#                                       6535
#                              Current ratio
#                                       6516
#                            Working Capital
#                                       6510
#                    returnOnCapitalEmployed
#                                       6509
#              5Y Revenue Growth (per Share)
#                                       6401
#           5Y Net Income Growth (per Share)
#                                       6401
#         5Y Operating CF Growth (per Share)
#                                       6364

# %%
#Merging and dropping duplicated variable names
#NOTE: Portions of the following code has been commmented out due to the length of its output.
#view(data[, c("Payout Ratio", "payoutRatio")])
data <- Name_Changer(dat=data,x='Payout Ratio',y='payoutRatio')

#view(data[, c('interestCoverage', 'Interest Coverage')])
data <- Name_Changer(dat=data,x='Interest Coverage',y='interestCoverage')

#view(data[, c('netProfitMargin', 'Net Profit Margin')])
data <- Name_Changer(dat=data,x='Net Profit Margin',y='netProfitMargin')

#view(data[, c('PE ratio', 'priceEarningsRatio')])
data <- Name_Changer(dat=data,x='PE ratio',y='priceEarningsRatio')

#view(data[, c('priceToFreeCashFlowsRatio', 'PFCF ratio')])
data <- Name_Changer(dat=data,x='PFCF ratio',y='priceToFreeCashFlowsRatio')

#view(data[, c('priceToOperatingCashFlowsRatio', 'POCF ratio')])
data <- Name_Changer(dat=data,x='POCF ratio',y='priceToOperatingCashFlowsRatio')

#view(data[, c('priceToSalesRatio', 'Price to Sales Ratio')])
data <- Name_Changer(dat=data,x='Price to Sales Ratio',y='priceToSalesRatio')

#view(data[, c('Days Payables Outstanding', 'daysOfPayablesOutstanding')])
data <- Name_Changer(dat=data,x='Days Payables Outstanding',y='daysOfPayablesOutstanding')

#view(data[, c('Free Cash Flow per Share', 'freeCashFlowPerShare')])
data <- Name_Changer(dat=data,x='Free Cash Flow per Share',y='freeCashFlowPerShare')

#view(data[, c('ROE', 'returnOnEquity')])
data <- Name_Changer(dat=data,x='ROE',y='returnOnEquity')

#view(data[, c('priceToBookRatio', 'PTB ratio')])
data <- Name_Changer(dat=data,x='PTB ratio',y='priceToBookRatio')

#view(data[, c('priceBookValueRatio', 'PB ratio')])
data <- Name_Changer(dat=data,x='PB ratio',y='priceBookValueRatio')

#view(data[, c('operatingCashFlowPerShare', 'Operating Cash Flow per Share')])
data <- Name_Changer(dat=data,x='Operating Cash Flow per Share',y='operatingCashFlowPerShare')

#view(data[, c('Cash per Share', 'cashPerShare')])
data <- Name_Changer(dat=data,x='Cash per Share',y='cashPerShare')

dim(data)
# Out:
# [1] 22073   195

# %% [markdown]
# ### Variable Names

# %%
#Checking variable names
names(data)
data <- setDT(data)
# Out:
#   [1] "Stock"
#   [2] "nextYR_PRICE_VAR"
#   [3] "Class"
#   [4] "Year"
#   [5] "Sector"
#   [6] "Revenue"
#   [7] "Revenue Growth"
#   [8] "Cost of Revenue"
#   [9] "Gross Profit"
#  [10] "R&D Expenses"
#  [11] "SG&A Expense"
#  [12] "Operating Expenses"
#  [13] "Operating Income"
#  [14] "Interest Expense"
#  [15] "Earnings before Tax"
#  [16] "Income Tax Expense"
#  [17] "Net Income - Non-Controlling int"
#  [18] "Net Income"
#  [19] "Net Income Com"
#  [20] "EPS"
#  [21] "EPS Diluted"
#  [22] "Weighted Average Shs Out"
#  [23] "Weighted Average Shs Out (Dil)"
#  [24] "Gross Margin"
#  [25] "EBITDA Margin"
#  [26] "EBIT Margin"
#  [27] "Profit Margin"
#  [28] "Free Cash Flow margin"
#  [29] "EBITDA"
#  [30] "EBIT"
#  [31] "Consolidated Income"
#  [32] "Earnings Before Tax Margin"
#  [33] "Cash and cash equivalents"
#  [34] "Short-term investments"
#  [35] "Cash and short-term investments"
#  [36] "Receivables"
#  [37] "Inventories"
#  [38] "Total current assets"
#  [39] "Property, Plant & Equipment Net"
#  [40] "Goodwill and Intangible Assets"
#  [41] "Long-term investments"
#  [42] "Tax assets"
#  [43] "Total non-current assets"
#  [44] "Total assets"
#  [45] "Payables"
#  [46] "Short-term debt"
#  [47] "Total current liabilities"
#  [48] "Long-term debt"
#  [49] "Total debt"
#  [50] "Deferred revenue"
#  [51] "Tax Liabilities"
#  [52] "Deposit Liabilities"
#  [53] "Total non-current liabilities"
#  [54] "Total liabilities"
#  [55] "Other comprehensive income"
#  [56] "Retained earnings (deficit)"
#  [57] "Total shareholders equity"
#  [58] "Investments"
#  [59] "Net Debt"
#  [60] "Other Assets"
#  [61] "Other Liabilities"
#  [62] "Depreciation & Amortization"
#  [63] "Stock-based compensation"
#  [64] "Operating Cash Flow"
#  [65] "Capital Expenditure"
#  [66] "Acquisitions and disposals"
#  [67] "Investment purchases and sales"
#  [68] "Investing Cash flow"
#  [69] "Issuance (repayment) of debt"
#  [70] "Issuance (buybacks) of shares"
#  [71] "Dividend payments"
#  [72] "Financing Cash Flow"
#  [73] "Effect of forex changes on cash"
#  [74] "Net cash flow / Change in cash"
#  [75] "Free Cash Flow"
#  [76] "Net Cash/Marketcap"
#  [77] "priceCashFlowRatio"
#  [78] "priceEarningsToGrowthRatio"
#  [79] "priceSalesRatio"
#  [80] "dividendYield"
#  [81] "enterpriseValueMultiple"
#  [82] "priceFairValue"
#  [83] "ebitperRevenue"
#  [84] "ebtperEBIT"
#  [85] "niperEBT"
#  [86] "grossProfitMargin"
#  [87] "pretaxProfitMargin"
#  [88] "effectiveTaxRate"
#  [89] "returnOnAssets"
#  [90] "returnOnCapitalEmployed"
#  [91] "payablesTurnover"
#  [92] "inventoryTurnover"
#  [93] "fixedAssetTurnover"
#  [94] "assetTurnover"
#  [95] "currentRatio"
#  [96] "quickRatio"
#  [97] "cashRatio"
#  [98] "daysOfSalesOutstanding"
#  [99] "daysOfInventoryOutstanding"
# [100] "debtRatio"
# [101] "debtEquityRatio"
# [102] "longtermDebtToCapitalization"
# [103] "totalDebtToCapitalization"
# [104] "cashFlowToDebtRatio"
# [105] "companyEquityMultiplier"
# [106] "operatingCashFlowSalesRatio"
# [107] "freeCashFlowOperatingCashFlowRatio"
# [108] "shortTermCoverageRatios"
# [109] "capitalExpenditureCoverageRatios"
# [110] "dividendpaidAndCapexCoverageRatios"
# [111] "dividendPayoutRatio"
# [112] "Revenue per Share"
# [113] "Net Income per Share"
# [114] "Book Value per Share"
# [115] "Tangible Book Value per Share"
# [116] "Shareholders Equity per Share"
# [117] "Interest Debt per Share"
# [118] "Market Cap"
# [119] "Enterprise Value"
# [120] "EV to Sales"
# [121] "Enterprise Value over EBITDA"
# [122] "EV to Operating cash flow"
# [123] "EV to Free cash flow"
# [124] "Earnings Yield"
# [125] "Free Cash Flow Yield"
# [126] "Net Debt to EBITDA"
# [127] "Current ratio"
# [128] "Income Quality"
# [129] "SG&A to Revenue"
# [130] "R&D to Revenue"
# [131] "Intangibles to Total Assets"
# [132] "Capex to Operating Cash Flow"
# [133] "Capex to Revenue"
# [134] "Capex to Depreciation"
# [135] "Stock-based compensation to Revenue"
# [136] "Graham Number"
# [137] "Graham Net-Net"
# [138] "Working Capital"
# [139] "Tangible Asset Value"
# [140] "Net Current Asset Value"
# [141] "Invested Capital"
# [142] "Average Receivables"
# [143] "Average Payables"
# [144] "Average Inventory"
# [145] "Days Sales Outstanding"
# [146] "Days of Inventory on Hand"
# [147] "Receivables Turnover"
# [148] "Capex per Share"
# [149] "Gross Profit Growth"
# [150] "EBIT Growth"
# [151] "Operating Income Growth"
# [152] "Net Income Growth"
# [153] "EPS Growth"
# [154] "EPS Diluted Growth"
# [155] "Weighted Average Shares Growth"
# [156] "Weighted Average Shares Diluted Growth"
# [157] "Dividends per Share Growth"
# [158] "Operating Cash Flow growth"
# [159] "Free Cash Flow growth"
# [160] "10Y Revenue Growth (per Share)"
# [161] "5Y Revenue Growth (per Share)"
# [162] "3Y Revenue Growth (per Share)"
# [163] "10Y Operating CF Growth (per Share)"
# [164] "5Y Operating CF Growth (per Share)"
# [165] "3Y Operating CF Growth (per Share)"
# [166] "10Y Net Income Growth (per Share)"
# [167] "5Y Net Income Growth (per Share)"
# [168] "3Y Net Income Growth (per Share)"
# [169] "10Y Shareholders Equity Growth (per Share)"
# [170] "5Y Shareholders Equity Growth (per Share)"
# [171] "3Y Shareholders Equity Growth (per Share)"
# [172] "10Y Dividend per Share Growth (per Share)"
# [173] "5Y Dividend per Share Growth (per Share)"
# [174] "3Y Dividend per Share Growth (per Share)"
# [175] "Receivables growth"
# [176] "Inventory Growth"
# [177] "Asset Growth"
# [178] "Book Value per Share Growth"
# [179] "Debt Growth"
# [180] "R&D Expense Growth"
# [181] "SG&A Expenses Growth"
# [182] "Payout Ratio"
# [183] "Interest Coverage"
# [184] "Net Profit Margin"
# [185] "PE ratio"
# [186] "PFCF ratio"
# [187] "POCF ratio"
# [188] "Price to Sales Ratio"
# [189] "Days Payables Outstanding"
# [190] "Free Cash Flow per Share"
# [191] "ROE"
# [192] "PTB ratio"
# [193] "PB ratio"
# [194] "Operating Cash Flow per Share"
# [195] "Cash per Share"

# %%
#Changing all names to lower case and replacing spaces with "_"
#Amending various features to make more compatible models
names(data) <- str_trim(names(data), side = "both")
names(data) <- str_to_lower(names(data), locale = "en")
names(data) <- str_replace_all(names(data), " ", "_")
names(data) <- str_replace_all(names(data), "-", "")
names(data) <- str_replace_all(names(data), "&", ".")
names(data) <- str_replace_all(names(data), "\\(", "")
names(data) <- str_replace_all(names(data), "\\)", "")
names(data) <- str_replace_all(names(data), "3y", "three_yr")
names(data) <- str_replace_all(names(data), "5y", "five_yr")
names(data) <- str_replace_all(names(data), "10y", "ten_yr")
names(data) <- str_replace_all(names(data), "\\\\", "")
names(data) <- str_replace_all(names(data), "////", "_")
names(data) <- str_replace_all(names(data), ",", "")
names(data) <- str_replace_all(names(data), "_._", "_")
names(data) <- str_replace_all(names(data), "/", "_")
setnames(data, 'eps', 'earnings_per_share')
names(data)
# Out:
#   [1] "stock"
#   [2] "nextyr_price_var"
#   [3] "class"
#   [4] "year"
#   [5] "sector"
#   [6] "revenue"
#   [7] "revenue_growth"
#   [8] "cost_of_revenue"
#   [9] "gross_profit"
#  [10] "r.d_expenses"
#  [11] "sg.a_expense"
#  [12] "operating_expenses"
#  [13] "operating_income"
#  [14] "interest_expense"
#  [15] "earnings_before_tax"
#  [16] "income_tax_expense"
#  [17] "net_income__noncontrolling_int"
#  [18] "net_income"
#  [19] "net_income_com"
#  [20] "earnings_per_share"
#  [21] "eps_diluted"
#  [22] "weighted_average_shs_out"
#  [23] "weighted_average_shs_out_dil"
#  [24] "gross_margin"
#  [25] "ebitda_margin"
#  [26] "ebit_margin"
#  [27] "profit_margin"
#  [28] "free_cash_flow_margin"
#  [29] "ebitda"
#  [30] "ebit"
#  [31] "consolidated_income"
#  [32] "earnings_before_tax_margin"
#  [33] "cash_and_cash_equivalents"
#  [34] "shortterm_investments"
#  [35] "cash_and_shortterm_investments"
#  [36] "receivables"
#  [37] "inventories"
#  [38] "total_current_assets"
#  [39] "property_plant_equipment_net"
#  [40] "goodwill_and_intangible_assets"
#  [41] "longterm_investments"
#  [42] "tax_assets"
#  [43] "total_noncurrent_assets"
#  [44] "total_assets"
#  [45] "payables"
#  [46] "shortterm_debt"
#  [47] "total_current_liabilities"
#  [48] "longterm_debt"
#  [49] "total_debt"
#  [50] "deferred_revenue"
#  [51] "tax_liabilities"
#  [52] "deposit_liabilities"
#  [53] "total_noncurrent_liabilities"
#  [54] "total_liabilities"
#  [55] "other_comprehensive_income"
#  [56] "retained_earnings_deficit"
#  [57] "total_shareholders_equity"
#  [58] "investments"
#  [59] "net_debt"
#  [60] "other_assets"
#  [61] "other_liabilities"
#  [62] "depreciation_amortization"
#  [63] "stockbased_compensation"
#  [64] "operating_cash_flow"
#  [65] "capital_expenditure"
#  [66] "acquisitions_and_disposals"
#  [67] "investment_purchases_and_sales"
#  [68] "investing_cash_flow"
#  [69] "issuance_repayment_of_debt"
#  [70] "issuance_buybacks_of_shares"
#  [71] "dividend_payments"
#  [72] "financing_cash_flow"
#  [73] "effect_of_forex_changes_on_cash"
#  [74] "net_cash_flow_change_in_cash"
#  [75] "free_cash_flow"
#  [76] "net_cash_marketcap"
#  [77] "pricecashflowratio"
#  [78] "priceearningstogrowthratio"
#  [79] "pricesalesratio"
#  [80] "dividendyield"
#  [81] "enterprisevaluemultiple"
#  [82] "pricefairvalue"
#  [83] "ebitperrevenue"
#  [84] "ebtperebit"
#  [85] "niperebt"
#  [86] "grossprofitmargin"
#  [87] "pretaxprofitmargin"
#  [88] "effectivetaxrate"
#  [89] "returnonassets"
#  [90] "returnoncapitalemployed"
#  [91] "payablesturnover"
#  [92] "inventoryturnover"
#  [93] "fixedassetturnover"
#  [94] "assetturnover"
#  [95] "currentratio"
#  [96] "quickratio"
#  [97] "cashratio"
#  [98] "daysofsalesoutstanding"
#  [99] "daysofinventoryoutstanding"
# [100] "debtratio"
# [101] "debtequityratio"
# [102] "longtermdebttocapitalization"
# [103] "totaldebttocapitalization"
# [104] "cashflowtodebtratio"
# [105] "companyequitymultiplier"
# [106] "operatingcashflowsalesratio"
# [107] "freecashflowoperatingcashflowratio"
# [108] "shorttermcoverageratios"
# [109] "capitalexpenditurecoverageratios"
# [110] "dividendpaidandcapexcoverageratios"
# [111] "dividendpayoutratio"
# [112] "revenue_per_share"
# [113] "net_income_per_share"
# [114] "book_value_per_share"
# [115] "tangible_book_value_per_share"
# [116] "shareholders_equity_per_share"
# [117] "interest_debt_per_share"
# [118] "market_cap"
# [119] "enterprise_value"
# [120] "ev_to_sales"
# [121] "enterprise_value_over_ebitda"
# [122] "ev_to_operating_cash_flow"
# [123] "ev_to_free_cash_flow"
# [124] "earnings_yield"
# [125] "free_cash_flow_yield"
# [126] "net_debt_to_ebitda"
# [127] "current_ratio"
# [128] "income_quality"
# [129] "sg.a_to_revenue"
# [130] "r.d_to_revenue"
# [131] "intangibles_to_total_assets"
# [132] "capex_to_operating_cash_flow"
# [133] "capex_to_revenue"
# [134] "capex_to_depreciation"
# [135] "stockbased_compensation_to_revenue"
# [136] "graham_number"
# [137] "graham_netnet"
# [138] "working_capital"
# [139] "tangible_asset_value"
# [140] "net_current_asset_value"
# [141] "invested_capital"
# [142] "average_receivables"
# [143] "average_payables"
# [144] "average_inventory"
# [145] "days_sales_outstanding"
# [146] "days_of_inventory_on_hand"
# [147] "receivables_turnover"
# [148] "capex_per_share"
# [149] "gross_profit_growth"
# [150] "ebit_growth"
# [151] "operating_income_growth"
# [152] "net_income_growth"
# [153] "eps_growth"
# [154] "eps_diluted_growth"
# [155] "weighted_average_shares_growth"
# [156] "weighted_average_shares_diluted_growth"
# [157] "dividends_per_share_growth"
# [158] "operating_cash_flow_growth"
# [159] "free_cash_flow_growth"
# [160] "ten_yr_revenue_growth_per_share"
# [161] "five_yr_revenue_growth_per_share"
# [162] "three_yr_revenue_growth_per_share"
# [163] "ten_yr_operating_cf_growth_per_share"
# [164] "five_yr_operating_cf_growth_per_share"
# [165] "three_yr_operating_cf_growth_per_share"
# [166] "ten_yr_net_income_growth_per_share"
# [167] "five_yr_net_income_growth_per_share"
# [168] "three_yr_net_income_growth_per_share"
# [169] "ten_yr_shareholders_equity_growth_per_share"
# [170] "five_yr_shareholders_equity_growth_per_share"
# [171] "three_yr_shareholders_equity_growth_per_share"
# [172] "ten_yr_dividend_per_share_growth_per_share"
# [173] "five_yr_dividend_per_share_growth_per_share"
# [174] "three_yr_dividend_per_share_growth_per_share"
# [175] "receivables_growth"
# [176] "inventory_growth"
# [177] "asset_growth"
# [178] "book_value_per_share_growth"
# [179] "debt_growth"
# [180] "r.d_expense_growth"
# [181] "sg.a_expenses_growth"
# [182] "payout_ratio"
# [183] "interest_coverage"
# [184] "net_profit_margin"
# [185] "pe_ratio"
# [186] "pfcf_ratio"
# [187] "pocf_ratio"
# [188] "price_to_sales_ratio"
# [189] "days_payables_outstanding"
# [190] "free_cash_flow_per_share"
# [191] "roe"
# [192] "ptb_ratio"
# [193] "pb_ratio"
# [194] "operating_cash_flow_per_share"
# [195] "cash_per_share"

# %% [markdown]
# ### Categorical Encoding

# %%
#Categorical Encoding
data[, sector := as.factor(sector)]
data[, sector_num := as.numeric(sector)]

#Reordering data to put "sector" with "sector_num"
data <- data %>%
  dplyr::select('stock','nextyr_price_var','class','year','sector','sector_num', everything()) %>%
  setDT()

# %% [markdown]
# ### Missing Data

# %%
na <- apply(is.na(data),2,sum)
#print(na)
max(na)
#sort(na, decreasing = TRUE)
head(sort(na, decreasing = TRUE), n=25)
summary(na)
# Out:
# [1] 10744
#                      shorttermcoverageratios
#                                        10744
#  ten_yr_shareholders_equity_growth_per_share
#                                         9680
#              ten_yr_revenue_growth_per_share
#                                         9532
#           ten_yr_net_income_growth_per_share
#                                         9532
#         ten_yr_operating_cf_growth_per_share
#                                         9478
#   ten_yr_dividend_per_share_growth_per_share
#                                         9177
#                   priceearningstogrowthratio
#                                         9079
#                          dividendpayoutratio
#                                         9079
#                                     niperebt
#                                         8595
#                             effectivetaxrate
#                                         8595
#                                   ebtperebit
#                                         8007
#                           net_debt_to_ebitda
#                                         7715
#                           pricecashflowratio
#                                         7064
#                      enterprisevaluemultiple
#                                         6944
#                                     net_debt
#                                         6859
#                                 other_assets
#                                         6756
# five_yr_shareholders_equity_growth_per_share
#                                         6610
#           freecashflowoperatingcashflowratio
#                                         6588
#                               returnonassets
#                                         6535
#                                current_ratio
#                                         6516
#                              working_capital
#                                         6510
#                      returnoncapitalemployed
#                                         6509
#             five_yr_revenue_growth_per_share
#                                         6401
#          five_yr_net_income_growth_per_share
#                                         6401
#        five_yr_operating_cf_growth_per_share
#                                         6364
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       0    1822    2342    3087    3307   10744

# %%
#Checking how many rows are complete
sum(complete.cases(data))

#Checking for NA across rows
data$na <- rowSums(is.na(data))
max(data$na)
head(sort(data$na, decreasing = TRUE),n = 20)
summary(data$na)
# Out:
# [1] 3397
# [1] 190
#  [1] 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190 190
# [20] 190
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    2.00   10.00   27.41   23.00  190.00

# %%
#Found that 50 was a good cut off for dropping rows
drop <- data %>% 
  filter(na >= 50)
dim(drop)

data <- data %>%
  filter(na <= 50)

data <- dplyr::select(data, -c(na))

#Re-checking the NAs across columns
na <- apply(is.na(data),2,sum)
max(na)
# NOTE: The following code has been commmented out due to the length of its output.
#print(na)
#sort(na, decreasing = TRUE)
head(sort(na, decreasing = TRUE), n=25)
# Out:
# [1] 2503  197
# [1] 8374
#                      shorttermcoverageratios
#                                         8374
#  ten_yr_shareholders_equity_growth_per_share
#                                         7200
#              ten_yr_revenue_growth_per_share
#                                         7046
#           ten_yr_net_income_growth_per_share
#                                         7046
#         ten_yr_operating_cf_growth_per_share
#                                         6999
#   ten_yr_dividend_per_share_growth_per_share
#                                         6699
#                   priceearningstogrowthratio
#                                         6628
#                          dividendpayoutratio
#                                         6628
#                                     niperebt
#                                         6459
#                             effectivetaxrate
#                                         6459
#                                   ebtperebit
#                                         5652
#                           net_debt_to_ebitda
#                                         5263
#                                     net_debt
#                                         5246
#                                 other_assets
#                                         5157
#                           pricecashflowratio
#                                         4615
#           freecashflowoperatingcashflowratio
#                                         4564
#                      enterprisevaluemultiple
#                                         4556
#                          cashflowtodebtratio
#                                         4211
# five_yr_shareholders_equity_growth_per_share
#                                         4142
#                                current_ratio
#                                         4141
#                               returnonassets
#                                         4140
#                 total_noncurrent_liabilities
#                                         4139
#                      returnoncapitalemployed
#                                         4136
#                              working_capital
#                                         4136
#                      total_noncurrent_assets
#                                         4129

# %%
#Keeping only columns with less than ~15 percent missing
perc <- apply(data,2,Perc_Missing)
max(perc)
# NOTE: The following code has been commmented out due to the length of its output.
#print(perc)
#sort(perc, decreasing = TRUE)
head(sort(perc, decreasing = TRUE), n=25)

#Choosing to only keep variables with less than 15% missing data
data <- data[, which(apply(data,2,Perc_Missing) < 15.0)]
# Out:
# [1] 42.76158
#                      shorttermcoverageratios
#                                     42.76158
#  ten_yr_shareholders_equity_growth_per_share
#                                     36.76658
#              ten_yr_revenue_growth_per_share
#                                     35.98019
#           ten_yr_net_income_growth_per_share
#                                     35.98019
#         ten_yr_operating_cf_growth_per_share
#                                     35.74018
#   ten_yr_dividend_per_share_growth_per_share
#                                     34.20824
#                   priceearningstogrowthratio
#                                     33.84568
#                          dividendpayoutratio
#                                     33.84568
#                                     niperebt
#                                     32.98269
#                             effectivetaxrate
#                                     32.98269
#                                   ebtperebit
#                                     28.86177
#                           net_debt_to_ebitda
#                                     26.87535
#                                     net_debt
#                                     26.78854
#                                 other_assets
#                                     26.33407
#                           pricecashflowratio
#                                     23.56636
#           freecashflowoperatingcashflowratio
#                                     23.30593
#                      enterprisevaluemultiple
#                                     23.26508
#                          cashflowtodebtratio
#                                     21.50334
# five_yr_shareholders_equity_growth_per_share
#                                     21.15100
#                                current_ratio
#                                     21.14589
#                               returnonassets
#                                     21.14079
#                 total_noncurrent_liabilities
#                                     21.13568
#                      returnoncapitalemployed
#                                     21.12036
#                              working_capital
#                                     21.12036
#                      total_noncurrent_assets
#                                     21.08461

# %% [markdown]
# ### Multicollinearity/Linear Dependence/Winsorization

# %%
#Splitting datasets
data <- setDT(data)
data2 <- select(data, c('stock','nextyr_price_var','sector'))
data <- select(data, -c('stock','nextyr_price_var','sector'))

#Converting class to a factor
data <- data[, class := as.factor(class)]

#Run regression to identify linearly dependent variables
set.seed(123)
glm <- suppressWarnings(glm(class~., family = binomial
           , data = data))

# %%
#Find the linearly dependent variables
vars <- attributes(alias(glm)$Complete)$dimnames[[1]]
vars

# Remove the linearly dependent variables
remove <- match(vars,names(data))
remove

dim(data)
data <- select(data, -c(remove))
dim(data)
# Out:
# [1] "days_sales_outstanding"    "days_of_inventory_on_hand"
# [1] 124 125
# [1] 19583   164
# [1] 19583   162

# %%
#Re-run regression without linearly dependent variables
set.seed(123)
glm <- suppressWarnings(glm(class~., family = binomial
           , data = data))

# %%
#NOTE: This section of the code will take some time to run.
#The function VIF_Check runs a regression and removes the max
#VIF, repeating this process until all VIFs are below threshold
#Removing variables with VIFs above 5
data <- VIF_Check(dat=data, threshold=5)
# Out:
# [1] 42501422
# [1] 42501422
# [1] 14857839
# [1] 7233613
# [1] 589255.9
# [1] 224275.1
# [1] 136088.1
# [1] 90188.32
# [1] 85687.64
# [1] 64580.32
# [1] 47223.74
# [1] 36937.24
# [1] 34305.54
# [1] 15651.42
# [1] 8154.741
# [1] 6957.033
# [1] 3236.491
# [1] 3432.8
# [1] 3006.367
# [1] 2107.776
# [1] 1695.465
# [1] 1459.61
# [1] 1059
# [1] 897.1616
# [1] 805.2764
# [1] 847.6565
# [1] 787.2204
# [1] 729.5147
# [1] 593.1282
# [1] 296.241
# [1] 368.0201
# [1] 235.8145
# [1] 234.6721
# [1] 207.8195
# [1] 206.0238
# [1] 175.2889
# [1] 164.1711
# [1] 119.1208
# [1] 112.1676
# [1] 86.7602
# [1] 75.9692
# [1] 98.85711
# [1] 65.27094
# [1] 44.12094
# [1] 41.82128
# [1] 38.25669
# [1] 38.15252
# [1] 1099.636
# [1] 34.42022
# [1] 25.95463
# [1] 25.16551
# [1] 24.20825
# [1] 21.9634
# [1] 21.5175
# [1] 20.7845
# [1] 17.37877
# [1] 15.94764
# [1] 11.32786
# [1] 9.723508
# [1] 9.203622
# [1] 8.782897
# [1] 8.662801
# [1] 7.623118
# [1] 7.273039
# [1] 6.057325
# [1] 6.021532
# [1] 5.181338
# [1] 5.031095
# [1] 4.370228
# [1] "All VIFs are below threshold of 5"

# %%
#Re-combine data
data <- cbind(data2,data) %>% setDT()
dim(data)
# Out:
# [1] 19583    98

# %%
#Re-run regression without linearly dependent variables
set.seed(123)
glm <- suppressWarnings(glm(class~., family = binomial(link = "logit")
                  , data = data[, -c('stock','nextyr_price_var','sector')], control = list(maxit = 100)))

# %%
#Split data for winsorization
data2 <- select(data, c('class','year','sector_num','stock'
                        ,'nextyr_price_var','sector'))
data <- select(data, -c('class','year','sector_num','stock'
                        ,'nextyr_price_var','sector'))

# %%
#Winsorize each column accordingly
data <- map_df(data, ~Winsorize(., probs=c(0.05,0.95),na.rm=TRUE))

#Recombine datasets
data <- cbind(data2,data) %>% setDT()
dim(data)
# Out:
# [1] 19583    98

# %%
#Re-run regression to see if error has been corrected
#No warning message occurs
set.seed(123)
glm <- glm(class~., family = binomial(link = "logit")
           , data = data[, -c('stock','nextyr_price_var','sector')], control = list(maxit = 100))
summary(glm)
# Out:
# Call:
# glm(formula = class ~ ., family = binomial(link = "logit"), data = data[,
#     -c("stock", "nextyr_price_var", "sector")], control = list(maxit = 100))
#
# Deviance Residuals:
#    Min      1Q  Median      3Q     Max
# -2.308  -1.190   0.764   1.030   2.088
#
# Coefficients:
#                                                 Estimate Std. Error z value
# (Intercept)                                   -1.370e+02  3.063e+01  -4.475
# year                                           6.777e-02  1.519e-02   4.461
# sector_num                                     6.455e-02  7.979e-03   8.090
# cost_of_revenue                                4.328e-12  1.801e-11   0.240
# r.d_expenses                                  -3.605e-10  4.957e-10  -0.727
# sg.a_expense                                  -3.005e-11  4.774e-11  -0.629
# interest_expense                              -2.202e-10  4.897e-10  -0.450
# income_tax_expense                            -3.651e-11  2.491e-10  -0.147
# net_income__noncontrolling_int                -5.664e-09  2.260e-09  -2.507
# net_income_com                                -2.132e-10  1.091e-10  -1.955
# weighted_average_shs_out_dil                   4.723e-11  2.759e-10   0.171
# ebitda_margin                                  3.492e-02  4.254e-02   0.821
# cash_and_cash_equivalents                      1.085e-10  6.662e-11   1.629
# shortterm_investments                          2.753e-10  1.605e-10   1.715
# receivables                                   -1.551e-10  7.316e-11  -2.120
# goodwill_and_intangible_assets                -3.793e-11  2.432e-11  -1.560
# longterm_investments                           5.870e-11  5.246e-11   1.119
# tax_assets                                    -4.607e-10  2.985e-10  -1.543
# payables                                       1.912e-10  8.794e-11   2.174
# shortterm_debt                                 1.424e-10  1.057e-10   1.348
# longterm_debt                                  1.165e-11  2.260e-11   0.515
# deferred_revenue                               9.647e-10  2.888e-10   3.340
# tax_liabilities                                1.113e-10  9.510e-11   1.170
# other_comprehensive_income                    -9.425e-11  1.907e-10  -0.494
# retained_earnings_deficit                     -2.908e-12  1.690e-11  -0.172
# other_liabilities                             -3.466e-12  2.413e-11  -0.144
# stockbased_compensation                        1.197e-09  1.273e-09   0.940
# capital_expenditure                            2.200e-10  1.442e-10   1.526
# acquisitions_and_disposals                    -2.157e-10  1.972e-10  -1.094
# investment_purchases_and_sales                 6.110e-10  2.078e-10   2.940
# issuance_repayment_of_debt                     2.241e-10  9.774e-11   2.293
# issuance_buybacks_of_shares                   -3.699e-10  1.811e-10  -2.043
# effect_of_forex_changes_on_cash               -4.176e-08  3.872e-09 -10.786
# net_cash_flow_change_in_cash                  -3.015e-10  1.747e-10  -1.726
# net_cash_marketcap                             2.230e-01  6.366e-02   3.502
# dividendyield                                  3.646e+00  1.198e+00   3.045
# grossprofitmargin                              7.508e-02  1.119e-01   0.671
# payablesturnover                               1.027e-02  6.384e-03   1.608
# inventoryturnover                             -9.934e-04  9.750e-04  -1.019
# fixedassetturnover                             1.031e-03  1.793e-03   0.575
# assetturnover                                 -6.937e-02  6.302e-02  -1.101
# currentratio                                   1.056e-02  2.279e-02   0.463
# quickratio                                     1.283e-02  2.922e-02   0.439
# cashratio                                     -3.859e-02  3.222e-02  -1.198
# daysofsalesoutstanding                        -6.369e-05  3.969e-04  -0.160
# daysofinventoryoutstanding                    -1.444e-03  6.642e-04  -2.173
# debtratio                                     -3.202e-01  2.653e-01  -1.207
# debtequityratio                               -3.770e-02  2.880e-02  -1.309
# longtermdebttocapitalization                   6.256e-01  1.902e-01   3.288
# capitalexpenditurecoverageratios              -9.024e-04  1.437e-03  -0.628
# revenue_per_share                             -1.657e-03  1.096e-03  -1.512
# ev_to_sales                                   -5.752e-03  7.321e-03  -0.786
# enterprise_value_over_ebitda                   3.030e-03  2.453e-03   1.235
# ev_to_free_cash_flow                           2.466e-05  9.922e-04   0.025
# earnings_yield                                 5.713e-01  1.857e-01   3.077
# income_quality                                 6.981e-03  1.298e-02   0.538
# intangibles_to_total_assets                    1.976e-01  1.420e-01   1.391
# capex_to_revenue                               1.448e-01  2.262e-01   0.640
# capex_to_depreciation                         -7.887e-02  2.668e-02  -2.956
# graham_number                                  3.367e-03  1.718e-03   1.960
# graham_netnet                                 -5.178e-02  2.429e-02  -2.132
# receivables_turnover                           4.097e-04  2.015e-03   0.203
# gross_profit_growth                           -1.665e-01  8.009e-02  -2.079
# ebit_growth                                   -2.195e-04  4.350e-02  -0.005
# operating_income_growth                       -5.542e-02  4.282e-02  -1.294
# net_income_growth                              6.305e-02  7.039e-02   0.896
# eps_growth                                    -8.251e-02  7.436e-02  -1.110
# weighted_average_shares_growth                -3.089e-01  3.298e-01  -0.937
# weighted_average_shares_diluted_growth         2.788e-01  2.860e-01   0.975
# dividends_per_share_growth                     3.614e-01  1.889e-01   1.913
# operating_cash_flow_growth                    -8.330e-03  3.356e-02  -0.248
# free_cash_flow_growth                          5.254e-02  2.088e-02   2.516
# three_yr_revenue_growth_per_share              2.121e-01  1.660e-01   1.277
# three_yr_operating_cf_growth_per_share         5.829e-02  1.331e-01   0.438
# three_yr_net_income_growth_per_share           3.179e-01  1.301e-01   2.444
# three_yr_shareholders_equity_growth_per_share  3.259e-01  1.723e-01   1.892
# three_yr_dividend_per_share_growth_per_share   2.472e-01  2.190e-01   1.129
# receivables_growth                            -6.284e-02  6.739e-02  -0.933
# inventory_growth                              -3.723e-01  1.286e-01  -2.895
# asset_growth                                  -1.105e-01  1.181e-01  -0.936
# book_value_per_share_growth                   -6.359e-02  7.842e-02  -0.811
# debt_growth                                   -2.739e-02  5.123e-02  -0.535
# r.d_expense_growth                            -3.963e-01  1.442e-01  -2.747
# sg.a_expenses_growth                          -6.188e-02  1.332e-01  -0.465
# payout_ratio                                  -1.064e-01  8.303e-02  -1.282
# interest_coverage                             -8.974e-04  1.046e-03  -0.858
# pe_ratio                                       9.731e-04  1.678e-03   0.580
# pfcf_ratio                                     1.541e-03  2.023e-03   0.762
# pocf_ratio                                     2.735e-04  1.820e-03   0.150
# days_payables_outstanding                     -9.995e-04  6.157e-04  -1.623
# free_cash_flow_per_share                       1.479e-02  1.315e-02   1.125
# roe                                            1.235e-01  8.012e-02   1.542
# ptb_ratio                                      7.473e-04  4.051e-03   0.184
# operating_cash_flow_per_share                  6.196e-03  1.190e-02   0.521
# cash_per_share                                -1.589e-02  4.748e-03  -3.346
#                                               Pr(>|z|)
# (Intercept)                                   7.64e-06 ***
# year                                          8.14e-06 ***
# sector_num                                    5.95e-16 ***
# cost_of_revenue                               0.810091
# r.d_expenses                                  0.467000
# sg.a_expense                                  0.529071
# interest_expense                              0.652904
# income_tax_expense                            0.883470
# net_income__noncontrolling_int                0.012193 *
# net_income_com                                0.050609 .
# weighted_average_shs_out_dil                  0.864080
# ebitda_margin                                 0.411766
# cash_and_cash_equivalents                     0.103360
# shortterm_investments                         0.086268 .
# receivables                                   0.034013 *
# goodwill_and_intangible_assets                0.118845
# longterm_investments                          0.263132
# tax_assets                                    0.122727
# payables                                      0.029700 *
# shortterm_debt                                0.177654
# longterm_debt                                 0.606246
# deferred_revenue                              0.000838 ***
# tax_liabilities                               0.242040
# other_comprehensive_income                    0.621145
# retained_earnings_deficit                     0.863339
# other_liabilities                             0.885764
# stockbased_compensation                       0.347136
# capital_expenditure                           0.127024
# acquisitions_and_disposals                    0.274152
# investment_purchases_and_sales                0.003279 **
# issuance_repayment_of_debt                    0.021869 *
# issuance_buybacks_of_shares                   0.041065 *
# effect_of_forex_changes_on_cash                < 2e-16 ***
# net_cash_flow_change_in_cash                  0.084389 .
# net_cash_marketcap                            0.000461 ***
# dividendyield                                 0.002328 **
# grossprofitmargin                             0.502232
# payablesturnover                              0.107796
# inventoryturnover                             0.308278
# fixedassetturnover                            0.565323
# assetturnover                                 0.271008
# currentratio                                  0.643170
# quickratio                                    0.660508
# cashratio                                     0.230986
# daysofsalesoutstanding                        0.872516
# daysofinventoryoutstanding                    0.029748 *
# debtratio                                     0.227560
# debtequityratio                               0.190475
# longtermdebttocapitalization                  0.001009 **
# capitalexpenditurecoverageratios              0.530017
# revenue_per_share                             0.130490
# ev_to_sales                                   0.432040
# enterprise_value_over_ebitda                  0.216707
# ev_to_free_cash_flow                          0.980172
# earnings_yield                                0.002094 **
# income_quality                                0.590646
# intangibles_to_total_assets                   0.164104
# capex_to_revenue                              0.522175
# capex_to_depreciation                         0.003117 **
# graham_number                                 0.049971 *
# graham_netnet                                 0.033029 *
# receivables_turnover                          0.838897
# gross_profit_growth                           0.037621 *
# ebit_growth                                   0.995973
# operating_income_growth                       0.195624
# net_income_growth                             0.370373
# eps_growth                                    0.267199
# weighted_average_shares_growth                0.348922
# weighted_average_shares_diluted_growth        0.329708
# dividends_per_share_growth                    0.055700 .
# operating_cash_flow_growth                    0.803941
# free_cash_flow_growth                         0.011864 *
# three_yr_revenue_growth_per_share             0.201491
# three_yr_operating_cf_growth_per_share        0.661437
# three_yr_net_income_growth_per_share          0.014544 *
# three_yr_shareholders_equity_growth_per_share 0.058536 .
# three_yr_dividend_per_share_growth_per_share  0.258948
# receivables_growth                            0.351060
# inventory_growth                              0.003789 **
# asset_growth                                  0.349492
# book_value_per_share_growth                   0.417395
# debt_growth                                   0.592869
# r.d_expense_growth                            0.006011 **
# sg.a_expenses_growth                          0.642221
# payout_ratio                                  0.199885
# interest_coverage                             0.391073
# pe_ratio                                      0.561989
# pfcf_ratio                                    0.446237
# pocf_ratio                                    0.880533
# days_payables_outstanding                     0.104533
# free_cash_flow_per_share                      0.260678
# roe                                           0.123185
# ptb_ratio                                     0.853666
# operating_cash_flow_per_share                 0.602670
# cash_per_share                                0.000820 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 16229  on 11854  degrees of freedom
# Residual deviance: 15286  on 11760  degrees of freedom
#   (7728 observations deleted due to missingness)
# AIC: 15476
#
# Number of Fisher Scoring iterations: 4

# %% [markdown]
# ### Imputing Missing Values

# %%
#Imputation will be implemented if necessary in the modeling notebook

# %% [markdown]
# ### Uniformity

# %%
#Implementing scaling in the modeling notebook

# %% [markdown]
# ### Additional Cleaning

# %%
#No additional cleaning was performed in this notebook

# %% [markdown]
# ## Save the Modeling Dataset

# %%
fwrite(data, paste0(dir$final_data,'clean_financial.csv'))

# %% [markdown]
# ## Outcome

# %% [markdown]
# ##### The following changes were made to the data set:
#  - Duplicates: Duplicate columns were removed from the dataset. This was done by first using the duplicated function to identify identical columns. Then, I looked at the columns sums to identify additional duplicate variables. In the end, about 10 variables were duplicated.
#  - Variable Names: Variable names were cleaned up so that they were consistent. Spaces and dashes were removed, all letters were lower-cased, and underscores were added between most words.
#  - Categorical Encoding: A new variable "sector_num" was created as the numeric version of the categorical variable "sector" to aid in machine learning models.
#  - Missing Data: The missing data was cleaned in the following manner:
#       1. Any row with missing values greater than 50 was removed
#       2. Any column with missing values greater than 15% was removed
#       3. The remaining values will be imputed after relevant variables are identified.
#  - Outliers: The outliers in the data set were removed in the previous notebook using Cook's Distance. Only four rows were identified as extreme outliers and were thus removed from the data set.
#  - Multicollinearity: A significant portion of the variables in the dataset had high multicollinearity and a few were even found to be perfectly collinear. To solve this issue, all variables with a VIF greater than or equal to 5 were removed from the dataset. This resulted in approximately 70 variables being removed from the dataset.
#  -  Complete Separation: When running a basic regression, predicted probabilities that were effectively indistinguishable from 1 were occurring. To solve this issue, I first removed collinear variables. After this did not solve the issue, I winsorized the majority of the independent variables in the dataset and the problem was solved.
