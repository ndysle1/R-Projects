# %% [markdown]
# # Data Preparation

# %% [markdown]
# ### Settings/Functions
# Read in settings and functions.

# %%
libraries <-c('here','missForest','stringr','imputeMissings','regclass'
             ,'purrr','DescTools')
suppressWarnings(lapply(libraries, require, character.only = TRUE))
suppressWarnings(source(here::here('Stock Estimation', 'settings.R')))
# Out:
# [[1]]
# [1] TRUE
#
# [[2]]
# [1] TRUE
#
# [[3]]
# [1] TRUE
#
# [[4]]
# [1] TRUE
#
# [[5]]
# [1] TRUE
#
# [[6]]
# [1] TRUE
#
# [[7]]
# [1] TRUE

# %% [markdown]
# ### Data
# Read in the final data set from the data preparation notebook.

# %%
data <- fread(paste0(dir$final_data,'combined_financial.csv'))

# %% [markdown]
# ## More Cleaning

# %% [markdown]
# ### Duplicates
# Deal with any duplicate rows/columns (or, contrarily, any empty rows/columns), if applicable.

# %%
#Checking for duplicate column sums
dups <- data[ , which(duplicated(t(data)))]
dups <- names(dups)
dups
# Out:
#  [1] "nIperEBT"                  "eBTperEBIT"
#  [3] "eBITperRevenue"            "cashFlowCoverageRatios"
#  [5] "Debt to Equity"            "Debt to Assets"
#  [7] "ROIC"                      "Return on Tangible Assets"
#  [9] "Payables Turnover"         "Inventory Turnover"

# %%
#Removing any duplicate column sums after verifying them
data <- data %>% dplyr::select(-c(dups))
dim(data)
# Out:
# [1] 22073   213

# %%
#Looking for missing values & evaluating list of variable names
na <- apply(is.na(data),2,sum)
max(na)
# NOTE: The following code has been commmented out due to the length of its output.
#print(na)
head(sort(na, decreasing = TRUE), n=25)
# Out:
# [1] 10744
#                    shortTermCoverageRatios
#                                      10744
# 10Y Shareholders Equity Growth (per Share)
#                                       9680
#             10Y Revenue Growth (per Share)
#                                       9532
#          10Y Net Income Growth (per Share)
#                                       9532
#        10Y Operating CF Growth (per Share)
#                                       9478
#  10Y Dividend per Share Growth (per Share)
#                                       9177
#                 priceEarningsToGrowthRatio
#                                       9079
#                        dividendPayoutRatio
#                                       9079
#                                   niperEBT
#                                       8595
#                           effectiveTaxRate
#                                       8595
#                                 ebtperEBIT
#                                       8007
#                         Net Debt to EBITDA
#                                       7715
#                         priceCashFlowRatio
#                                       7064
#                    enterpriseValueMultiple
#                                       6944
#                                   Net Debt
#                                       6859
#                               Other Assets
#                                       6756
#  5Y Shareholders Equity Growth (per Share)
#                                       6610
#         freeCashFlowOperatingCashFlowRatio
#                                       6588
#                             returnOnAssets
#                                       6535
#                              Current ratio
#                                       6516
#                            Working Capital
#                                       6510
#                    returnOnCapitalEmployed
#                                       6509
#              5Y Revenue Growth (per Share)
#                                       6401
#           5Y Net Income Growth (per Share)
#                                       6401
#         5Y Operating CF Growth (per Share)
#                                       6364

# %%
#Merging and dropping duplicated variable names
#view(data[, c("Payout Ratio", "payoutRatio")])
data <- Name_Changer(dat=data,x='Payout Ratio',y='payoutRatio')

#view(data[, c('interestCoverage', 'Interest Coverage')])
data <- Name_Changer(dat=data,x='Interest Coverage',y='interestCoverage')

#view(data[, c('netProfitMargin', 'Net Profit Margin')])
data <- Name_Changer(dat=data,x='Net Profit Margin',y='netProfitMargin')

#view(data[, c('Dividend Yield', 'dividendYield')])
data <- Name_Changer(dat=data,x='Dividend Yield',y='dividendYield')

#view(data[, c('PE ratio', 'priceEarningsRatio')])
data <- Name_Changer(dat=data,x='PE ratio',y='priceEarningsRatio')

#view(data[, c('priceToFreeCashFlowsRatio', 'PFCF ratio')])
data <- Name_Changer(dat=data,x='PFCF ratio',y='priceToFreeCashFlowsRatio')

#view(data[, c('priceToOperatingCashFlowsRatio', 'POCF ratio')])
data <- Name_Changer(dat=data,x='POCF ratio',y='priceToOperatingCashFlowsRatio')

#view(data[, c('priceToSalesRatio', 'Price to Sales Ratio')])
data <- Name_Changer(dat=data,x='Price to Sales Ratio',y='priceToSalesRatio')

#view(data[, c('Days Payables Outstanding', 'daysOfPayablesOutstanding')])
data <- Name_Changer(dat=data,x='Days Payables Outstanding',y='daysOfPayablesOutstanding')

#view(data[, c('Free Cash Flow per Share', 'freeCashFlowPerShare')])
data <- Name_Changer(dat=data,x='Free Cash Flow per Share',y='freeCashFlowPerShare')

#view(data[, c('ROE', 'returnOnEquity')])
data <- Name_Changer(dat=data,x='ROE',y='returnOnEquity')

#view(data[, c('priceToBookRatio', 'PTB ratio')])
data <- Name_Changer(dat=data,x='PTB ratio',y='priceToBookRatio')

#view(data[, c('priceBookValueRatio', 'PB ratio')])
data <- Name_Changer(dat=data,x='PB ratio',y='priceBookValueRatio')

#view(data[, c('operatingCashFlowPerShare', 'Operating Cash Flow per Share')])
data <- Name_Changer(dat=data,x='Operating Cash Flow per Share',y='operatingCashFlowPerShare')

#view(data[, c('Cash per Share', 'cashPerShare')])
data <- Name_Changer(dat=data,x='Cash per Share',y='cashPerShare')

dim(data)
# Out:
# [1] 22073   198

# %% [markdown]
# ### Variable Names
# Depending on your data set, variables may have names with strange symbols, which can making loading, saving, and subsetting data difficult. If applicable, you should deal with this now.

# %%
#Checking variable names
names(data)
data <- setDT(data)
# Out:
#   [1] "Stock"
#   [2] "nextYR_PRICE_VAR"
#   [3] "Class"
#   [4] "Year"
#   [5] "Sector"
#   [6] "Revenue"
#   [7] "Revenue Growth"
#   [8] "Cost of Revenue"
#   [9] "Gross Profit"
#  [10] "R&D Expenses"
#  [11] "SG&A Expense"
#  [12] "Operating Expenses"
#  [13] "Operating Income"
#  [14] "Interest Expense"
#  [15] "Earnings before Tax"
#  [16] "Income Tax Expense"
#  [17] "Net Income - Non-Controlling int"
#  [18] "Net Income - Discontinued ops"
#  [19] "Net Income"
#  [20] "Preferred Dividends"
#  [21] "Net Income Com"
#  [22] "EPS"
#  [23] "EPS Diluted"
#  [24] "Weighted Average Shs Out"
#  [25] "Weighted Average Shs Out (Dil)"
#  [26] "Dividend per Share"
#  [27] "Gross Margin"
#  [28] "EBITDA Margin"
#  [29] "EBIT Margin"
#  [30] "Profit Margin"
#  [31] "Free Cash Flow margin"
#  [32] "EBITDA"
#  [33] "EBIT"
#  [34] "Consolidated Income"
#  [35] "Earnings Before Tax Margin"
#  [36] "Cash and cash equivalents"
#  [37] "Short-term investments"
#  [38] "Cash and short-term investments"
#  [39] "Receivables"
#  [40] "Inventories"
#  [41] "Total current assets"
#  [42] "Property, Plant & Equipment Net"
#  [43] "Goodwill and Intangible Assets"
#  [44] "Long-term investments"
#  [45] "Tax assets"
#  [46] "Total non-current assets"
#  [47] "Total assets"
#  [48] "Payables"
#  [49] "Short-term debt"
#  [50] "Total current liabilities"
#  [51] "Long-term debt"
#  [52] "Total debt"
#  [53] "Deferred revenue"
#  [54] "Tax Liabilities"
#  [55] "Deposit Liabilities"
#  [56] "Total non-current liabilities"
#  [57] "Total liabilities"
#  [58] "Other comprehensive income"
#  [59] "Retained earnings (deficit)"
#  [60] "Total shareholders equity"
#  [61] "Investments"
#  [62] "Net Debt"
#  [63] "Other Assets"
#  [64] "Other Liabilities"
#  [65] "Depreciation & Amortization"
#  [66] "Stock-based compensation"
#  [67] "Operating Cash Flow"
#  [68] "Capital Expenditure"
#  [69] "Acquisitions and disposals"
#  [70] "Investment purchases and sales"
#  [71] "Investing Cash flow"
#  [72] "Issuance (repayment) of debt"
#  [73] "Issuance (buybacks) of shares"
#  [74] "Dividend payments"
#  [75] "Financing Cash Flow"
#  [76] "Effect of forex changes on cash"
#  [77] "Net cash flow / Change in cash"
#  [78] "Free Cash Flow"
#  [79] "Net Cash/Marketcap"
#  [80] "priceCashFlowRatio"
#  [81] "priceEarningsToGrowthRatio"
#  [82] "priceSalesRatio"
#  [83] "enterpriseValueMultiple"
#  [84] "priceFairValue"
#  [85] "ebitperRevenue"
#  [86] "ebtperEBIT"
#  [87] "niperEBT"
#  [88] "grossProfitMargin"
#  [89] "pretaxProfitMargin"
#  [90] "effectiveTaxRate"
#  [91] "returnOnAssets"
#  [92] "returnOnCapitalEmployed"
#  [93] "payablesTurnover"
#  [94] "inventoryTurnover"
#  [95] "fixedAssetTurnover"
#  [96] "assetTurnover"
#  [97] "currentRatio"
#  [98] "quickRatio"
#  [99] "cashRatio"
# [100] "daysOfSalesOutstanding"
# [101] "daysOfInventoryOutstanding"
# [102] "debtRatio"
# [103] "debtEquityRatio"
# [104] "longtermDebtToCapitalization"
# [105] "totalDebtToCapitalization"
# [106] "cashFlowToDebtRatio"
# [107] "companyEquityMultiplier"
# [108] "operatingCashFlowSalesRatio"
# [109] "freeCashFlowOperatingCashFlowRatio"
# [110] "shortTermCoverageRatios"
# [111] "capitalExpenditureCoverageRatios"
# [112] "dividendpaidAndCapexCoverageRatios"
# [113] "dividendPayoutRatio"
# [114] "Revenue per Share"
# [115] "Net Income per Share"
# [116] "Book Value per Share"
# [117] "Tangible Book Value per Share"
# [118] "Shareholders Equity per Share"
# [119] "Interest Debt per Share"
# [120] "Market Cap"
# [121] "Enterprise Value"
# [122] "EV to Sales"
# [123] "Enterprise Value over EBITDA"
# [124] "EV to Operating cash flow"
# [125] "EV to Free cash flow"
# [126] "Earnings Yield"
# [127] "Free Cash Flow Yield"
# [128] "Net Debt to EBITDA"
# [129] "Current ratio"
# [130] "Income Quality"
# [131] "SG&A to Revenue"
# [132] "R&D to Revenue"
# [133] "Intangibles to Total Assets"
# [134] "Capex to Operating Cash Flow"
# [135] "Capex to Revenue"
# [136] "Capex to Depreciation"
# [137] "Stock-based compensation to Revenue"
# [138] "Graham Number"
# [139] "Graham Net-Net"
# [140] "Working Capital"
# [141] "Tangible Asset Value"
# [142] "Net Current Asset Value"
# [143] "Invested Capital"
# [144] "Average Receivables"
# [145] "Average Payables"
# [146] "Average Inventory"
# [147] "Days Sales Outstanding"
# [148] "Days of Inventory on Hand"
# [149] "Receivables Turnover"
# [150] "Capex per Share"
# [151] "Gross Profit Growth"
# [152] "EBIT Growth"
# [153] "Operating Income Growth"
# [154] "Net Income Growth"
# [155] "EPS Growth"
# [156] "EPS Diluted Growth"
# [157] "Weighted Average Shares Growth"
# [158] "Weighted Average Shares Diluted Growth"
# [159] "Dividends per Share Growth"
# [160] "Operating Cash Flow growth"
# [161] "Free Cash Flow growth"
# [162] "10Y Revenue Growth (per Share)"
# [163] "5Y Revenue Growth (per Share)"
# [164] "3Y Revenue Growth (per Share)"
# [165] "10Y Operating CF Growth (per Share)"
# [166] "5Y Operating CF Growth (per Share)"
# [167] "3Y Operating CF Growth (per Share)"
# [168] "10Y Net Income Growth (per Share)"
# [169] "5Y Net Income Growth (per Share)"
# [170] "3Y Net Income Growth (per Share)"
# [171] "10Y Shareholders Equity Growth (per Share)"
# [172] "5Y Shareholders Equity Growth (per Share)"
# [173] "3Y Shareholders Equity Growth (per Share)"
# [174] "10Y Dividend per Share Growth (per Share)"
# [175] "5Y Dividend per Share Growth (per Share)"
# [176] "3Y Dividend per Share Growth (per Share)"
# [177] "Receivables growth"
# [178] "Inventory Growth"
# [179] "Asset Growth"
# [180] "Book Value per Share Growth"
# [181] "Debt Growth"
# [182] "R&D Expense Growth"
# [183] "SG&A Expenses Growth"
# [184] "Payout Ratio"
# [185] "Interest Coverage"
# [186] "Net Profit Margin"
# [187] "Dividend Yield"
# [188] "PE ratio"
# [189] "PFCF ratio"
# [190] "POCF ratio"
# [191] "Price to Sales Ratio"
# [192] "Days Payables Outstanding"
# [193] "Free Cash Flow per Share"
# [194] "ROE"
# [195] "PTB ratio"
# [196] "PB ratio"
# [197] "Operating Cash Flow per Share"
# [198] "Cash per Share"

# %%
#Changing all names to lower case and replacing spaces with "_"
#Amending various features to make more compatible models
names(data) <- str_trim(names(data), side = "both")
names(data) <- str_to_lower(names(data), locale = "en")
names(data) <- str_replace_all(names(data), " ", "_")
names(data) <- str_replace_all(names(data), "-", "")
names(data) <- str_replace_all(names(data), "&", ".")
names(data) <- str_replace_all(names(data), "\\(", "")
names(data) <- str_replace_all(names(data), "\\)", "")
names(data) <- str_replace_all(names(data), "3y", "three_yr")
names(data) <- str_replace_all(names(data), "5y", "five_yr")
names(data) <- str_replace_all(names(data), "10y", "ten_yr")
names(data) <- str_replace_all(names(data), "\\\\", "")
names(data) <- str_replace_all(names(data), "////", "_")
names(data) <- str_replace_all(names(data), ",", "")
names(data) <- str_replace_all(names(data), "_._", "_")
names(data) <- str_replace_all(names(data), "/", "_")
setnames(data, 'eps', 'earnings_per_share')
names(data)
# Out:
#   [1] "stock"
#   [2] "nextyr_price_var"
#   [3] "class"
#   [4] "year"
#   [5] "sector"
#   [6] "revenue"
#   [7] "revenue_growth"
#   [8] "cost_of_revenue"
#   [9] "gross_profit"
#  [10] "r.d_expenses"
#  [11] "sg.a_expense"
#  [12] "operating_expenses"
#  [13] "operating_income"
#  [14] "interest_expense"
#  [15] "earnings_before_tax"
#  [16] "income_tax_expense"
#  [17] "net_income__noncontrolling_int"
#  [18] "net_income__discontinued_ops"
#  [19] "net_income"
#  [20] "preferred_dividends"
#  [21] "net_income_com"
#  [22] "earnings_per_share"
#  [23] "eps_diluted"
#  [24] "weighted_average_shs_out"
#  [25] "weighted_average_shs_out_dil"
#  [26] "dividend_per_share"
#  [27] "gross_margin"
#  [28] "ebitda_margin"
#  [29] "ebit_margin"
#  [30] "profit_margin"
#  [31] "free_cash_flow_margin"
#  [32] "ebitda"
#  [33] "ebit"
#  [34] "consolidated_income"
#  [35] "earnings_before_tax_margin"
#  [36] "cash_and_cash_equivalents"
#  [37] "shortterm_investments"
#  [38] "cash_and_shortterm_investments"
#  [39] "receivables"
#  [40] "inventories"
#  [41] "total_current_assets"
#  [42] "property_plant_equipment_net"
#  [43] "goodwill_and_intangible_assets"
#  [44] "longterm_investments"
#  [45] "tax_assets"
#  [46] "total_noncurrent_assets"
#  [47] "total_assets"
#  [48] "payables"
#  [49] "shortterm_debt"
#  [50] "total_current_liabilities"
#  [51] "longterm_debt"
#  [52] "total_debt"
#  [53] "deferred_revenue"
#  [54] "tax_liabilities"
#  [55] "deposit_liabilities"
#  [56] "total_noncurrent_liabilities"
#  [57] "total_liabilities"
#  [58] "other_comprehensive_income"
#  [59] "retained_earnings_deficit"
#  [60] "total_shareholders_equity"
#  [61] "investments"
#  [62] "net_debt"
#  [63] "other_assets"
#  [64] "other_liabilities"
#  [65] "depreciation_amortization"
#  [66] "stockbased_compensation"
#  [67] "operating_cash_flow"
#  [68] "capital_expenditure"
#  [69] "acquisitions_and_disposals"
#  [70] "investment_purchases_and_sales"
#  [71] "investing_cash_flow"
#  [72] "issuance_repayment_of_debt"
#  [73] "issuance_buybacks_of_shares"
#  [74] "dividend_payments"
#  [75] "financing_cash_flow"
#  [76] "effect_of_forex_changes_on_cash"
#  [77] "net_cash_flow_change_in_cash"
#  [78] "free_cash_flow"
#  [79] "net_cash_marketcap"
#  [80] "pricecashflowratio"
#  [81] "priceearningstogrowthratio"
#  [82] "pricesalesratio"
#  [83] "enterprisevaluemultiple"
#  [84] "pricefairvalue"
#  [85] "ebitperrevenue"
#  [86] "ebtperebit"
#  [87] "niperebt"
#  [88] "grossprofitmargin"
#  [89] "pretaxprofitmargin"
#  [90] "effectivetaxrate"
#  [91] "returnonassets"
#  [92] "returnoncapitalemployed"
#  [93] "payablesturnover"
#  [94] "inventoryturnover"
#  [95] "fixedassetturnover"
#  [96] "assetturnover"
#  [97] "currentratio"
#  [98] "quickratio"
#  [99] "cashratio"
# [100] "daysofsalesoutstanding"
# [101] "daysofinventoryoutstanding"
# [102] "debtratio"
# [103] "debtequityratio"
# [104] "longtermdebttocapitalization"
# [105] "totaldebttocapitalization"
# [106] "cashflowtodebtratio"
# [107] "companyequitymultiplier"
# [108] "operatingcashflowsalesratio"
# [109] "freecashflowoperatingcashflowratio"
# [110] "shorttermcoverageratios"
# [111] "capitalexpenditurecoverageratios"
# [112] "dividendpaidandcapexcoverageratios"
# [113] "dividendpayoutratio"
# [114] "revenue_per_share"
# [115] "net_income_per_share"
# [116] "book_value_per_share"
# [117] "tangible_book_value_per_share"
# [118] "shareholders_equity_per_share"
# [119] "interest_debt_per_share"
# [120] "market_cap"
# [121] "enterprise_value"
# [122] "ev_to_sales"
# [123] "enterprise_value_over_ebitda"
# [124] "ev_to_operating_cash_flow"
# [125] "ev_to_free_cash_flow"
# [126] "earnings_yield"
# [127] "free_cash_flow_yield"
# [128] "net_debt_to_ebitda"
# [129] "current_ratio"
# [130] "income_quality"
# [131] "sg.a_to_revenue"
# [132] "r.d_to_revenue"
# [133] "intangibles_to_total_assets"
# [134] "capex_to_operating_cash_flow"
# [135] "capex_to_revenue"
# [136] "capex_to_depreciation"
# [137] "stockbased_compensation_to_revenue"
# [138] "graham_number"
# [139] "graham_netnet"
# [140] "working_capital"
# [141] "tangible_asset_value"
# [142] "net_current_asset_value"
# [143] "invested_capital"
# [144] "average_receivables"
# [145] "average_payables"
# [146] "average_inventory"
# [147] "days_sales_outstanding"
# [148] "days_of_inventory_on_hand"
# [149] "receivables_turnover"
# [150] "capex_per_share"
# [151] "gross_profit_growth"
# [152] "ebit_growth"
# [153] "operating_income_growth"
# [154] "net_income_growth"
# [155] "eps_growth"
# [156] "eps_diluted_growth"
# [157] "weighted_average_shares_growth"
# [158] "weighted_average_shares_diluted_growth"
# [159] "dividends_per_share_growth"
# [160] "operating_cash_flow_growth"
# [161] "free_cash_flow_growth"
# [162] "ten_yr_revenue_growth_per_share"
# [163] "five_yr_revenue_growth_per_share"
# [164] "three_yr_revenue_growth_per_share"
# [165] "ten_yr_operating_cf_growth_per_share"
# [166] "five_yr_operating_cf_growth_per_share"
# [167] "three_yr_operating_cf_growth_per_share"
# [168] "ten_yr_net_income_growth_per_share"
# [169] "five_yr_net_income_growth_per_share"
# [170] "three_yr_net_income_growth_per_share"
# [171] "ten_yr_shareholders_equity_growth_per_share"
# [172] "five_yr_shareholders_equity_growth_per_share"
# [173] "three_yr_shareholders_equity_growth_per_share"
# [174] "ten_yr_dividend_per_share_growth_per_share"
# [175] "five_yr_dividend_per_share_growth_per_share"
# [176] "three_yr_dividend_per_share_growth_per_share"
# [177] "receivables_growth"
# [178] "inventory_growth"
# [179] "asset_growth"
# [180] "book_value_per_share_growth"
# [181] "debt_growth"
# [182] "r.d_expense_growth"
# [183] "sg.a_expenses_growth"
# [184] "payout_ratio"
# [185] "interest_coverage"
# [186] "net_profit_margin"
# [187] "dividend_yield"
# [188] "pe_ratio"
# [189] "pfcf_ratio"
# [190] "pocf_ratio"
# [191] "price_to_sales_ratio"
# [192] "days_payables_outstanding"
# [193] "free_cash_flow_per_share"
# [194] "roe"
# [195] "ptb_ratio"
# [196] "pb_ratio"
# [197] "operating_cash_flow_per_share"
# [198] "cash_per_share"

# %% [markdown]
# ### Categorical Encoding
# Are there any categorical variables in your data? If so, transform them so that they can be used to train a machine learning algorithm.

# %%
#Categorical Encoding
data[, sector := as.factor(sector)]
data[, sector_num := as.numeric(sector)]

#Reordering data to put "sector" with "sector_num"
data <- data %>%
  dplyr::select('stock','nextyr_price_var','class','year','sector','sector_num', everything()) %>%
  setDT()

# %% [markdown]
# ### Missing Data
# If missing data is present (ie, NaN values), what is the best way to deal with it? Should values be imputed (and if so, how)? Or should they simply be filled? How will each option will affect the ultimate outcome of your model? Design and implement a solution.

# %%
na <- apply(is.na(data),2,sum)
#print(na)
max(na)
#sort(na, decreasing = TRUE)
head(sort(na, decreasing = TRUE), n=25)
summary(na)
# Out:
# [1] 10744
#                      shorttermcoverageratios
#                                        10744
#  ten_yr_shareholders_equity_growth_per_share
#                                         9680
#              ten_yr_revenue_growth_per_share
#                                         9532
#           ten_yr_net_income_growth_per_share
#                                         9532
#         ten_yr_operating_cf_growth_per_share
#                                         9478
#   ten_yr_dividend_per_share_growth_per_share
#                                         9177
#                   priceearningstogrowthratio
#                                         9079
#                          dividendpayoutratio
#                                         9079
#                                     niperebt
#                                         8595
#                             effectivetaxrate
#                                         8595
#                                   ebtperebit
#                                         8007
#                           net_debt_to_ebitda
#                                         7715
#                           pricecashflowratio
#                                         7064
#                      enterprisevaluemultiple
#                                         6944
#                                     net_debt
#                                         6859
#                                 other_assets
#                                         6756
# five_yr_shareholders_equity_growth_per_share
#                                         6610
#           freecashflowoperatingcashflowratio
#                                         6588
#                               returnonassets
#                                         6535
#                                current_ratio
#                                         6516
#                              working_capital
#                                         6510
#                      returnoncapitalemployed
#                                         6509
#             five_yr_revenue_growth_per_share
#                                         6401
#          five_yr_net_income_growth_per_share
#                                         6401
#        five_yr_operating_cf_growth_per_share
#                                         6364
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       0    1835    2315    3069    3197   10744

# %%
#Checking how many rows are complete
sum(complete.cases(data))

#Checking for NA across rows
data$na <- rowSums(is.na(data))
max(data$na)
head(sort(data$na, decreasing = TRUE),n = 20)
summary(data$na)
# Out:
# [1] 3454
# [1] 193
#  [1] 193 193 193 193 193 193 193 193 193 193 193 193 193 193 193 193 193 193 193
# [20] 193
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    2.00   10.00   27.67   23.00  193.00

# %%
#Found that 50 was a good cut off for dropping rows
drop <- data %>% 
  filter(na >= 50)
dim(drop)

data <- data %>%
  filter(na <= 50)

data <- dplyr::select(data, -c(na))

#Re-checking the NAs across columns
na <- apply(is.na(data),2,sum)
max(na)
# NOTE: The following code has been commmented out due to the length of its output.
#print(na)
#sort(na, decreasing = TRUE)
head(sort(na, decreasing = TRUE), n=25)
# Out:
# [1] 2500  200
# [1] 8380
#                      shorttermcoverageratios
#                                         8380
#  ten_yr_shareholders_equity_growth_per_share
#                                         7209
#              ten_yr_revenue_growth_per_share
#                                         7055
#           ten_yr_net_income_growth_per_share
#                                         7055
#         ten_yr_operating_cf_growth_per_share
#                                         7008
#   ten_yr_dividend_per_share_growth_per_share
#                                         6708
#                   priceearningstogrowthratio
#                                         6636
#                          dividendpayoutratio
#                                         6636
#                                     niperebt
#                                         6466
#                             effectivetaxrate
#                                         6466
#                                   ebtperebit
#                                         5656
#                           net_debt_to_ebitda
#                                         5270
#                                     net_debt
#                                         5253
#                                 other_assets
#                                         5164
#                           pricecashflowratio
#                                         4623
#           freecashflowoperatingcashflowratio
#                                         4569
#                      enterprisevaluemultiple
#                                         4559
#                          cashflowtodebtratio
#                                         4215
# five_yr_shareholders_equity_growth_per_share
#                                         4151
#                                current_ratio
#                                         4141
#                               returnonassets
#                                         4140
#                 total_noncurrent_liabilities
#                                         4139
#                      returnoncapitalemployed
#                                         4136
#                              working_capital
#                                         4136
#                      total_noncurrent_assets
#                                         4129

# %%
#Keeping only columns with less than ~15 percent missing
perc <- apply(data,2,Perc_Missing)
max(perc)
# NOTE: The following code has been commmented out due to the length of its output.
#print(perc)
#sort(perc, decreasing = TRUE)
head(sort(perc, decreasing = TRUE), n=25)

#Choosing to only keep variables with less than 15% missing data
data <- data[, which(apply(data,2,Perc_Missing) < 15.0)]
# Out:
# [1] 42.77256
#                      shorttermcoverageratios
#                                     42.77256
#  ten_yr_shareholders_equity_growth_per_share
#                                     36.79563
#              ten_yr_revenue_growth_per_share
#                                     36.00960
#           ten_yr_net_income_growth_per_share
#                                     36.00960
#         ten_yr_operating_cf_growth_per_share
#                                     35.76970
#   ten_yr_dividend_per_share_growth_per_share
#                                     34.23846
#                   priceearningstogrowthratio
#                                     33.87097
#                          dividendpayoutratio
#                                     33.87097
#                                     niperebt
#                                     33.00327
#                             effectivetaxrate
#                                     33.00327
#                                   ebtperebit
#                                     28.86893
#                           net_debt_to_ebitda
#                                     26.89873
#                                     net_debt
#                                     26.81196
#                                 other_assets
#                                     26.35770
#                           pricecashflowratio
#                                     23.59637
#           freecashflowoperatingcashflowratio
#                                     23.32074
#                      enterprisevaluemultiple
#                                     23.26970
#                          cashflowtodebtratio
#                                     21.51388
# five_yr_shareholders_equity_growth_per_share
#                                     21.18722
#                                current_ratio
#                                     21.13618
#                               returnonassets
#                                     21.13107
#                 total_noncurrent_liabilities
#                                     21.12597
#                      returnoncapitalemployed
#                                     21.11066
#                              working_capital
#                                     21.11066
#                      total_noncurrent_assets
#                                     21.07493

# %% [markdown]
# ### Multicollinearity/Linear Dependence/Winsorization

# %%
#Splitting datasets
data <- setDT(data)
data2 <- select(data, c('stock','nextyr_price_var','sector'))
data <- select(data, -c('stock','nextyr_price_var','sector'))

#Checking VIF
data <- data[, class := as.factor(class)]
set.seed(123)
glm <- suppressWarnings(glm(class~., family = binomial
           , data = data))

# %%
#Find the linearly dependent variables
vars <- attributes(alias(glm)$Complete)$dimnames[[1]]
vars

# Remove the linearly dependent variables
remove <- match(vars,names(data))
remove

dim(data)
data <- select(data, -c(remove))
dim(data)
# Out:
# [1] "days_sales_outstanding"    "days_of_inventory_on_hand"
# [1] 126 127
# [1] 19592   167
# [1] 19592   165

# %%
#Re-run regression without linearly dependent variables
set.seed(123)
glm <- suppressWarnings(glm(class~., family = binomial
           , data = data))

# %%
#NOTE: This section of the code will take some time to run.
#The function VIF_Check runs a regression and removes the max
#VIF, repeating this process until all VIFs are below threshold
#Removing variables with VIFs above 5
data <- VIF_Check(dat=data, threshold=5)
# Out:
# [1] 31848522
# [1] 31848522
# [1] 13727077
# [1] 6567829
# [1] 558586.5
# [1] 228754.2
# [1] 219056.6
# [1] 147027.9
# [1] 86891.98
# [1] 70412.86
# [1] 46632.56
# [1] 33074.87
# [1] 26687.25
# [1] 15686.43
# [1] 10301.86
# [1] 8468.376
# [1] 6086.797
# [1] 8416.862
# [1] 9055.831
# [1] 4066.393
# [1] 2987.626
# [1] 2824.977
# [1] 2199.412
# [1] 1760.843
# [1] 1691.861
# [1] 1627.559
# [1] 1515.678
# [1] 791.6509
# [1] 647.0901
# [1] 607.7472
# [1] 545.4467
# [1] 307.4189
# [1] 290.9236
# [1] 255.0669
# [1] 244.4844
# [1] 224.1648
# [1] 207.1089
# [1] 169.4459
# [1] 141.986
# [1] 140.9392
# [1] 116.1003
# [1] 113.7217
# [1] 94.91644
# [1] 93.13798
# [1] 50.84481
# [1] 45.15902
# [1] 45.004
# [1] 2967.687
# [1] 35.95497
# [1] 35.44187
# [1] 35.27178
# [1] 31.62997
# [1] 29.10458
# [1] 25.79769
# [1] 22.84653
# [1] 20.31843
# [1] 15.96435
# [1] 15.85057
# [1] 15.77902
# [1] 12.96951
# [1] 12.18576
# [1] 11.94668
# [1] 9.455477
# [1] 8.959038
# [1] 8.448388
# [1] 8.277409
# [1] 7.683182
# [1] 5.969597
# [1] 5.958365
# [1] 5.920798
# [1] 5.45168
# [1] 4.969429
# [1] "All VIFs are below threshold of 5"

# %%
#Re-combine data
data <- cbind(data2,data) %>% setDT()
dim(data)
# Out:
# [1] 19592    98

# %%
#Re-run regression without linearly dependent variables
set.seed(123)
glm <- suppressWarnings(glm(class~., family = binomial(link = "logit")
                  , data = data[, -c('stock','nextyr_price_var','sector')], control = list(maxit = 100)))

# %%
#Split data for winsorization
data2 <- select(data, c('class','year','sector_num','stock'
                        ,'nextyr_price_var','sector'))
data <- select(data, -c('class','year','sector_num','stock'
                        ,'nextyr_price_var','sector'))

# %%
data <- map_df(data, ~Winsorize(., probs=c(0.05,0.95),na.rm=TRUE))

#Recombine datasets
data <- cbind(data2,data) %>% setDT()
dim(data)
# Out:
# [1] 19592    98

# %%
#Re-run regression to see if error has been corrected
#No warning message occurs
set.seed(123)
glm <- glm(class~., family = binomial(link = "logit")
           , data = data[, -c('stock','nextyr_price_var','sector')], control = list(maxit = 100))
summary(glm)
# Out:
# Call:
# glm(formula = class ~ ., family = binomial(link = "logit"), data = data[,
#     -c("stock", "nextyr_price_var", "sector")], control = list(maxit = 100))
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.2334  -1.1861   0.7578   1.0342   2.0884
#
# Coefficients:
#                                                 Estimate Std. Error z value
# (Intercept)                                   -1.509e+02  3.000e+01  -5.029
# year                                           7.468e-02  1.488e-02   5.019
# sector_num                                     6.619e-02  7.889e-03   8.390
# cost_of_revenue                                2.081e-13  1.687e-11   0.012
# r.d_expenses                                  -1.845e-10  4.933e-10  -0.374
# sg.a_expense                                  -3.412e-11  4.662e-11  -0.732
# interest_expense                              -1.484e-10  4.859e-10  -0.305
# income_tax_expense                            -8.698e-11  2.480e-10  -0.351
# net_income__noncontrolling_int                -5.524e-09  2.257e-09  -2.447
# net_income__discontinued_ops                   2.627e-08  7.241e-08   0.363
# preferred_dividends                           -1.998e-08  1.122e-08  -1.781
# earnings_per_share                             1.084e-01  2.036e-02   5.322
# weighted_average_shs_out_dil                   2.893e-10  2.708e-10   1.068
# dividend_per_share                             6.199e-02  5.746e-02   1.079
# ebitda_margin                                  2.966e-02  4.244e-02   0.699
# consolidated_income                           -3.442e-10  1.081e-10  -3.183
# cash_and_cash_equivalents                      2.982e-11  6.017e-11   0.496
# shortterm_investments                          2.792e-10  1.590e-10   1.756
# receivables                                   -1.472e-10  7.170e-11  -2.053
# goodwill_and_intangible_assets                -2.395e-11  2.411e-11  -0.993
# longterm_investments                           9.182e-11  5.268e-11   1.743
# tax_assets                                    -4.324e-10  2.957e-10  -1.463
# payables                                       1.598e-10  8.676e-11   1.842
# shortterm_debt                                 1.373e-10  1.049e-10   1.308
# longterm_debt                                  1.198e-11  2.243e-11   0.534
# deferred_revenue                               7.937e-10  2.850e-10   2.785
# tax_liabilities                                1.285e-10  9.503e-11   1.352
# other_comprehensive_income                    -1.392e-10  1.898e-10  -0.734
# retained_earnings_deficit                     -6.287e-13  1.680e-11  -0.037
# other_liabilities                              2.769e-12  2.342e-11   0.118
# stockbased_compensation                        1.169e-09  1.261e-09   0.927
# capital_expenditure                            1.234e-10  1.481e-10   0.833
# acquisitions_and_disposals                    -2.141e-10  1.962e-10  -1.091
# investment_purchases_and_sales                 5.265e-10  2.063e-10   2.552
# issuance_repayment_of_debt                     1.780e-10  9.730e-11   1.829
# issuance_buybacks_of_shares                   -2.596e-10  1.792e-10  -1.449
# effect_of_forex_changes_on_cash               -4.065e-08  3.827e-09 -10.621
# net_cash_flow_change_in_cash                  -2.708e-10  1.729e-10  -1.566
# net_cash_marketcap                             1.086e-01  5.628e-02   1.929
# grossprofitmargin                              1.425e-01  1.077e-01   1.323
# payablesturnover                               8.345e-03  6.289e-03   1.327
# inventoryturnover                             -1.019e-03  9.688e-04  -1.052
# fixedassetturnover                             5.727e-04  1.778e-03   0.322
# assetturnover                                 -1.378e-01  5.631e-02  -2.448
# currentratio                                   4.903e-03  2.184e-02   0.224
# quickratio                                     1.802e-02  2.878e-02   0.626
# cashratio                                     -6.107e-02  3.128e-02  -1.952
# daysofsalesoutstanding                         3.590e-05  3.917e-04   0.092
# daysofinventoryoutstanding                    -1.623e-03  6.446e-04  -2.518
# debtratio                                     -5.029e-01  2.545e-01  -1.976
# debtequityratio                               -5.493e-02  2.893e-02  -1.898
# longtermdebttocapitalization                   6.725e-01  1.849e-01   3.637
# capitalexpenditurecoverageratios               2.105e-04  1.423e-03   0.148
# ev_to_sales                                   -2.125e-03  7.241e-03  -0.293
# enterprise_value_over_ebitda                   3.510e-03  2.435e-03   1.442
# ev_to_free_cash_flow                           2.303e-04  9.893e-04   0.233
# earnings_yield                                 4.028e-02  2.079e-01   0.194
# income_quality                                 1.670e-02  1.291e-02   1.294
# intangibles_to_total_assets                    1.769e-01  1.392e-01   1.271
# capex_to_revenue                               1.928e-01  2.273e-01   0.848
# capex_to_depreciation                         -6.909e-02  2.670e-02  -2.588
# graham_number                                 -5.202e-03  1.989e-03  -2.615
# receivables_turnover                           2.119e-04  1.968e-03   0.108
# capex_per_share                                1.512e-02  1.438e-02   1.051
# gross_profit_growth                           -1.562e-01  7.941e-02  -1.968
# ebit_growth                                   -6.307e-03  4.317e-02  -0.146
# operating_income_growth                       -5.044e-02  4.262e-02  -1.184
# net_income_growth                             -1.454e-02  2.624e-02  -0.554
# weighted_average_shares_growth                -3.288e-01  3.260e-01  -1.009
# weighted_average_shares_diluted_growth         2.355e-01  2.812e-01   0.837
# dividends_per_share_growth                     2.510e-01  1.865e-01   1.346
# operating_cash_flow_growth                    -7.679e-03  3.296e-02  -0.233
# free_cash_flow_growth                          5.196e-02  2.068e-02   2.513
# three_yr_revenue_growth_per_share              2.112e-01  1.654e-01   1.277
# three_yr_operating_cf_growth_per_share         1.047e-01  1.315e-01   0.796
# three_yr_net_income_growth_per_share           2.997e-01  1.292e-01   2.320
# three_yr_shareholders_equity_growth_per_share  3.449e-01  1.709e-01   2.018
# three_yr_dividend_per_share_growth_per_share   1.917e-01  2.184e-01   0.878
# receivables_growth                            -6.528e-02  6.665e-02  -0.979
# inventory_growth                              -3.621e-01  1.271e-01  -2.848
# asset_growth                                  -9.697e-02  1.170e-01  -0.829
# book_value_per_share_growth                   -1.150e-01  7.797e-02  -1.475
# debt_growth                                   -3.268e-03  5.053e-02  -0.065
# r.d_expense_growth                            -4.153e-01  1.429e-01  -2.907
# sg.a_expenses_growth                          -1.304e-02  1.322e-01  -0.099
# payout_ratio                                  -2.037e-01  9.222e-02  -2.209
# interest_coverage                             -1.019e-03  1.027e-03  -0.992
# dividend_yield                                 5.154e+00  1.813e+00   2.842
# pe_ratio                                       5.291e-04  1.668e-03   0.317
# pfcf_ratio                                     1.420e-03  2.005e-03   0.708
# pocf_ratio                                    -1.498e-04  1.804e-03  -0.083
# days_payables_outstanding                     -1.246e-03  6.061e-04  -2.056
# free_cash_flow_per_share                      -1.432e-03  1.121e-02  -0.128
# roe                                            1.712e-01  8.006e-02   2.138
# ptb_ratio                                      8.050e-04  4.027e-03   0.200
#                                               Pr(>|z|)
# (Intercept)                                   4.92e-07 ***
# year                                          5.20e-07 ***
# sector_num                                     < 2e-16 ***
# cost_of_revenue                               0.990155
# r.d_expenses                                  0.708360
# sg.a_expense                                  0.464195
# interest_expense                              0.760036
# income_tax_expense                            0.725786
# net_income__noncontrolling_int                0.014403 *
# net_income__discontinued_ops                  0.716731
# preferred_dividends                           0.074868 .
# earnings_per_share                            1.03e-07 ***
# weighted_average_shs_out_dil                  0.285318
# dividend_per_share                            0.280647
# ebitda_margin                                 0.484628
# consolidated_income                           0.001456 **
# cash_and_cash_equivalents                     0.620114
# shortterm_investments                         0.079065 .
# receivables                                   0.040082 *
# goodwill_and_intangible_assets                0.320518
# longterm_investments                          0.081358 .
# tax_assets                                    0.143598
# payables                                      0.065525 .
# shortterm_debt                                0.190761
# longterm_debt                                 0.593277
# deferred_revenue                              0.005352 **
# tax_liabilities                               0.176422
# other_comprehensive_income                    0.463121
# retained_earnings_deficit                     0.970149
# other_liabilities                             0.905904
# stockbased_compensation                       0.353695
# capital_expenditure                           0.404750
# acquisitions_and_disposals                    0.275174
# investment_purchases_and_sales                0.010704 *
# issuance_repayment_of_debt                    0.067369 .
# issuance_buybacks_of_shares                   0.147251
# effect_of_forex_changes_on_cash                < 2e-16 ***
# net_cash_flow_change_in_cash                  0.117236
# net_cash_marketcap                            0.053771 .
# grossprofitmargin                             0.185727
# payablesturnover                              0.184563
# inventoryturnover                             0.292992
# fixedassetturnover                            0.747348
# assetturnover                                 0.014371 *
# currentratio                                  0.822406
# quickratio                                    0.531261
# cashratio                                     0.050900 .
# daysofsalesoutstanding                        0.926989
# daysofinventoryoutstanding                    0.011794 *
# debtratio                                     0.048172 *
# debtequityratio                               0.057644 .
# longtermdebttocapitalization                  0.000276 ***
# capitalexpenditurecoverageratios              0.882420
# ev_to_sales                                   0.769178
# enterprise_value_over_ebitda                  0.149425
# ev_to_free_cash_flow                          0.815897
# earnings_yield                                0.846353
# income_quality                                0.195579
# intangibles_to_total_assets                   0.203715
# capex_to_revenue                              0.396368
# capex_to_depreciation                         0.009665 **
# graham_number                                 0.008918 **
# receivables_turnover                          0.914250
# capex_per_share                               0.293048
# gross_profit_growth                           0.049115 *
# ebit_growth                                   0.883840
# operating_income_growth                       0.236597
# net_income_growth                             0.579609
# weighted_average_shares_growth                0.313181
# weighted_average_shares_diluted_growth        0.402399
# dividends_per_share_growth                    0.178456
# operating_cash_flow_growth                    0.815773
# free_cash_flow_growth                         0.011981 *
# three_yr_revenue_growth_per_share             0.201590
# three_yr_operating_cf_growth_per_share        0.426055
# three_yr_net_income_growth_per_share          0.020334 *
# three_yr_shareholders_equity_growth_per_share 0.043549 *
# three_yr_dividend_per_share_growth_per_share  0.379924
# receivables_growth                            0.327361
# inventory_growth                              0.004400 **
# asset_growth                                  0.407180
# book_value_per_share_growth                   0.140210
# debt_growth                                   0.948445
# r.d_expense_growth                            0.003645 **
# sg.a_expenses_growth                          0.921444
# payout_ratio                                  0.027195 *
# interest_coverage                             0.321357
# dividend_yield                                0.004477 **
# pe_ratio                                      0.751065
# pfcf_ratio                                    0.478748
# pocf_ratio                                    0.933836
# days_payables_outstanding                     0.039778 *
# free_cash_flow_per_share                      0.898322
# roe                                           0.032505 *
# ptb_ratio                                     0.841541
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 16538  on 12065  degrees of freedom
# Residual deviance: 15560  on 11971  degrees of freedom
#   (7526 observations deleted due to missingness)
# AIC: 15750
#
# Number of Fisher Scoring iterations: 4

# %% [markdown]
# ### Imputing Missing Values

# %%
#Imputation will be implemented if necessary in the modeling notebook

# %% [markdown]
# ### Uniformity
# Are all variables measured using compatible units? Or are there monetary values in different forms of currency? Or something else entirely? If any of these issues are applicable to your data, design and implement a solution.

# %%
#Implementing scaling in the modeling notebook

# %% [markdown]
# ### Additional Cleaning
# If your data set has any other issues you have noticed, you should handle them here.

# %%
#No additional cleaning was performed in this notebook

# %% [markdown]
# ## Save the Prepared Set

# %%
fwrite(data, paste0(dir$final_data,'clean_financial.csv'))

# %% [markdown]
# ## Outcome
# At this point you should have an analytic data set prepared for data modeling. You should also be able to account for any changes you have made in the data. Do this now.

# %% [markdown]
# ##### The following changes were made to the data set:
#  - Duplicates: Any duplicate columns were removed from the data set. This was done by first using the duplicated function to identify identical columns. Then, I looked at the columns sums to identify additional duplicate variables. In the end, about 20 variables were duplicated.
#  - Variable Names: The variables names were cleaned up so that they were consistent. Spaces and dashes were removed, all letters were lower-cased, and underscores were added between most words.
#  - Categorical Encoding: A new variable "sector_num" was created as the numeric version of the categorical variable "sector" to aid in machine learning modeling.
#  - Missing Data: The missing data was cleaned in the following manner:
#       1. Any row with missing values greater than 50 was removed
#       2. Any column with missing values greater than 15% was removed
#       3. The remaining values will be imputed after relevant variables are identified.
#  - Outliers: The outliers in the data set were removed in the previous notebook using Cook's Distance. Only four rows were identified as extreme outliers and were thus removed from the data set.
#  - Multicollinearity: A significant portion of variables in the dataset had high multicollinearity and a few were even found to be perfectly collinear. To solve this issue, all variables with a VIF greater than or equal to 5 were removed from the dataset. This resulted in approximately 70 variables being removed from the dataset.
#  -  Complete Separation: When running a basic regression, predicted probabilities that were effectively indistinguishable from 1 were occurring. To solve this issue, I first removed collinear variables. After this did not solve the issue, I winsorized the majority of the independent variables in the dataset.
