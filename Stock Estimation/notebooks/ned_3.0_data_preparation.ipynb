# %% [markdown]
# # Data Preparation

# %% [markdown]
# ### Settings/Functions
# Read in settings and functions.

# %%
libraries <-c('here','missForest','stringr','imputeMissings')
suppressWarnings(lapply(libraries, require, character.only = TRUE))
suppressWarnings(source(here::here('Stock Estimation', 'settings.R')))
# Out:
# [[1]]
# [1] TRUE
#
# [[2]]
# [1] TRUE
#
# [[3]]
# [1] TRUE
#
# [[4]]
# [1] TRUE

# %% [markdown]
# ### Data
# Read in the final data set from the data preparation notebook.

# %%
data <- fread(paste0(dir$final_data,'combined_financial.csv'))

# %% [markdown]
# ## More Cleaning

# %% [markdown]
# ### Duplicates
# Deal with any duplicate rows/columns (or, contrarily, any empty rows/columns), if applicable.

# %%
#Checking for duplicate column sums
dups <- data[ , which(duplicated(t(data)))]
dups <- names(dups)
dups
# Out:
#  [1] "nIperEBT"                  "eBTperEBIT"
#  [3] "eBITperRevenue"            "cashFlowCoverageRatios"
#  [5] "Debt to Equity"            "Debt to Assets"
#  [7] "ROIC"                      "Return on Tangible Assets"
#  [9] "Payables Turnover"         "Inventory Turnover"

# %%
#Removing any duplicate column sums after verifying them
data <- data %>% dplyr::select(-c(dups))
dim(data)
# Out:
# [1] 22073   214

# %%
#Looking for missing values & evaluating list of variable names
na <- apply(is.na(data),2,sum)
max(na)
# NOTE: The following code has been commmented out due to the length of its output.
#print(na)
head(sort(na, decreasing = TRUE), n=25)
# Out:
# [1] 10744
#                    shortTermCoverageRatios
#                                      10744
# 10Y Shareholders Equity Growth (per Share)
#                                       9680
#             10Y Revenue Growth (per Share)
#                                       9532
#          10Y Net Income Growth (per Share)
#                                       9532
#        10Y Operating CF Growth (per Share)
#                                       9478
#  10Y Dividend per Share Growth (per Share)
#                                       9177
#                 priceEarningsToGrowthRatio
#                                       9079
#                        dividendPayoutRatio
#                                       9079
#                                   niperEBT
#                                       8595
#                           effectiveTaxRate
#                                       8595
#                                 ebtperEBIT
#                                       8007
#                         Net Debt to EBITDA
#                                       7715
#                         priceCashFlowRatio
#                                       7064
#                    enterpriseValueMultiple
#                                       6944
#                                   Net Debt
#                                       6859
#                               Other Assets
#                                       6756
#  5Y Shareholders Equity Growth (per Share)
#                                       6610
#         freeCashFlowOperatingCashFlowRatio
#                                       6588
#                             returnOnAssets
#                                       6535
#                              Current ratio
#                                       6516
#                            Working Capital
#                                       6510
#                    returnOnCapitalEmployed
#                                       6509
#              5Y Revenue Growth (per Share)
#                                       6401
#           5Y Net Income Growth (per Share)
#                                       6401
#         5Y Operating CF Growth (per Share)
#                                       6364

# %%
#Merging and dropping duplicated variable names
#view(data[, c("Payout Ratio", "payoutRatio")])
data <- Name_Changer(dat=data,x='Payout Ratio',y='payoutRatio')

#view(data[, c('interestCoverage', 'Interest Coverage')])
data <- Name_Changer(dat=data,x='Interest Coverage',y='interestCoverage')

#view(data[, c('netProfitMargin', 'Net Profit Margin')])
data <- Name_Changer(dat=data,x='Net Profit Margin',y='netProfitMargin')

#view(data[, c('Dividend Yield', 'dividendYield')])
data <- Name_Changer(dat=data,x='Dividend Yield',y='dividendYield')

#view(data[, c('PE ratio', 'priceEarningsRatio')])
data <- Name_Changer(dat=data,x='PE ratio',y='priceEarningsRatio')

#view(data[, c('priceToFreeCashFlowsRatio', 'PFCF ratio')])
data <- Name_Changer(dat=data,x='PFCF ratio',y='priceToFreeCashFlowsRatio')

#view(data[, c('priceToOperatingCashFlowsRatio', 'POCF ratio')])
data <- Name_Changer(dat=data,x='POCF ratio',y='priceToOperatingCashFlowsRatio')

#view(data[, c('priceToSalesRatio', 'Price to Sales Ratio')])
data <- Name_Changer(dat=data,x='Price to Sales Ratio',y='priceToSalesRatio')

#view(data[, c('Days Payables Outstanding', 'daysOfPayablesOutstanding')])
data <- Name_Changer(dat=data,x='Days Payables Outstanding',y='daysOfPayablesOutstanding')

#view(data[, c('Free Cash Flow per Share', 'freeCashFlowPerShare')])
data <- Name_Changer(dat=data,x='Free Cash Flow per Share',y='freeCashFlowPerShare')

#view(data[, c('ROE', 'returnOnEquity')])
data <- Name_Changer(dat=data,x='ROE',y='returnOnEquity')

#view(data[, c('priceToBookRatio', 'PTB ratio')])
data <- Name_Changer(dat=data,x='PTB ratio',y='priceToBookRatio')

#view(data[, c('priceBookValueRatio', 'PB ratio')])
data <- Name_Changer(dat=data,x='PB ratio',y='priceBookValueRatio')

#view(data[, c('operatingCashFlowPerShare', 'Operating Cash Flow per Share')])
data <- Name_Changer(dat=data,x='Operating Cash Flow per Share',y='operatingCashFlowPerShare')

#view(data[, c('Cash per Share', 'cashPerShare')])
data <- Name_Changer(dat=data,x='Cash per Share',y='cashPerShare')

dim(data)
# Out:
# [1] 22073   199

# %% [markdown]
# ### Variable Names
# Depending on your data set, variables may have names with strange symbols, which can making loading, saving, and subsetting data difficult. If applicable, you should deal with this now.

# %%
#Checking variable names
names(data)
# Out:
#   [1] "Stock"
#   [2] "nextYR_PRICE_VAR"
#   [3] "Class"
#   [4] "Year"
#   [5] "Sector"
#   [6] "Revenue"
#   [7] "Revenue Growth"
#   [8] "Cost of Revenue"
#   [9] "Gross Profit"
#  [10] "R&D Expenses"
#  [11] "SG&A Expense"
#  [12] "Operating Expenses"
#  [13] "Operating Income"
#  [14] "Interest Expense"
#  [15] "Earnings before Tax"
#  [16] "Income Tax Expense"
#  [17] "Net Income - Non-Controlling int"
#  [18] "Net Income - Discontinued ops"
#  [19] "Net Income"
#  [20] "Preferred Dividends"
#  [21] "Net Income Com"
#  [22] "EPS"
#  [23] "EPS Diluted"
#  [24] "Weighted Average Shs Out"
#  [25] "Weighted Average Shs Out (Dil)"
#  [26] "Dividend per Share"
#  [27] "Gross Margin"
#  [28] "EBITDA Margin"
#  [29] "EBIT Margin"
#  [30] "Profit Margin"
#  [31] "Free Cash Flow margin"
#  [32] "EBITDA"
#  [33] "EBIT"
#  [34] "Consolidated Income"
#  [35] "Earnings Before Tax Margin"
#  [36] "Cash and cash equivalents"
#  [37] "Short-term investments"
#  [38] "Cash and short-term investments"
#  [39] "Receivables"
#  [40] "Inventories"
#  [41] "Total current assets"
#  [42] "Property, Plant & Equipment Net"
#  [43] "Goodwill and Intangible Assets"
#  [44] "Long-term investments"
#  [45] "Tax assets"
#  [46] "Total non-current assets"
#  [47] "Total assets"
#  [48] "Payables"
#  [49] "Short-term debt"
#  [50] "Total current liabilities"
#  [51] "Long-term debt"
#  [52] "Total debt"
#  [53] "Deferred revenue"
#  [54] "Tax Liabilities"
#  [55] "Deposit Liabilities"
#  [56] "Total non-current liabilities"
#  [57] "Total liabilities"
#  [58] "Other comprehensive income"
#  [59] "Retained earnings (deficit)"
#  [60] "Total shareholders equity"
#  [61] "Investments"
#  [62] "Net Debt"
#  [63] "Other Assets"
#  [64] "Other Liabilities"
#  [65] "Depreciation & Amortization"
#  [66] "Stock-based compensation"
#  [67] "Operating Cash Flow"
#  [68] "Capital Expenditure"
#  [69] "Acquisitions and disposals"
#  [70] "Investment purchases and sales"
#  [71] "Investing Cash flow"
#  [72] "Issuance (repayment) of debt"
#  [73] "Issuance (buybacks) of shares"
#  [74] "Dividend payments"
#  [75] "Financing Cash Flow"
#  [76] "Effect of forex changes on cash"
#  [77] "Net cash flow / Change in cash"
#  [78] "Free Cash Flow"
#  [79] "Net Cash/Marketcap"
#  [80] "priceCashFlowRatio"
#  [81] "priceEarningsToGrowthRatio"
#  [82] "priceSalesRatio"
#  [83] "enterpriseValueMultiple"
#  [84] "priceFairValue"
#  [85] "ebitperRevenue"
#  [86] "ebtperEBIT"
#  [87] "niperEBT"
#  [88] "grossProfitMargin"
#  [89] "operatingProfitMargin"
#  [90] "pretaxProfitMargin"
#  [91] "effectiveTaxRate"
#  [92] "returnOnAssets"
#  [93] "returnOnCapitalEmployed"
#  [94] "payablesTurnover"
#  [95] "inventoryTurnover"
#  [96] "fixedAssetTurnover"
#  [97] "assetTurnover"
#  [98] "currentRatio"
#  [99] "quickRatio"
# [100] "cashRatio"
# [101] "daysOfSalesOutstanding"
# [102] "daysOfInventoryOutstanding"
# [103] "debtRatio"
# [104] "debtEquityRatio"
# [105] "longtermDebtToCapitalization"
# [106] "totalDebtToCapitalization"
# [107] "cashFlowToDebtRatio"
# [108] "companyEquityMultiplier"
# [109] "operatingCashFlowSalesRatio"
# [110] "freeCashFlowOperatingCashFlowRatio"
# [111] "shortTermCoverageRatios"
# [112] "capitalExpenditureCoverageRatios"
# [113] "dividendpaidAndCapexCoverageRatios"
# [114] "dividendPayoutRatio"
# [115] "Revenue per Share"
# [116] "Net Income per Share"
# [117] "Book Value per Share"
# [118] "Tangible Book Value per Share"
# [119] "Shareholders Equity per Share"
# [120] "Interest Debt per Share"
# [121] "Market Cap"
# [122] "Enterprise Value"
# [123] "EV to Sales"
# [124] "Enterprise Value over EBITDA"
# [125] "EV to Operating cash flow"
# [126] "EV to Free cash flow"
# [127] "Earnings Yield"
# [128] "Free Cash Flow Yield"
# [129] "Net Debt to EBITDA"
# [130] "Current ratio"
# [131] "Income Quality"
# [132] "SG&A to Revenue"
# [133] "R&D to Revenue"
# [134] "Intangibles to Total Assets"
# [135] "Capex to Operating Cash Flow"
# [136] "Capex to Revenue"
# [137] "Capex to Depreciation"
# [138] "Stock-based compensation to Revenue"
# [139] "Graham Number"
# [140] "Graham Net-Net"
# [141] "Working Capital"
# [142] "Tangible Asset Value"
# [143] "Net Current Asset Value"
# [144] "Invested Capital"
# [145] "Average Receivables"
# [146] "Average Payables"
# [147] "Average Inventory"
# [148] "Days Sales Outstanding"
# [149] "Days of Inventory on Hand"
# [150] "Receivables Turnover"
# [151] "Capex per Share"
# [152] "Gross Profit Growth"
# [153] "EBIT Growth"
# [154] "Operating Income Growth"
# [155] "Net Income Growth"
# [156] "EPS Growth"
# [157] "EPS Diluted Growth"
# [158] "Weighted Average Shares Growth"
# [159] "Weighted Average Shares Diluted Growth"
# [160] "Dividends per Share Growth"
# [161] "Operating Cash Flow growth"
# [162] "Free Cash Flow growth"
# [163] "10Y Revenue Growth (per Share)"
# [164] "5Y Revenue Growth (per Share)"
# [165] "3Y Revenue Growth (per Share)"
# [166] "10Y Operating CF Growth (per Share)"
# [167] "5Y Operating CF Growth (per Share)"
# [168] "3Y Operating CF Growth (per Share)"
# [169] "10Y Net Income Growth (per Share)"
# [170] "5Y Net Income Growth (per Share)"
# [171] "3Y Net Income Growth (per Share)"
# [172] "10Y Shareholders Equity Growth (per Share)"
# [173] "5Y Shareholders Equity Growth (per Share)"
# [174] "3Y Shareholders Equity Growth (per Share)"
# [175] "10Y Dividend per Share Growth (per Share)"
# [176] "5Y Dividend per Share Growth (per Share)"
# [177] "3Y Dividend per Share Growth (per Share)"
# [178] "Receivables growth"
# [179] "Inventory Growth"
# [180] "Asset Growth"
# [181] "Book Value per Share Growth"
# [182] "Debt Growth"
# [183] "R&D Expense Growth"
# [184] "SG&A Expenses Growth"
# [185] "Payout Ratio"
# [186] "Interest Coverage"
# [187] "Net Profit Margin"
# [188] "Dividend Yield"
# [189] "PE ratio"
# [190] "PFCF ratio"
# [191] "POCF ratio"
# [192] "Price to Sales Ratio"
# [193] "Days Payables Outstanding"
# [194] "Free Cash Flow per Share"
# [195] "ROE"
# [196] "PTB ratio"
# [197] "PB ratio"
# [198] "Operating Cash Flow per Share"
# [199] "Cash per Share"

# %%
#Changing all names to lower case and replacing spaces with "_"
#Amending various features to make more compatible models
names(data) <- str_trim(names(data), side = "both")
names(data) <- str_to_lower(names(data), locale = "en")
names(data) <- str_replace_all(names(data), " ", "_")
names(data) <- str_replace_all(names(data), "-", "")
names(data) <- str_replace_all(names(data), "&", ".")
names(data) <- str_replace_all(names(data), "\\(", "")
names(data) <- str_replace_all(names(data), "\\)", "")
names(data) <- str_replace_all(names(data), "3y", "three_yr")
names(data) <- str_replace_all(names(data), "5y", "five_yr")
names(data) <- str_replace_all(names(data), "10y", "ten_yr")
names(data) <- str_replace_all(names(data), "\\\\", "")
names(data) <- str_replace_all(names(data), "////", "_")
names(data) <- str_replace_all(names(data), ",", "")
names(data) <- str_replace_all(names(data), "_._", "_")
names(data) <- str_replace_all(names(data), "/", "_")
names(data)
# Out:
#   [1] "stock"
#   [2] "nextyr_price_var"
#   [3] "class"
#   [4] "year"
#   [5] "sector"
#   [6] "revenue"
#   [7] "revenue_growth"
#   [8] "cost_of_revenue"
#   [9] "gross_profit"
#  [10] "r.d_expenses"
#  [11] "sg.a_expense"
#  [12] "operating_expenses"
#  [13] "operating_income"
#  [14] "interest_expense"
#  [15] "earnings_before_tax"
#  [16] "income_tax_expense"
#  [17] "net_income__noncontrolling_int"
#  [18] "net_income__discontinued_ops"
#  [19] "net_income"
#  [20] "preferred_dividends"
#  [21] "net_income_com"
#  [22] "eps"
#  [23] "eps_diluted"
#  [24] "weighted_average_shs_out"
#  [25] "weighted_average_shs_out_dil"
#  [26] "dividend_per_share"
#  [27] "gross_margin"
#  [28] "ebitda_margin"
#  [29] "ebit_margin"
#  [30] "profit_margin"
#  [31] "free_cash_flow_margin"
#  [32] "ebitda"
#  [33] "ebit"
#  [34] "consolidated_income"
#  [35] "earnings_before_tax_margin"
#  [36] "cash_and_cash_equivalents"
#  [37] "shortterm_investments"
#  [38] "cash_and_shortterm_investments"
#  [39] "receivables"
#  [40] "inventories"
#  [41] "total_current_assets"
#  [42] "property_plant_equipment_net"
#  [43] "goodwill_and_intangible_assets"
#  [44] "longterm_investments"
#  [45] "tax_assets"
#  [46] "total_noncurrent_assets"
#  [47] "total_assets"
#  [48] "payables"
#  [49] "shortterm_debt"
#  [50] "total_current_liabilities"
#  [51] "longterm_debt"
#  [52] "total_debt"
#  [53] "deferred_revenue"
#  [54] "tax_liabilities"
#  [55] "deposit_liabilities"
#  [56] "total_noncurrent_liabilities"
#  [57] "total_liabilities"
#  [58] "other_comprehensive_income"
#  [59] "retained_earnings_deficit"
#  [60] "total_shareholders_equity"
#  [61] "investments"
#  [62] "net_debt"
#  [63] "other_assets"
#  [64] "other_liabilities"
#  [65] "depreciation_amortization"
#  [66] "stockbased_compensation"
#  [67] "operating_cash_flow"
#  [68] "capital_expenditure"
#  [69] "acquisitions_and_disposals"
#  [70] "investment_purchases_and_sales"
#  [71] "investing_cash_flow"
#  [72] "issuance_repayment_of_debt"
#  [73] "issuance_buybacks_of_shares"
#  [74] "dividend_payments"
#  [75] "financing_cash_flow"
#  [76] "effect_of_forex_changes_on_cash"
#  [77] "net_cash_flow_change_in_cash"
#  [78] "free_cash_flow"
#  [79] "net_cash_marketcap"
#  [80] "pricecashflowratio"
#  [81] "priceearningstogrowthratio"
#  [82] "pricesalesratio"
#  [83] "enterprisevaluemultiple"
#  [84] "pricefairvalue"
#  [85] "ebitperrevenue"
#  [86] "ebtperebit"
#  [87] "niperebt"
#  [88] "grossprofitmargin"
#  [89] "operatingprofitmargin"
#  [90] "pretaxprofitmargin"
#  [91] "effectivetaxrate"
#  [92] "returnonassets"
#  [93] "returnoncapitalemployed"
#  [94] "payablesturnover"
#  [95] "inventoryturnover"
#  [96] "fixedassetturnover"
#  [97] "assetturnover"
#  [98] "currentratio"
#  [99] "quickratio"
# [100] "cashratio"
# [101] "daysofsalesoutstanding"
# [102] "daysofinventoryoutstanding"
# [103] "debtratio"
# [104] "debtequityratio"
# [105] "longtermdebttocapitalization"
# [106] "totaldebttocapitalization"
# [107] "cashflowtodebtratio"
# [108] "companyequitymultiplier"
# [109] "operatingcashflowsalesratio"
# [110] "freecashflowoperatingcashflowratio"
# [111] "shorttermcoverageratios"
# [112] "capitalexpenditurecoverageratios"
# [113] "dividendpaidandcapexcoverageratios"
# [114] "dividendpayoutratio"
# [115] "revenue_per_share"
# [116] "net_income_per_share"
# [117] "book_value_per_share"
# [118] "tangible_book_value_per_share"
# [119] "shareholders_equity_per_share"
# [120] "interest_debt_per_share"
# [121] "market_cap"
# [122] "enterprise_value"
# [123] "ev_to_sales"
# [124] "enterprise_value_over_ebitda"
# [125] "ev_to_operating_cash_flow"
# [126] "ev_to_free_cash_flow"
# [127] "earnings_yield"
# [128] "free_cash_flow_yield"
# [129] "net_debt_to_ebitda"
# [130] "current_ratio"
# [131] "income_quality"
# [132] "sg.a_to_revenue"
# [133] "r.d_to_revenue"
# [134] "intangibles_to_total_assets"
# [135] "capex_to_operating_cash_flow"
# [136] "capex_to_revenue"
# [137] "capex_to_depreciation"
# [138] "stockbased_compensation_to_revenue"
# [139] "graham_number"
# [140] "graham_netnet"
# [141] "working_capital"
# [142] "tangible_asset_value"
# [143] "net_current_asset_value"
# [144] "invested_capital"
# [145] "average_receivables"
# [146] "average_payables"
# [147] "average_inventory"
# [148] "days_sales_outstanding"
# [149] "days_of_inventory_on_hand"
# [150] "receivables_turnover"
# [151] "capex_per_share"
# [152] "gross_profit_growth"
# [153] "ebit_growth"
# [154] "operating_income_growth"
# [155] "net_income_growth"
# [156] "eps_growth"
# [157] "eps_diluted_growth"
# [158] "weighted_average_shares_growth"
# [159] "weighted_average_shares_diluted_growth"
# [160] "dividends_per_share_growth"
# [161] "operating_cash_flow_growth"
# [162] "free_cash_flow_growth"
# [163] "ten_yr_revenue_growth_per_share"
# [164] "five_yr_revenue_growth_per_share"
# [165] "three_yr_revenue_growth_per_share"
# [166] "ten_yr_operating_cf_growth_per_share"
# [167] "five_yr_operating_cf_growth_per_share"
# [168] "three_yr_operating_cf_growth_per_share"
# [169] "ten_yr_net_income_growth_per_share"
# [170] "five_yr_net_income_growth_per_share"
# [171] "three_yr_net_income_growth_per_share"
# [172] "ten_yr_shareholders_equity_growth_per_share"
# [173] "five_yr_shareholders_equity_growth_per_share"
# [174] "three_yr_shareholders_equity_growth_per_share"
# [175] "ten_yr_dividend_per_share_growth_per_share"
# [176] "five_yr_dividend_per_share_growth_per_share"
# [177] "three_yr_dividend_per_share_growth_per_share"
# [178] "receivables_growth"
# [179] "inventory_growth"
# [180] "asset_growth"
# [181] "book_value_per_share_growth"
# [182] "debt_growth"
# [183] "r.d_expense_growth"
# [184] "sg.a_expenses_growth"
# [185] "payout_ratio"
# [186] "interest_coverage"
# [187] "net_profit_margin"
# [188] "dividend_yield"
# [189] "pe_ratio"
# [190] "pfcf_ratio"
# [191] "pocf_ratio"
# [192] "price_to_sales_ratio"
# [193] "days_payables_outstanding"
# [194] "free_cash_flow_per_share"
# [195] "roe"
# [196] "ptb_ratio"
# [197] "pb_ratio"
# [198] "operating_cash_flow_per_share"
# [199] "cash_per_share"

# %% [markdown]
# ### Categorical Encoding
# Are there any categorical variables in your data? If so, transform them so that they can be used to train a machine learning algorithm.

# %%
#Categorical Encoding
data[, sector := as.factor(sector)]
data[, sector_num := as.numeric(sector)]

#Reordering data to put "sector" with "sector_num"
data <- data %>%
  dplyr::select('stock','nextyr_price_var','class','year','sector','sector_num', everything())

# %% [markdown]
# ### Missing Data
# If missing data is present (ie, NaN values), what is the best way to deal with it? Should values be imputed (and if so, how)? Or should they simply be filled? How will each option will affect the ultimate outcome of your model? Design and implement a solution.

# %%
na <- apply(is.na(data),2,sum)
#print(na)
max(na)
#sort(na, decreasing = TRUE)
head(sort(na, decreasing = TRUE), n=25)
summary(na)
# Out:
# [1] 10744
#                      shorttermcoverageratios
#                                        10744
#  ten_yr_shareholders_equity_growth_per_share
#                                         9680
#              ten_yr_revenue_growth_per_share
#                                         9532
#           ten_yr_net_income_growth_per_share
#                                         9532
#         ten_yr_operating_cf_growth_per_share
#                                         9478
#   ten_yr_dividend_per_share_growth_per_share
#                                         9177
#                   priceearningstogrowthratio
#                                         9079
#                          dividendpayoutratio
#                                         9079
#                                     niperebt
#                                         8595
#                             effectivetaxrate
#                                         8595
#                                   ebtperebit
#                                         8007
#                           net_debt_to_ebitda
#                                         7715
#                           pricecashflowratio
#                                         7064
#                      enterprisevaluemultiple
#                                         6944
#                                     net_debt
#                                         6859
#                                 other_assets
#                                         6756
# five_yr_shareholders_equity_growth_per_share
#                                         6610
#           freecashflowoperatingcashflowratio
#                                         6588
#                               returnonassets
#                                         6535
#                                current_ratio
#                                         6516
#                              working_capital
#                                         6510
#                      returnoncapitalemployed
#                                         6509
#             five_yr_revenue_growth_per_share
#                                         6401
#          five_yr_net_income_growth_per_share
#                                         6401
#        five_yr_operating_cf_growth_per_share
#                                         6364
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       0    1654    2264    2869    3087   10744

# %%
#Checking how many rows are complete
sum(complete.cases(data))

#Checking for NA across rows
data$na <- rowSums(is.na(data))
max(data$na)
head(sort(data$na, decreasing = TRUE),n = 20)
summary(data$na)
# Out:
# [1] 3454
# [1] 179
#  [1] 179 179 179 179 179 179 179 179 179 179 179 179 179 179 179 179 179 179 179
# [20] 179
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    2.00   10.00   25.99   22.00  179.00

# %%
#Found that 50 was a good cut off for dropping rows
drop <- data %>% 
  filter(na >= 50)
dim(drop)

data <- data %>%
  filter(na <= 50)

data <- dplyr::select(data, -c(na))

#Re-checking the NAs across columns
na <- apply(is.na(data),2,sum)
max(na)
# NOTE: The following code has been commmented out due to the length of its output.
#print(na)
#sort(na, decreasing = TRUE)
head(sort(na, decreasing = TRUE), n=25)
# Out:
# [1] 2469  201
# [1] 8393
#                      shorttermcoverageratios
#                                         8393
#  ten_yr_shareholders_equity_growth_per_share
#                                         7230
#              ten_yr_revenue_growth_per_share
#                                         7076
#           ten_yr_net_income_growth_per_share
#                                         7076
#         ten_yr_operating_cf_growth_per_share
#                                         7029
#   ten_yr_dividend_per_share_growth_per_share
#                                         6728
#                   priceearningstogrowthratio
#                                         6653
#                          dividendpayoutratio
#                                         6653
#                                     niperebt
#                                         6475
#                             effectivetaxrate
#                                         6475
#                                   ebtperebit
#                                         5666
#                           net_debt_to_ebitda
#                                         5290
#                                     net_debt
#                                         5271
#                                 other_assets
#                                         5182
#                           pricecashflowratio
#                                         4639
#           freecashflowoperatingcashflowratio
#                                         4578
#                      enterprisevaluemultiple
#                                         4570
#                          cashflowtodebtratio
#                                         4222
# five_yr_shareholders_equity_growth_per_share
#                                         4171
#                                current_ratio
#                                         4150
#                               returnonassets
#                                         4149
#                 total_noncurrent_liabilities
#                                         4146
#                      returnoncapitalemployed
#                                         4145
#                              working_capital
#                                         4145
#                      total_noncurrent_assets
#                                         4136

# %%
#Keeping only columns with less than ~15 percent missing
perc <- apply(data,2,Perc_Missing)
max(perc)
# NOTE: The following code has been commmented out due to the length of its output.
#print(perc)
#sort(perc, decreasing = TRUE)
head(sort(perc, decreasing = TRUE), n=25)

#Choosing to only keep variables with less than 15% missing data
data <- data[, which(apply(data,2,Perc_Missing) < 15.0)]
# Out:
# [1] 42.78868
#                      shorttermcoverageratios
#                                     42.78868
#  ten_yr_shareholders_equity_growth_per_share
#                                     36.85955
#              ten_yr_revenue_growth_per_share
#                                     36.07443
#           ten_yr_net_income_growth_per_share
#                                     36.07443
#         ten_yr_operating_cf_growth_per_share
#                                     35.83482
#   ten_yr_dividend_per_share_growth_per_share
#                                     34.30028
#                   priceearningstogrowthratio
#                                     33.91792
#                          dividendpayoutratio
#                                     33.91792
#                                     niperebt
#                                     33.01045
#                             effectivetaxrate
#                                     33.01045
#                                   ebtperebit
#                                     28.88606
#                           net_debt_to_ebitda
#                                     26.96916
#                                     net_debt
#                                     26.87229
#                                 other_assets
#                                     26.41856
#                           pricecashflowratio
#                                     23.65027
#           freecashflowoperatingcashflowratio
#                                     23.33928
#                      enterprisevaluemultiple
#                                     23.29850
#                          cashflowtodebtratio
#                                     21.52434
# five_yr_shareholders_equity_growth_per_share
#                                     21.26434
#                                current_ratio
#                                     21.15728
#                               returnonassets
#                                     21.15218
#                 total_noncurrent_liabilities
#                                     21.13689
#                      returnoncapitalemployed
#                                     21.13179
#                              working_capital
#                                     21.13179
#                      total_noncurrent_assets
#                                     21.08590

# %%
missing <- select(data, -c('stock','nextyr_price_var','class','year','sector','sector_num'))

imputedm <- impute(missing, method = "median/mode")

# %%
summary(imputedm)
# Out:
#     revenue           revenue_growth     cost_of_revenue
#  Min.   :-6.276e+08   Min.   :   -6.87   Min.   :-2.987e+09
#  1st Qu.: 6.695e+07   1st Qu.:   -0.01   1st Qu.: 3.084e+06
#  Median : 4.685e+08   Median :    0.06   Median : 1.510e+08
#  Mean   : 4.808e+09   Mean   :    3.64   Mean   : 2.900e+09
#  3rd Qu.: 2.336e+09   3rd Qu.:    0.18   3rd Qu.: 1.150e+09
#  Max.   : 5.003e+11   Max.   :42138.66   Max.   : 3.771e+11
#   gross_profit         r.d_expenses         sg.a_expense
#  Min.   :-1.281e+10   Min.   :-1.098e+08   Min.   :-1.402e+08
#  1st Qu.: 3.400e+07   1st Qu.: 0.000e+00   1st Qu.: 1.815e+07
#  Median : 2.075e+08   Median : 0.000e+00   Median : 8.152e+07
#  Mean   : 1.905e+09   Mean   : 9.805e+07   Mean   : 8.504e+08
#  3rd Qu.: 9.018e+08   3rd Qu.: 1.202e+07   3rd Qu.: 3.649e+08
#  Max.   : 1.269e+11   Max.   : 2.884e+10   Max.   : 1.065e+11
#  operating_expenses   operating_income     interest_expense
#  Min.   :-5.496e+09   Min.   :-1.934e+10   Min.   :-1.711e+09
#  1st Qu.: 3.693e+07   1st Qu.:-4.520e+06   1st Qu.: 0.000e+00
#  Median : 1.588e+08   Median : 3.842e+07   Median : 3.671e+06
#  Mean   : 1.344e+09   Mean   : 5.667e+08   Mean   : 9.047e+07
#  3rd Qu.: 6.175e+08   3rd Qu.: 2.611e+08   3rd Qu.: 4.868e+07
#  Max.   : 1.065e+11   Max.   : 7.123e+10   Max.   : 1.845e+10
#  earnings_before_tax  income_tax_expense   net_income__noncontrolling_int
#  Min.   :-2.177e+10   Min.   :-1.471e+10   Min.   :-1.587e+09
#  1st Qu.:-8.818e+06   1st Qu.: 0.000e+00   1st Qu.: 0.000e+00
#  Median : 2.523e+07   Median : 3.585e+06   Median : 0.000e+00
#  Mean   : 4.880e+08   Mean   : 1.272e+08   Mean   : 1.338e+07
#  3rd Qu.: 2.027e+08   3rd Qu.: 4.494e+07   3rd Qu.: 0.000e+00
#  Max.   : 7.290e+10   Max.   : 2.939e+10   Max.   : 6.431e+09
#  net_income__discontinued_ops   net_income         preferred_dividends
#  Min.   :-1.591e+10           Min.   :-2.236e+10   Min.   :-161000000
#  1st Qu.: 0.000e+00           1st Qu.:-9.243e+06   1st Qu.:         0
#  Median : 0.000e+00           Median : 1.881e+07   Median :         0
#  Mean   :-2.734e+06           Mean   : 3.608e+08   Mean   :   4663189
#  3rd Qu.: 0.000e+00           3rd Qu.: 1.568e+08   3rd Qu.:         0
#  Max.   : 8.368e+09           Max.   : 5.953e+10   Max.   :2741588000
#  net_income_com            eps              eps_diluted
#  Min.   :-2.280e+10   Min.   :-101870898   Min.   :-101870898
#  1st Qu.:-1.003e+07   1st Qu.:         0   1st Qu.:         0
#  Median : 1.807e+07   Median :         1   Median :         1
#  Mean   : 3.561e+08   Mean   :    -11286   Mean   :    -11374
#  3rd Qu.: 1.540e+08   3rd Qu.:         2   3rd Qu.:         2
#  Max.   : 5.953e+10   Max.   :   8028004   Max.   :   6624003
#  weighted_average_shs_out weighted_average_shs_out_dil dividend_per_share
#  Min.   :0.000e+00        Min.   :0.000e+00            Min.   :    0.000
#  1st Qu.:1.762e+07        1st Qu.:1.627e+07            1st Qu.:    0.000
#  Median :4.397e+07        Median :4.237e+07            Median :    0.000
#  Mean   :2.602e+08        Mean   :2.634e+08            Mean   :    1.225
#  3rd Qu.:1.178e+08        3rd Qu.:1.147e+08            3rd Qu.:    0.720
#  Max.   :1.113e+11        Max.   :1.113e+11            Max.   :10100.664
#   gross_margin      ebitda_margin         ebit_margin
#  Min.   :-74.3191   Min.   :-24207.000   Min.   :-24242.000
#  1st Qu.:  0.2512   1st Qu.:     0.027   1st Qu.:     0.000
#  Median :  0.4547   Median :     0.129   Median :     0.082
#  Mean   :  0.4833   Mean   :    -8.395   Mean   :    -7.558
#  3rd Qu.:  0.7803   3rd Qu.:     0.290   3rd Qu.:     0.212
#  Max.   :  4.2531   Max.   :  1060.404   Max.   :  1056.466
#  profit_margin        free_cash_flow_margin     ebitda
#  Min.   :-24414.000   Min.   :-23256.000    Min.   :-1.648e+10
#  1st Qu.:    -0.033   1st Qu.:    -0.036    1st Qu.: 1.594e+06
#  Median :     0.043   Median :     0.045    Median : 7.164e+07
#  Mean   :    -8.820   Mean   :    -6.336    Mean   : 8.644e+08
#  3rd Qu.:     0.126   3rd Qu.:     0.152    3rd Qu.: 4.085e+08
#  Max.   :   940.041   Max.   :   689.830    Max.   : 8.381e+10
#       ebit            consolidated_income  earnings_before_tax_margin
#  Min.   :-1.871e+10   Min.   :-2.244e+10   Min.   :-24202.000
#  1st Qu.:-3.914e+06   1st Qu.:-9.226e+06   1st Qu.:    -0.026
#  Median : 3.918e+07   Median : 1.999e+07   Median :     0.060
#  Mean   : 5.805e+08   Mean   : 3.743e+08   Mean   :    -7.638
#  3rd Qu.: 2.680e+08   3rd Qu.: 1.640e+08   3rd Qu.:     0.173
#  Max.   : 7.290e+10   Max.   : 5.953e+10   Max.   :  1056.466
#  cash_and_cash_equivalents shortterm_investments cash_and_shortterm_investments
#  Min.   :0.000e+00         Min.   :0.000e+00     Min.   :0.000e+00
#  1st Qu.:1.872e+07         1st Qu.:0.000e+00     1st Qu.:2.429e+07
#  Median :7.444e+07         Median :0.000e+00     Median :9.408e+07
#  Mean   :1.552e+09         Mean   :1.227e+09     Mean   :2.564e+09
#  3rd Qu.:2.970e+08         3rd Qu.:1.301e+07     3rd Qu.:3.401e+08
#  Max.   :5.123e+11         Max.   :8.000e+11     Max.   :9.854e+11
#   receivables         inventories        total_current_assets
#  Min.   :0.000e+00   Min.   :0.000e+00   Min.   :0.000e+00
#  1st Qu.:2.190e+06   1st Qu.:0.000e+00   1st Qu.:7.437e+07
#  Median :4.465e+07   Median :1.552e+06   Median :2.788e+08
#  Mean   :8.629e+08   Mean   :4.077e+08   Mean   :4.847e+09
#  3rd Qu.:2.866e+08   3rd Qu.:1.036e+08   3rd Qu.:1.082e+09
#  Max.   :1.624e+11   Max.   :9.120e+11   Max.   :1.181e+12
#  property_plant_equipment_net goodwill_and_intangible_assets
#  Min.   :0.000e+00            Min.   :0.000e+00
#  1st Qu.:9.163e+06            1st Qu.:0.000e+00
#  Median :9.582e+07            Median :3.841e+07
#  Mean   :2.447e+09            Mean   :1.654e+09
#  3rd Qu.:8.537e+08            3rd Qu.:4.847e+08
#  Max.   :2.822e+11            Max.   :2.931e+11
#  longterm_investments   tax_assets         total_assets
#  Min.   :-8.000e+07   Min.   :0.000e+00   Min.   :2.809e+04
#  1st Qu.: 0.000e+00   1st Qu.:0.000e+00   1st Qu.:2.112e+08
#  Median : 0.000e+00   Median :0.000e+00   Median :1.172e+09
#  Mean   : 2.847e+09   Mean   :1.453e+08   Mean   :1.808e+10
#  3rd Qu.: 4.600e+07   3rd Qu.:1.565e+07   3rd Qu.:5.092e+09
#  Max.   : 9.970e+11   Max.   :4.262e+10   Max.   :2.634e+12
#     payables          shortterm_debt       total_current_liabilities
#  Min.   :-2.059e+10   Min.   :-1.375e+09   Min.   :-2.108e+10
#  1st Qu.: 2.831e+06   1st Qu.: 0.000e+00   1st Qu.: 3.164e+07
#  Median : 2.642e+07   Median : 1.535e+06   Median : 1.787e+08
#  Mean   : 8.393e+08   Mean   : 5.160e+08   Mean   : 7.118e+09
#  3rd Qu.: 1.798e+08   3rd Qu.: 3.250e+07   3rd Qu.: 9.091e+08
#  Max.   : 2.136e+11   Max.   : 2.192e+11   Max.   : 2.095e+12
#  longterm_debt          total_debt         deferred_revenue
#  Min.   :-8.446e+09   Min.   :-9.290e+09   Min.   :-2.364e+07
#  1st Qu.: 1.225e+06   1st Qu.: 5.941e+06   1st Qu.: 0.000e+00
#  Median : 1.395e+08   Median : 2.065e+08   Median : 0.000e+00
#  Mean   : 2.686e+09   Mean   : 4.126e+09   Mean   : 6.884e+11
#  3rd Qu.: 1.117e+09   3rd Qu.: 1.465e+09   3rd Qu.: 4.280e+06
#  Max.   : 7.330e+11   Max.   : 1.014e+12   Max.   : 1.350e+16
#  tax_liabilities      deposit_liabilities total_liabilities
#  Min.   :-1.784e+09   Min.   :0.000e+00   Min.   :-7.872e+09
#  1st Qu.: 0.000e+00   1st Qu.:0.000e+00   1st Qu.: 7.375e+07
#  Median : 3.410e+05   Median :0.000e+00   Median : 6.427e+08
#  Mean   : 2.521e+11   Mean   :5.069e+09   Mean   : 1.456e+10
#  3rd Qu.: 5.094e+07   3rd Qu.:0.000e+00   3rd Qu.: 3.314e+09
#  Max.   : 4.938e+15   Max.   :1.471e+12   Max.   : 2.434e+12
#  other_comprehensive_income retained_earnings_deficit total_shareholders_equity
#  Min.   :-9.478e+10         Min.   :-2.800e+11        Min.   :-1.324e+10
#  1st Qu.:-2.135e+07         1st Qu.:-1.173e+08        1st Qu.: 7.354e+07
#  Median :-2.538e+05         Median : 2.310e+07        Median : 3.598e+08
#  Mean   : 8.695e+10         Mean   : 1.979e+09        Mean   : 3.358e+09
#  3rd Qu.: 0.000e+00         3rd Qu.: 5.298e+08        3rd Qu.: 1.535e+09
#  Max.   : 1.709e+15         Max.   : 4.217e+11        Max.   : 2.671e+11
#   investments         other_liabilities    depreciation_amortization
#  Min.   :-1.614e+09   Min.   :-9.923e+10   Min.   :-8.336e+07
#  1st Qu.: 0.000e+00   1st Qu.: 9.570e+06   1st Qu.: 2.048e+06
#  Median : 1.373e+07   Median : 6.638e+07   Median : 2.038e+07
#  Mean   : 9.140e+09   Mean   : 5.827e+09   Mean   : 3.248e+08
#  3rd Qu.: 3.918e+08   3rd Qu.: 4.094e+08   3rd Qu.: 1.223e+08
#  Max.   : 2.080e+12   Max.   : 1.866e+12   Max.   : 7.510e+11
#  stockbased_compensation operating_cash_flow  capital_expenditure
#  Min.   :-137000000      Min.   :-1.127e+11   Min.   :-9.662e+10
#  1st Qu.:    499000      1st Qu.: 1.290e+06   1st Qu.:-1.254e+08
#  Median :   3818000      Median : 5.989e+07   Median :-1.690e+07
#  Mean   :  29262341      Mean   : 8.270e+08   Mean   :-3.468e+08
#  3rd Qu.:  14887500      3rd Qu.: 3.376e+08   3rd Qu.:-1.363e+06
#  Max.   :9353000000      Max.   : 9.600e+11   Max.   : 5.823e+09
#  acquisitions_and_disposals investment_purchases_and_sales investing_cash_flow
#  Min.   :-5.100e+10         Min.   :-1.930e+11             Min.   :-1.980e+11
#  1st Qu.:-1.168e+07         1st Qu.:-1.053e+07             1st Qu.:-2.867e+08
#  Median : 0.000e+00         Median : 0.000e+00             Median :-4.892e+07
#  Mean   :-1.098e+08         Mean   :-1.699e+08             Mean   :-6.428e+08
#  3rd Qu.: 0.000e+00         3rd Qu.: 0.000e+00             3rd Qu.:-1.924e+06
#  Max.   : 6.987e+10         Max.   : 1.499e+11             Max.   : 1.446e+11
#  issuance_repayment_of_debt issuance_buybacks_of_shares dividend_payments
#  Min.   :-8.488e+10         Min.   :-7.207e+10          Min.   :-1.603e+10
#  1st Qu.:-8.544e+06         1st Qu.:-8.502e+06          1st Qu.:-5.040e+07
#  Median : 0.000e+00         Median : 0.000e+00          Median : 0.000e+00
#  Mean   : 1.315e+08         Mean   :-1.148e+08          Mean   :-1.828e+08
#  3rd Qu.: 5.176e+07         3rd Qu.: 6.307e+06          3rd Qu.: 0.000e+00
#  Max.   : 6.268e+10         Max.   : 1.444e+11          Max.   : 0.000e+00
#  financing_cash_flow  effect_of_forex_changes_on_cash
#  Min.   :-1.875e+11   Min.   :-4.300e+10
#  1st Qu.:-7.733e+07   1st Qu.:-2.566e+05
#  Median : 0.000e+00   Median : 0.000e+00
#  Mean   :-5.683e+07   Mean   :-4.703e+06
#  3rd Qu.: 5.774e+07   3rd Qu.: 0.000e+00
#  Max.   : 2.260e+11   Max.   : 9.993e+09
#  net_cash_flow_change_in_cash free_cash_flow       net_cash_marketcap
#  Min.   :-1.525e+11           Min.   :-1.042e+11   Min.   :-4943.553
#  1st Qu.:-1.679e+07           1st Qu.:-1.006e+07   1st Qu.:   -0.402
#  Median : 7.233e+05           Median : 1.886e+07   Median :   -0.064
#  Mean   : 7.969e+07           Mean   : 4.370e+08   Mean   :   -0.861
#  3rd Qu.: 2.940e+07           3rd Qu.: 1.763e+08   3rd Qu.:    0.098
#  Max.   : 4.050e+11           Max.   : 9.415e+10   Max.   :  501.780
#  pricesalesratio    pricefairvalue     ebitperrevenue       grossprofitmargin
#  Min.   :     0.0   Min.   :       0   Min.   :-24242.000   Min.   :-223.4828
#  1st Qu.:     0.7   1st Qu.:       1   1st Qu.:     0.002   1st Qu.:   0.2895
#  Median :     1.8   Median :       2   Median :     0.090   Median :   0.4772
#  Mean   :    74.5   Mean   :   10538   Mean   :    -7.558   Mean   :   0.4907
#  3rd Qu.:     3.7   3rd Qu.:       3   3rd Qu.:     0.212   3rd Qu.:   0.7795
#  Max.   :377315.8   Max.   :94309693   Max.   :  1056.466   Max.   :  34.8107
#  operatingprofitmargin pretaxprofitmargin   payablesturnover
#  Min.   :1             Min.   :-24577.000   Min.   : -41.096
#  1st Qu.:1             1st Qu.:    -0.001   1st Qu.:   1.121
#  Median :1             Median :     0.087   Median :   2.612
#  Mean   :1             Mean   :    -7.842   Mean   :   5.755
#  3rd Qu.:1             3rd Qu.:     0.202   3rd Qu.:   4.581
#  Max.   :1             Max.   :   198.684   Max.   :8650.316
#  inventoryturnover  fixedassetturnover assetturnover       currentratio
#  Min.   :    0.00   Min.   :  -383.6   Min.   : -0.1251   Min.   :  -1.439
#  1st Qu.:    0.00   1st Qu.:     1.3   1st Qu.:  0.1245   1st Qu.:   0.989
#  Median :    3.21   Median :     4.1   Median :  0.4832   Median :   1.757
#  Mean   :   31.52   Mean   :    87.2   Mean   :  0.6962   Mean   :   4.045
#  3rd Qu.:   10.38   3rd Qu.:    10.1   3rd Qu.:  0.9645   3rd Qu.:   3.072
#  Max.   :95827.71   Max.   :446511.9   Max.   :134.3659   Max.   :5719.167
#    quickratio         cashratio         daysofsalesoutstanding
#  Min.   :     0.0   Min.   :     0.00   Min.   :-5182867
#  1st Qu.:     0.7   1st Qu.:     0.15   1st Qu.:     -70
#  Median :     1.2   Median :     0.46   Median :      -6
#  Mean   :    67.1   Mean   :    18.39   Mean   :    -358
#  3rd Qu.:     2.3   3rd Qu.:     1.17   3rd Qu.:       0
#  Max.   :486211.3   Max.   :164465.79   Max.   :     976
#  daysofinventoryoutstanding   debtratio        debtequityratio
#  Min.   :-165044.9          Min.   : -0.4536   Min.   :-2586.4359
#  1st Qu.:     10.7          1st Qu.:  0.0335   1st Qu.:    0.0105
#  Median :     45.5          Median :  0.1958   Median :    0.4370
#  Mean   :    191.2          Mean   :  0.2728   Mean   :    0.5878
#  3rd Qu.:     72.6          3rd Qu.:  0.3891   3rd Qu.:    1.0788
#  Max.   :1504680.2          Max.   :133.6571   Max.   : 2131.5128
#  longtermdebttocapitalization totaldebttocapitalization companyequitymultiplier
#  Min.   :-1.93098             Min.   :  -2.7361         Min.   :      0
#  1st Qu.: 0.00039             1st Qu.:   0.0271         1st Qu.:      2
#  Median : 0.25956             Median :   0.3062         Median :      2
#  Mean   : 0.35133             Mean   :   0.4429         Mean   :   1178
#  3rd Qu.: 0.49131             3rd Qu.:   0.5307         3rd Qu.:      4
#  Max.   :91.03812             Max.   :1040.0474         Max.   :8740761
#  operatingcashflowsalesratio capitalexpenditurecoverageratios
#  Min.   :-27566.00           Min.   :-46880.00
#  1st Qu.:     0.03           1st Qu.:     0.48
#  Median :     0.12           Median :     2.00
#  Mean   :    -3.33           Mean   :   -12.11
#  3rd Qu.:     0.26           3rd Qu.:     5.02
#  Max.   : 57805.09           Max.   :313315.67
#  dividendpaidandcapexcoverageratios revenue_per_share   net_income_per_share
#  Min.   :-46880.00                  Min.   :       -3   Min.   :-12724878
#  1st Qu.:     0.35                  1st Qu.:        4   1st Qu.:        0
#  Median :     1.40                  Median :       11   Median :        1
#  Mean   :   -32.54                  Mean   :   151097   Mean   :    12665
#  3rd Qu.:     2.82                  3rd Qu.:       32   3rd Qu.:        2
#  Max.   : 64384.91                  Max.   :226232495   Max.   : 29790472
#  book_value_per_share tangible_book_value_per_share
#  Min.   :  -642647    Min.   :0.000e+00
#  1st Qu.:        4    1st Qu.:7.000e+00
#  Median :       10    Median :2.000e+01
#  Mean   :    57233    Mean   :1.090e+05
#  3rd Qu.:       20    3rd Qu.:5.400e+01
#  Max.   :616362319    Max.   :1.095e+09
#  shareholders_equity_per_share interest_debt_per_share   market_cap
#  Min.   :  -660561             Min.   :      -20       Min.   :0.000e+00
#  1st Qu.:        4             1st Qu.:        0       1st Qu.:2.166e+08
#  Median :       11             Median :        6       Median :9.249e+08
#  Mean   :   199672             Mean   :   312808       Mean   :2.959e+10
#  3rd Qu.:       22             3rd Qu.:       19       3rd Qu.:3.626e+09
#  Max.   :258351242             Max.   :419924841       Max.   :9.619e+13
#  enterprise_value      ev_to_sales        enterprise_value_over_ebitda
#  Min.   :-1.488e+11   Min.   : -4324.81   Min.   :    0.00
#  1st Qu.: 2.957e+08   1st Qu.:     1.09   1st Qu.:    5.11
#  Median : 1.182e+09   Median :     2.33   Median :    9.95
#  Mean   : 7.497e+09   Mean   :    46.49   Mean   :   20.07
#  3rd Qu.: 3.897e+09   3rd Qu.:     4.82   3rd Qu.:   14.37
#  Max.   : 1.146e+12   Max.   :185096.30   Max.   :35296.20
#  ev_to_operating_cash_flow ev_to_free_cash_flow earnings_yield
#  Min.   :-94684.2          Min.   :-467933.3    Min.   :-9992.020
#  1st Qu.:     5.6          1st Qu.:     -2.7    1st Qu.:   -0.044
#  Median :    12.1          Median :     12.7    Median :    0.032
#  Mean   :    36.8          Mean   :    -14.7    Mean   :    0.885
#  3rd Qu.:    18.5          3rd Qu.:     23.0    3rd Qu.:    0.060
#  Max.   :512579.0          Max.   :  84994.9    Max.   :12673.441
#  free_cash_flow_yield income_quality      sg.a_to_revenue
#  Min.   :-25896.708   Min.   :-2719.500   Min.   :  -58.798
#  1st Qu.:    -0.036   1st Qu.:    0.388   1st Qu.:    0.098
#  Median :     0.034   Median :    1.198   Median :    0.227
#  Mean   :    -1.661   Mean   :    2.743   Mean   :    3.545
#  3rd Qu.:     0.071   3rd Qu.:    2.041   3rd Qu.:    0.465
#  Max.   :   293.818   Max.   :17675.500   Max.   :15246.000
#  r.d_to_revenue      intangibles_to_total_assets capex_to_operating_cash_flow
#  Min.   :   -0.732   Min.   :0.0000              Min.   :    0.000
#  1st Qu.:    0.000   1st Qu.:0.0000              1st Qu.:    0.000
#  Median :    0.000   Median :0.0445              Median :    0.177
#  Mean   :    4.481   Mean   :0.1557              Mean   :    1.396
#  3rd Qu.:    0.041   3rd Qu.:0.2556              3rd Qu.:    0.533
#  Max.   :12991.000   Max.   :0.9953              Max.   :11850.172
#  capex_to_revenue    capex_to_depreciation stockbased_compensation_to_revenue
#  Min.   :-4310.000   Min.   :-28088.98     Min.   :  -5.768
#  1st Qu.:    0.011   1st Qu.:    -1.48     1st Qu.:   0.002
#  Median :    0.032   Median :    -0.82     Median :   0.007
#  Mean   :    0.125   Mean   :    -5.46     Mean   :   1.087
#  3rd Qu.:    0.085   3rd Qu.:    -0.38     3rd Qu.:   0.024
#  Max.   :  773.667   Max.   : 35298.33     Max.   :3700.000
#  graham_number     graham_netnet       tangible_asset_value
#  Min.   :      0   Min.   :-5474.441   Min.   :-5.852e+09
#  1st Qu.:      0   1st Qu.:   -0.823   1st Qu.: 1.706e+08
#  Median :     12   Median :   -0.158   Median : 9.074e+08
#  Mean   :    642   Mean   :   -1.530   Mean   : 1.620e+10
#  3rd Qu.:     25   3rd Qu.:    0.085   3rd Qu.: 3.994e+09
#  Max.   :8851966   Max.   :  283.039   Max.   : 2.568e+12
#  net_current_asset_value invested_capital     average_receivables
#  Min.   :-1.378e+12      Min.   :-8.263e+15   Min.   :0.000e+00
#  1st Qu.:-1.456e+09      1st Qu.: 9.654e+07   1st Qu.:2.517e+06
#  Median :-9.867e+07      Median : 8.677e+08   Median :4.370e+07
#  Mean   :-7.317e+09      Mean   :-4.036e+11   Mean   :8.525e+08
#  3rd Qu.: 2.552e+07      3rd Qu.: 4.448e+09   3rd Qu.:2.784e+08
#  Max.   : 8.051e+10      Max.   : 3.053e+12   Max.   :1.614e+11
#  average_payables     average_inventory   days_sales_outstanding
#  Min.   :-2.037e+10   Min.   :0.000e+00   Min.   :-165044.9
#  1st Qu.: 2.951e+06   1st Qu.:0.000e+00   1st Qu.:     10.7
#  Median : 2.607e+07   Median :1.664e+06   Median :     45.5
#  Mean   : 9.480e+08   Mean   :3.786e+08   Mean   :    191.2
#  3rd Qu.: 1.757e+08   3rd Qu.:9.900e+07   3rd Qu.:     72.6
#  Max.   : 7.124e+11   Max.   :4.560e+11   Max.   :1504680.2
#  days_of_inventory_on_hand receivables_turnover capex_per_share
#  Min.   :-5182867          Min.   :   -27.99    Min.   :-73354000
#  1st Qu.:     -70          1st Qu.:     2.78    1st Qu.:       -2
#  Median :      -6          Median :     5.98    Median :        0
#  Mean   :    -358          Mean   :    45.66    Mean   :   -18885
#  3rd Qu.:       0          3rd Qu.:     9.85    3rd Qu.:        0
#  Max.   :     976          Max.   :164428.50    Max.   :   736000
#  gross_profit_growth  ebit_growth         operating_income_growth
#  Min.   :  -224.5    Min.   :-16888.000   Min.   :-18881.000
#  1st Qu.:     0.0    1st Qu.:    -0.289   1st Qu.:    -0.262
#  Median :     0.1    Median :     0.060   Median :     0.058
#  Mean   :    19.6    Mean   :     0.824   Mean   :     0.438
#  3rd Qu.:     0.2    3rd Qu.:     0.418   3rd Qu.:     0.362
#  Max.   :336767.8    Max.   : 20598.429   Max.   : 13545.339
#  net_income_growth     eps_growth        eps_diluted_growth
#  Min.   :-33777.00   Min.   :-2125.000   Min.   :   -2125
#  1st Qu.:    -0.41   1st Qu.:   -0.311   1st Qu.:       0
#  Median :     0.06   Median :    0.098   Median :       0
#  Mean   :    -2.24   Mean   :    0.241   Mean   :    2023
#  3rd Qu.:     0.53   3rd Qu.:    0.566   3rd Qu.:       1
#  Max.   :  3159.00   Max.   : 4378.049   Max.   :39679767
#  weighted_average_shares_growth weighted_average_shares_diluted_growth
#  Min.   :    -1.00              Min.   :     -1
#  1st Qu.:     0.00              1st Qu.:      0
#  Median :     0.01              Median :      0
#  Mean   :    12.98              Mean   :    175
#  3rd Qu.:     0.08              3rd Qu.:      0
#  Max.   :223089.50              Max.   :3378329
#  dividends_per_share_growth operating_cash_flow_growth free_cash_flow_growth
#  Min.   : -1.0000           Min.   :-5831.500          Min.   :-83431.43
#  1st Qu.:  0.0000           1st Qu.:   -0.275          1st Qu.:    -0.47
#  Median :  0.0000           Median :    0.047          Median :     0.03
#  Mean   :  0.1581           Mean   :   -0.431          Mean   :    -3.54
#  3rd Qu.:  0.0411           3rd Qu.:    0.406          3rd Qu.:     0.59
#  Max.   :372.5714           Max.   : 5496.639          Max.   :  8030.33
#  three_yr_revenue_growth_per_share three_yr_operating_cf_growth_per_share
#  Min.   :-1.00000                  Min.   :-1.00000
#  1st Qu.:-0.02125                  1st Qu.: 0.00000
#  Median : 0.03300                  Median : 0.00000
#  Mean   : 0.03995                  Mean   : 0.05772
#  3rd Qu.: 0.09440                  3rd Qu.: 0.10690
#  Max.   :43.91950                  Max.   : 9.69610
#  three_yr_net_income_growth_per_share
#  Min.   :-1.00000
#  1st Qu.: 0.00000
#  Median : 0.00000
#  Mean   : 0.06495
#  3rd Qu.: 0.09135
#  Max.   :17.02820
#  three_yr_shareholders_equity_growth_per_share
#  Min.   :-0.98100
#  1st Qu.:-0.01580
#  Median : 0.02660
#  Mean   : 0.04538
#  3rd Qu.: 0.08890
#  Max.   :20.03670
#  three_yr_dividend_per_share_growth_per_share receivables_growth
#  Min.   :-1.00000                             Min.   :   -1.000
#  1st Qu.: 0.00000                             1st Qu.:   -0.047
#  Median : 0.00000                             Median :    0.010
#  Mean   : 0.01139                             Mean   :    2.041
#  3rd Qu.: 0.02630                             3rd Qu.:    0.199
#  Max.   : 5.40050                             Max.   :14414.584
#  inventory_growth     asset_growth      book_value_per_share_growth
#  Min.   : -1.00000   Min.   :  -1.000   Min.   :-3963.131
#  1st Qu.:  0.00000   1st Qu.:  -0.030   1st Qu.:   -0.099
#  Median :  0.00000   Median :   0.048   Median :    0.032
#  Mean   :  0.15897   Mean   :   1.087   Mean   :    0.767
#  3rd Qu.:  0.05755   3rd Qu.:   0.176   3rd Qu.:    0.138
#  Max.   :293.47300   Max.   :5468.426   Max.   : 7039.326
#   debt_growth        r.d_expense_growth  sg.a_expenses_growth
#  Min.   :   -1.051   Min.   :  -2.6622   Min.   :  -2.3699
#  1st Qu.:   -0.065   1st Qu.:   0.0000   1st Qu.:  -0.0134
#  Median :    0.000   Median :   0.0000   Median :   0.0610
#  Mean   :    3.705   Mean   :   0.2935   Mean   :   0.3569
#  3rd Qu.:    0.147   3rd Qu.:   0.0000   3rd Qu.:   0.1848
#  Max.   :17646.823   Max.   :1542.6110   Max.   :2042.0000
#  payout_ratio       interest_coverage  net_profit_margin  dividend_yield
#  Length:19615       Length:19615       Length:19615       Length:19615
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#    pe_ratio          pfcf_ratio         pocf_ratio        price_to_sales_ratio
#  Length:19615       Length:19615       Length:19615       Length:19615
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#  days_payables_outstanding free_cash_flow_per_share     roe
#  Length:19615              Length:19615             Length:19615
#  Class :character          Class :character         Class :character
#  Mode  :character          Mode  :character         Mode  :character
#
#
#
#   ptb_ratio           pb_ratio         operating_cash_flow_per_share
#  Length:19615       Length:19615       Length:19615
#  Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character
#
#
#
#  cash_per_share
#  Length:19615
#  Class :character
#  Mode  :character

# %%
#Combining the sets with the original data
imputedm <- cbind(data[, c('stock','nextyr_price_var','class','year','sector','sector_num')], imputedm)
dim(imputedm)
# Out:
# [1] 19615   171

# %%
max(apply(is.na(imputedm),2,sum))
# Out:
# [1] 0

# %% [markdown]
# ### Uniformity
# Are all variables measured using compatible units? Or are there monetary values in different forms of currency? Or something else entirely? If any of these issues are applicable to your data, design and implement a solution.

# %%
#Implementing scaling in the modeling notebook

# %% [markdown]
# ### Additional Cleaning
# If your data set has any other issues you have noticed, you should handle them here.

# %%
#No additional cleaning was performed in this notebook

# %% [markdown]
# ## Save the Prepared Set

# %%
fwrite(data, paste0(dir$final_data,'clean_financial.csv'))
fwrite(imputedm, paste0(dir$final_data,'imputedm_financial.csv'))

# %% [markdown]
# ## Outcome
# At this point you should have an analytic data set prepared for data modeling. You should also be able to account for any changes you have made in the data. Do this now.

# %% [markdown]
# ##### The following changes were made to the data set:
#  - Duplicates: Any duplicate columns were removed from the data set. This was done by first using the duplicated function to identify identical columns. Then, I looked at the columns sums to identify additional duplicate variables. In the end, about 20 variables were duplicated.
#  - Variable Names: The variables names were cleaned up so that they were consistent. Spaces and dashes were removed, all letters were lower-cased, and underscores were added between most words.
#  - Categorical Encoding: A new variable "sector_num" was created as the numeric version of the categorical variable "sector" to aid in machine learning modeling.
#  - Missing Data: The missing data was cleaned in the following manner:
#       1. Any row with missing values greater than 50 was removed
#       2. Any column with missing values greater than 15% was removed
#       3. The remaining values were imputed using the median value for now
#       4. The plan is to use the complete data set to identify which variables are relevant first. Then I will impute on those variables and re-train my data set. Trying to use random forest to impute the missing values at this stage was far too time consuming in R at this stage.
#  - Outliers: The outliers in the data set were removed in the previous notebook using Cook's Distance. Only four rows were identified as extreme outliers and were thus removed from the data set.
