# %% [markdown]
# # Data Preparation
# In this stage, you will handle some of the errors that you found during the previous notebook and prepare your data for the model training stage.

# %% [markdown]
# ### Imports

# %%
library(tidyverse)

# %% [markdown]
# ### Data
# Read in the final data set from your data_preparation notebook.

# %%
setwd("C:/Users/User/Documents/nick-kaggle-training")
data <- read_csv("data/combined_financial.csv")

# %% [markdown]
# ## More Cleaning

# %% [markdown]
# ### Duplicates
# Deal with any duplicate rows/columns (or, contrarily, any empty rows/columns), if applicable.

# %%
#Checking for duplicate column sums
dups <- data[ , which(duplicated(t(data)))]
names(dups)
# Out:
#  [1] "nIperEBT"                  "eBTperEBIT"
#  [3] "eBITperRevenue"            "cashFlowCoverageRatios"
#  [5] "Debt to Equity"            "Debt to Assets"
#  [7] "ROIC"                      "Return on Tangible Assets"
#  [9] "Payables Turnover"         "Inventory Turnover"

# %%
#Removing any duplicate column sums after verifying them
data <- data[ , which(!duplicated(t(data)))] 
dim(data)
# Out:
# [1] 22077   214

# %%
#Looking for missing values & evaluating list of variable names
na <- apply(is.na(data),2,sum)
max(na)
#print(na)
#sort(na, decreasing = TRUE)
#head(sort(na, decreasing = TRUE), n=25)
# Out:
# [1] 10744

# %%
#Merging and dropping duplicated variable names
view(data[, c("Payout Ratio", "payoutRatio")])
data <- {x <- "Payout Ratio"
  y <- "payoutRatio"
  d <- data[, c(x,y)]
  data <- select(data, -c(x,y))
  d$c <- ifelse(is.na(d[[1]]), round(d[[2]],4), d[[1]])
  d$c <- ifelse(d[[3]] == 0.0000 & d[[2]] != 0.0000, round(d[[2]],4), d[[3]])
  colnames(d)[3] <- x
  d <- d[ , -c(1:2)]
  data <- cbind(data, d)
}

view(data[, c("interestCoverage", "Interest Coverage")])
data <- {x <- "Interest Coverage"
  y <- "interestCoverage"
  d <- data[, c(x,y)]
  data <- select(data, -c(x,y))
  d$c <- ifelse(is.na(d[[1]]), round(d[[2]],4), d[[1]])
  d$c <- ifelse(d[[3]] == 0.0000 & d[[2]] != 0.0000, round(d[[2]],4), d[[3]])
  colnames(d)[3] <- x
  d <- subset(d, select = -c(1:2))
  data <- cbind(data, d)
}

view(data[, c("netProfitMargin", "Net Profit Margin")])
data <- {x <- "Net Profit Margin"
  y <- "netProfitMargin"
  d <- data[, c(x,y)]
  data <- select(data, -c(x,y))
  d$c <- ifelse(is.na(d[[1]]), round(d[[2]],4), d[[1]])
  d$c <- ifelse(d[[3]] == 0.0000 & d[[2]] != 0.0000, round(d[[2]],4), d[[3]])
  colnames(d)[3] <- x
  d <- subset(d, select = -c(1:2))
  data <- cbind(data, d)
}

view(data[, c("Dividend Yield", "dividendYield")])
data <- {x <- "Dividend Yield"
  y <- "dividendYield"
  d <- data[, c(x,y)]
  data <- select(data, -c(x,y))
  d$c <- ifelse(is.na(d[[1]]), round(d[[2]],4), d[[1]])
  d$c <- ifelse(d[[3]] == 0.0000 & d[[2]] != 0.0000, round(d[[2]],4), d[[3]])
  colnames(d)[3] <- x
  d <- subset(d, select = -c(1:2))
  data <- cbind(data, d)
}

view(data[, c("PE ratio", "priceEarningsRatio")])
data <- {x <- "PE ratio"
  y <- "priceEarningsRatio"
  d <- data[, c(x,y)]
  data <- select(data, -c(x,y))
  d$c <- ifelse(is.na(d[[1]]), round(d[[2]],4), d[[1]])
  d$c <- ifelse(d[[3]] == 0.0000 & d[[2]] != 0.0000, round(d[[2]],4), d[[3]])
  colnames(d)[3] <- x
  d <- subset(d, select = -c(1:2))
  data <- cbind(data, d)
}

view(data[, c("priceToFreeCashFlowsRatio", "PFCF ratio")])
data <- {x <- "PFCF ratio"
  y <- "priceToFreeCashFlowsRatio"
  d <- data[, c(x,y)]
  data <- select(data, -c(x,y))
  d$c <- ifelse(is.na(d[[1]]), round(d[[2]],4), d[[1]])
  d$c <- ifelse(d[[3]] == 0.0000 & d[[2]] != 0.0000, round(d[[2]],4), d[[3]])
  colnames(d)[3] <- x
  d <- subset(d, select = -c(1:2))
  data <- cbind(data, d)
}

view(data[, c("priceToOperatingCashFlowsRatio", "POCF ratio")])
data <- {x <- "POCF ratio"
  y <- "priceToOperatingCashFlowsRatio"
  d <- data[, c(x,y)]
  data <- select(data, -c(x,y))
  d$c <- ifelse(is.na(d[[1]]), round(d[[2]],4), d[[1]])
  d$c <- ifelse(d[[3]] == 0.0000 & d[[2]] != 0.0000, round(d[[2]],4), d[[3]])
  colnames(d)[3] <- x
  d <- subset(d, select = -c(1:2))
  data <- cbind(data, d)
}

view(data[, c("priceToSalesRatio", "Price to Sales Ratio")])
data <- {x <- "Price to Sales Ratio"
  y <- "priceToSalesRatio"
  d <- data[, c(x,y)]
  data <- select(data, -c(x,y))
  d$c <- ifelse(is.na(d[[1]]), round(d[[2]],4), d[[1]])
  d$c <- ifelse(d[[3]] == 0.0000 & d[[2]] != 0.0000, round(d[[2]],4), d[[3]])
  colnames(d)[3] <- x
  d <- subset(d, select = -c(1:2))
  data <- cbind(data, d)
}

view(data[, c("Days Payables Outstanding", "daysOfPayablesOutstanding")])
data <- {x <- "Days Payables Outstanding"
  y <- "daysOfPayablesOutstanding"
  d <- data[, c(x,y)]
  data <- select(data, -c(x,y))
  d$c <- ifelse(is.na(d[[1]]), round(d[[2]],4), d[[1]])
  d$c <- ifelse(d[[3]] == 0.0000 & d[[2]] != 0.0000, round(d[[2]],4), d[[3]])
  colnames(d)[3] <- x
  d <- subset(d, select = -c(1:2))
  data <- cbind(data, d)
}

view(data[, c("Free Cash Flow per Share", "freeCashFlowPerShare")])
data <- {x <- "Free Cash Flow per Share"
  y <- "freeCashFlowPerShare"
  d <- data[, c(x,y)]
  data <- select(data, -c(x,y))
  d$c <- ifelse(is.na(d[[1]]), round(d[[2]],4), d[[1]])
  d$c <- ifelse(d[[3]] == 0.0000 & d[[2]] != 0.0000, round(d[[2]],4), d[[3]])
  colnames(d)[3] <- x
  d <- subset(d, select = -c(1:2))
  data <- cbind(data, d)
}

view(data[, c("ROE", "returnOnEquity")])
data <- {x <- "ROE"
  y <- "returnOnEquity"
  d <- data[, c(x,y)]
  data <- select(data, -c(x,y))
  d$c <- ifelse(is.na(d[[1]]), round(d[[2]],4), d[[1]])
  d$c <- ifelse(d[[3]] == 0.0000 & d[[2]] != 0.0000, round(d[[2]],4), d[[3]])
  colnames(d)[3] <- x
  d <- subset(d, select = -c(1:2))
  data <- cbind(data, d)
}

view(data[, c("priceToBookRatio", "PTB ratio")])
data <- {x <- "PTB ratio"
  y <- "priceToBookRatio"
  d <- data[, c(x,y)]
  data <- select(data, -c(x,y))
  d$c <- ifelse(is.na(d[[1]]), round(d[[2]],4), d[[1]])
  d$c <- ifelse(d[[3]] == 0.0000 & d[[2]] != 0.0000, round(d[[2]],4), d[[3]])
  colnames(d)[3] <- x
  d <- subset(d, select = -c(1:2))
  data <- cbind(data, d)
}

view(data[, c("priceBookValueRatio", "PB ratio")])
data <- {x <- "PB ratio"
  y <- "priceBookValueRatio"
  d <- data[, c(x,y)]
  data <- select(data, -c(x,y))
  d$c <- ifelse(is.na(d[[1]]), round(d[[2]],4), d[[1]])
  d$c <- ifelse(d[[3]] == 0.0000 & d[[2]] != 0.0000, round(d[[2]],4), d[[3]])
  colnames(d)[3] <- x
  d <- subset(d, select = -c(1:2))
  data <- cbind(data, d)
}

view(data[, c("operatingCashFlowPerShare", "Operating Cash Flow per Share")])
data <- {x <- "Operating Cash Flow per Share"
  y <- "operatingCashFlowPerShare"
  d <- data[, c(x,y)]
  data <- select(data, -c(x,y))
  d$c <- ifelse(is.na(d[[1]]), round(d[[2]],4), d[[1]])
  d$c <- ifelse(d[[3]] == 0.0000 & d[[2]] != 0.0000, round(d[[2]],4), d[[3]])
  colnames(d)[3] <- x
  d <- subset(d, select = -c(1:2))
  data <- cbind(data, d)
}

view(data[, c("Cash per Share", "cashPerShare")])
data <- {x <- "Cash per Share"
  y <- "cashPerShare"
  d <- data[, c(x,y)]
  data <- select(data, -c(x,y))
  d$c <- ifelse(is.na(d[[1]]), round(d[[2]],4), d[[1]])
  d$c <- ifelse(d[[3]] == 0.0000 & d[[2]] != 0.0000, round(d[[2]],4), d[[3]])
  colnames(d)[3] <- x
  d <- subset(d, select = -c(1:2))
  data <- cbind(data, d)
}

dim(data)
# Out:
# [1] 22077   199

# %% [markdown]
# ### Variable Names
# Depending on your data set, variables may have names with strange symbols, which can making loading, saving, and subsetting data difficult. If applicable, you should deal with this now.

# %%
#Checking variable names
names(data)
# Out:
#   [1] "Stock"
#   [2] "nextYR_PRICE_VAR"
#   [3] "Class"
#   [4] "Year"
#   [5] "Sector"
#   [6] "Revenue"
#   [7] "Revenue Growth"
#   [8] "Cost of Revenue"
#   [9] "Gross Profit"
#  [10] "R&D Expenses"
#  [11] "SG&A Expense"
#  [12] "Operating Expenses"
#  [13] "Operating Income"
#  [14] "Interest Expense"
#  [15] "Earnings before Tax"
#  [16] "Income Tax Expense"
#  [17] "Net Income - Non-Controlling int"
#  [18] "Net Income - Discontinued ops"
#  [19] "Net Income"
#  [20] "Preferred Dividends"
#  [21] "Net Income Com"
#  [22] "EPS"
#  [23] "EPS Diluted"
#  [24] "Weighted Average Shs Out"
#  [25] "Weighted Average Shs Out (Dil)"
#  [26] "Dividend per Share"
#  [27] "Gross Margin"
#  [28] "EBITDA Margin"
#  [29] "EBIT Margin"
#  [30] "Profit Margin"
#  [31] "Free Cash Flow margin"
#  [32] "EBITDA"
#  [33] "EBIT"
#  [34] "Consolidated Income"
#  [35] "Earnings Before Tax Margin"
#  [36] "Cash and cash equivalents"
#  [37] "Short-term investments"
#  [38] "Cash and short-term investments"
#  [39] "Receivables"
#  [40] "Inventories"
#  [41] "Total current assets"
#  [42] "Property, Plant & Equipment Net"
#  [43] "Goodwill and Intangible Assets"
#  [44] "Long-term investments"
#  [45] "Tax assets"
#  [46] "Total non-current assets"
#  [47] "Total assets"
#  [48] "Payables"
#  [49] "Short-term debt"
#  [50] "Total current liabilities"
#  [51] "Long-term debt"
#  [52] "Total debt"
#  [53] "Deferred revenue"
#  [54] "Tax Liabilities"
#  [55] "Deposit Liabilities"
#  [56] "Total non-current liabilities"
#  [57] "Total liabilities"
#  [58] "Other comprehensive income"
#  [59] "Retained earnings (deficit)"
#  [60] "Total shareholders equity"
#  [61] "Investments"
#  [62] "Net Debt"
#  [63] "Other Assets"
#  [64] "Other Liabilities"
#  [65] "Depreciation & Amortization"
#  [66] "Stock-based compensation"
#  [67] "Operating Cash Flow"
#  [68] "Capital Expenditure"
#  [69] "Acquisitions and disposals"
#  [70] "Investment purchases and sales"
#  [71] "Investing Cash flow"
#  [72] "Issuance (repayment) of debt"
#  [73] "Issuance (buybacks) of shares"
#  [74] "Dividend payments"
#  [75] "Financing Cash Flow"
#  [76] "Effect of forex changes on cash"
#  [77] "Net cash flow / Change in cash"
#  [78] "Free Cash Flow"
#  [79] "Net Cash/Marketcap"
#  [80] "priceCashFlowRatio"
#  [81] "priceEarningsToGrowthRatio"
#  [82] "priceSalesRatio"
#  [83] "enterpriseValueMultiple"
#  [84] "priceFairValue"
#  [85] "ebitperRevenue"
#  [86] "ebtperEBIT"
#  [87] "niperEBT"
#  [88] "grossProfitMargin"
#  [89] "operatingProfitMargin"
#  [90] "pretaxProfitMargin"
#  [91] "effectiveTaxRate"
#  [92] "returnOnAssets"
#  [93] "returnOnCapitalEmployed"
#  [94] "payablesTurnover"
#  [95] "inventoryTurnover"
#  [96] "fixedAssetTurnover"
#  [97] "assetTurnover"
#  [98] "currentRatio"
#  [99] "quickRatio"
# [100] "cashRatio"
# [101] "daysOfSalesOutstanding"
# [102] "daysOfInventoryOutstanding"
# [103] "debtRatio"
# [104] "debtEquityRatio"
# [105] "longtermDebtToCapitalization"
# [106] "totalDebtToCapitalization"
# [107] "cashFlowToDebtRatio"
# [108] "companyEquityMultiplier"
# [109] "operatingCashFlowSalesRatio"
# [110] "freeCashFlowOperatingCashFlowRatio"
# [111] "shortTermCoverageRatios"
# [112] "capitalExpenditureCoverageRatios"
# [113] "dividendpaidAndCapexCoverageRatios"
# [114] "dividendPayoutRatio"
# [115] "Revenue per Share"
# [116] "Net Income per Share"
# [117] "Book Value per Share"
# [118] "Tangible Book Value per Share"
# [119] "Shareholders Equity per Share"
# [120] "Interest Debt per Share"
# [121] "Market Cap"
# [122] "Enterprise Value"
# [123] "EV to Sales"
# [124] "Enterprise Value over EBITDA"
# [125] "EV to Operating cash flow"
# [126] "EV to Free cash flow"
# [127] "Earnings Yield"
# [128] "Free Cash Flow Yield"
# [129] "Net Debt to EBITDA"
# [130] "Current ratio"
# [131] "Income Quality"
# [132] "SG&A to Revenue"
# [133] "R&D to Revenue"
# [134] "Intangibles to Total Assets"
# [135] "Capex to Operating Cash Flow"
# [136] "Capex to Revenue"
# [137] "Capex to Depreciation"
# [138] "Stock-based compensation to Revenue"
# [139] "Graham Number"
# [140] "Graham Net-Net"
# [141] "Working Capital"
# [142] "Tangible Asset Value"
# [143] "Net Current Asset Value"
# [144] "Invested Capital"
# [145] "Average Receivables"
# [146] "Average Payables"
# [147] "Average Inventory"
# [148] "Days Sales Outstanding"
# [149] "Days of Inventory on Hand"
# [150] "Receivables Turnover"
# [151] "Capex per Share"
# [152] "Gross Profit Growth"
# [153] "EBIT Growth"
# [154] "Operating Income Growth"
# [155] "Net Income Growth"
# [156] "EPS Growth"
# [157] "EPS Diluted Growth"
# [158] "Weighted Average Shares Growth"
# [159] "Weighted Average Shares Diluted Growth"
# [160] "Dividends per Share Growth"
# [161] "Operating Cash Flow growth"
# [162] "Free Cash Flow growth"
# [163] "10Y Revenue Growth (per Share)"
# [164] "5Y Revenue Growth (per Share)"
# [165] "3Y Revenue Growth (per Share)"
# [166] "10Y Operating CF Growth (per Share)"
# [167] "5Y Operating CF Growth (per Share)"
# [168] "3Y Operating CF Growth (per Share)"
# [169] "10Y Net Income Growth (per Share)"
# [170] "5Y Net Income Growth (per Share)"
# [171] "3Y Net Income Growth (per Share)"
# [172] "10Y Shareholders Equity Growth (per Share)"
# [173] "5Y Shareholders Equity Growth (per Share)"
# [174] "3Y Shareholders Equity Growth (per Share)"
# [175] "10Y Dividend per Share Growth (per Share)"
# [176] "5Y Dividend per Share Growth (per Share)"
# [177] "3Y Dividend per Share Growth (per Share)"
# [178] "Receivables growth"
# [179] "Inventory Growth"
# [180] "Asset Growth"
# [181] "Book Value per Share Growth"
# [182] "Debt Growth"
# [183] "R&D Expense Growth"
# [184] "SG&A Expenses Growth"
# [185] "Payout Ratio"
# [186] "Interest Coverage"
# [187] "Net Profit Margin"
# [188] "Dividend Yield"
# [189] "PE ratio"
# [190] "PFCF ratio"
# [191] "POCF ratio"
# [192] "Price to Sales Ratio"
# [193] "Days Payables Outstanding"
# [194] "Free Cash Flow per Share"
# [195] "ROE"
# [196] "PTB ratio"
# [197] "PB ratio"
# [198] "Operating Cash Flow per Share"
# [199] "Cash per Share"

# %%
library(stringr)
#Changing all names to lower case and replacing spaces with "_"
names(data) <- str_trim(names(data), side = "both")
names(data) <- str_to_lower(names(data), locale = "en")
names(data) <- str_replace_all(names(data), " ", "_")
names(data) <- str_replace_all(names(data), "-", "")
names(data)
# Out:
#   [1] "stock"
#   [2] "nextyr_price_var"
#   [3] "class"
#   [4] "year"
#   [5] "sector"
#   [6] "revenue"
#   [7] "revenue_growth"
#   [8] "cost_of_revenue"
#   [9] "gross_profit"
#  [10] "r&d_expenses"
#  [11] "sg&a_expense"
#  [12] "operating_expenses"
#  [13] "operating_income"
#  [14] "interest_expense"
#  [15] "earnings_before_tax"
#  [16] "income_tax_expense"
#  [17] "net_income__noncontrolling_int"
#  [18] "net_income__discontinued_ops"
#  [19] "net_income"
#  [20] "preferred_dividends"
#  [21] "net_income_com"
#  [22] "eps"
#  [23] "eps_diluted"
#  [24] "weighted_average_shs_out"
#  [25] "weighted_average_shs_out_(dil)"
#  [26] "dividend_per_share"
#  [27] "gross_margin"
#  [28] "ebitda_margin"
#  [29] "ebit_margin"
#  [30] "profit_margin"
#  [31] "free_cash_flow_margin"
#  [32] "ebitda"
#  [33] "ebit"
#  [34] "consolidated_income"
#  [35] "earnings_before_tax_margin"
#  [36] "cash_and_cash_equivalents"
#  [37] "shortterm_investments"
#  [38] "cash_and_shortterm_investments"
#  [39] "receivables"
#  [40] "inventories"
#  [41] "total_current_assets"
#  [42] "property,_plant_&_equipment_net"
#  [43] "goodwill_and_intangible_assets"
#  [44] "longterm_investments"
#  [45] "tax_assets"
#  [46] "total_noncurrent_assets"
#  [47] "total_assets"
#  [48] "payables"
#  [49] "shortterm_debt"
#  [50] "total_current_liabilities"
#  [51] "longterm_debt"
#  [52] "total_debt"
#  [53] "deferred_revenue"
#  [54] "tax_liabilities"
#  [55] "deposit_liabilities"
#  [56] "total_noncurrent_liabilities"
#  [57] "total_liabilities"
#  [58] "other_comprehensive_income"
#  [59] "retained_earnings_(deficit)"
#  [60] "total_shareholders_equity"
#  [61] "investments"
#  [62] "net_debt"
#  [63] "other_assets"
#  [64] "other_liabilities"
#  [65] "depreciation_&_amortization"
#  [66] "stockbased_compensation"
#  [67] "operating_cash_flow"
#  [68] "capital_expenditure"
#  [69] "acquisitions_and_disposals"
#  [70] "investment_purchases_and_sales"
#  [71] "investing_cash_flow"
#  [72] "issuance_(repayment)_of_debt"
#  [73] "issuance_(buybacks)_of_shares"
#  [74] "dividend_payments"
#  [75] "financing_cash_flow"
#  [76] "effect_of_forex_changes_on_cash"
#  [77] "net_cash_flow_/_change_in_cash"
#  [78] "free_cash_flow"
#  [79] "net_cash/marketcap"
#  [80] "pricecashflowratio"
#  [81] "priceearningstogrowthratio"
#  [82] "pricesalesratio"
#  [83] "enterprisevaluemultiple"
#  [84] "pricefairvalue"
#  [85] "ebitperrevenue"
#  [86] "ebtperebit"
#  [87] "niperebt"
#  [88] "grossprofitmargin"
#  [89] "operatingprofitmargin"
#  [90] "pretaxprofitmargin"
#  [91] "effectivetaxrate"
#  [92] "returnonassets"
#  [93] "returnoncapitalemployed"
#  [94] "payablesturnover"
#  [95] "inventoryturnover"
#  [96] "fixedassetturnover"
#  [97] "assetturnover"
#  [98] "currentratio"
#  [99] "quickratio"
# [100] "cashratio"
# [101] "daysofsalesoutstanding"
# [102] "daysofinventoryoutstanding"
# [103] "debtratio"
# [104] "debtequityratio"
# [105] "longtermdebttocapitalization"
# [106] "totaldebttocapitalization"
# [107] "cashflowtodebtratio"
# [108] "companyequitymultiplier"
# [109] "operatingcashflowsalesratio"
# [110] "freecashflowoperatingcashflowratio"
# [111] "shorttermcoverageratios"
# [112] "capitalexpenditurecoverageratios"
# [113] "dividendpaidandcapexcoverageratios"
# [114] "dividendpayoutratio"
# [115] "revenue_per_share"
# [116] "net_income_per_share"
# [117] "book_value_per_share"
# [118] "tangible_book_value_per_share"
# [119] "shareholders_equity_per_share"
# [120] "interest_debt_per_share"
# [121] "market_cap"
# [122] "enterprise_value"
# [123] "ev_to_sales"
# [124] "enterprise_value_over_ebitda"
# [125] "ev_to_operating_cash_flow"
# [126] "ev_to_free_cash_flow"
# [127] "earnings_yield"
# [128] "free_cash_flow_yield"
# [129] "net_debt_to_ebitda"
# [130] "current_ratio"
# [131] "income_quality"
# [132] "sg&a_to_revenue"
# [133] "r&d_to_revenue"
# [134] "intangibles_to_total_assets"
# [135] "capex_to_operating_cash_flow"
# [136] "capex_to_revenue"
# [137] "capex_to_depreciation"
# [138] "stockbased_compensation_to_revenue"
# [139] "graham_number"
# [140] "graham_netnet"
# [141] "working_capital"
# [142] "tangible_asset_value"
# [143] "net_current_asset_value"
# [144] "invested_capital"
# [145] "average_receivables"
# [146] "average_payables"
# [147] "average_inventory"
# [148] "days_sales_outstanding"
# [149] "days_of_inventory_on_hand"
# [150] "receivables_turnover"
# [151] "capex_per_share"
# [152] "gross_profit_growth"
# [153] "ebit_growth"
# [154] "operating_income_growth"
# [155] "net_income_growth"
# [156] "eps_growth"
# [157] "eps_diluted_growth"
# [158] "weighted_average_shares_growth"
# [159] "weighted_average_shares_diluted_growth"
# [160] "dividends_per_share_growth"
# [161] "operating_cash_flow_growth"
# [162] "free_cash_flow_growth"
# [163] "10y_revenue_growth_(per_share)"
# [164] "5y_revenue_growth_(per_share)"
# [165] "3y_revenue_growth_(per_share)"
# [166] "10y_operating_cf_growth_(per_share)"
# [167] "5y_operating_cf_growth_(per_share)"
# [168] "3y_operating_cf_growth_(per_share)"
# [169] "10y_net_income_growth_(per_share)"
# [170] "5y_net_income_growth_(per_share)"
# [171] "3y_net_income_growth_(per_share)"
# [172] "10y_shareholders_equity_growth_(per_share)"
# [173] "5y_shareholders_equity_growth_(per_share)"
# [174] "3y_shareholders_equity_growth_(per_share)"
# [175] "10y_dividend_per_share_growth_(per_share)"
# [176] "5y_dividend_per_share_growth_(per_share)"
# [177] "3y_dividend_per_share_growth_(per_share)"
# [178] "receivables_growth"
# [179] "inventory_growth"
# [180] "asset_growth"
# [181] "book_value_per_share_growth"
# [182] "debt_growth"
# [183] "r&d_expense_growth"
# [184] "sg&a_expenses_growth"
# [185] "payout_ratio"
# [186] "interest_coverage"
# [187] "net_profit_margin"
# [188] "dividend_yield"
# [189] "pe_ratio"
# [190] "pfcf_ratio"
# [191] "pocf_ratio"
# [192] "price_to_sales_ratio"
# [193] "days_payables_outstanding"
# [194] "free_cash_flow_per_share"
# [195] "roe"
# [196] "ptb_ratio"
# [197] "pb_ratio"
# [198] "operating_cash_flow_per_share"
# [199] "cash_per_share"

# %% [markdown]
# ### Categorical Encoding
# Are there any categorical variables in your data? If so, transform them so that they can be used to train a machine learning algorithm.

# %%
#Categorical Encoding
data$sector <- as.factor(data$sector)
data$sector_num <- as.numeric(data$sector)

#Reordering data to put "sector" with "sector_num"
data <- data %>%
  select(1:5, 200, everything())

# %% [markdown]
# ### Missing Data
# If missing data is present (ie, NaN values), what is the best way to deal with it? Should values be imputed (and if so, how)? Or should they simply be filled? How will each option will affect the ultimate outcome of your model? Design and implement a solution.

# %%
na <- apply(is.na(data),2,sum)
#print(na)
max(na)
# Out:
# [1] 10744

# %%
#sort(na, decreasing = TRUE)
head(sort(na, decreasing = TRUE), n=25)
# Out:
#                    shorttermcoverageratios
#                                      10744
# 10y_shareholders_equity_growth_(per_share)
#                                       9680
#             10y_revenue_growth_(per_share)
#                                       9532
#          10y_net_income_growth_(per_share)
#                                       9532
#        10y_operating_cf_growth_(per_share)
#                                       9478
#  10y_dividend_per_share_growth_(per_share)
#                                       9177
#                 priceearningstogrowthratio
#                                       9079
#                        dividendpayoutratio
#                                       9079
#                                   niperebt
#                                       8595
#                           effectivetaxrate
#                                       8595
#                                 ebtperebit
#                                       8007
#                         net_debt_to_ebitda
#                                       7715
#                         pricecashflowratio
#                                       7064
#                    enterprisevaluemultiple
#                                       6944
#                                   net_debt
#                                       6859
#                               other_assets
#                                       6756
#  5y_shareholders_equity_growth_(per_share)
#                                       6610
#         freecashflowoperatingcashflowratio
#                                       6588
#                             returnonassets
#                                       6535
#                              current_ratio
#                                       6516
#                            working_capital
#                                       6510
#                    returnoncapitalemployed
#                                       6509
#              5y_revenue_growth_(per_share)
#                                       6401
#           5y_net_income_growth_(per_share)
#                                       6401
#         5y_operating_cf_growth_(per_share)
#                                       6364

# %%
#Checking how many cases are complete
sum(complete.cases(data))

#Checking for NA across rows
data$na <- rowSums(is.na(data))
max(data$na)
head(sort(data$na, decreasing = TRUE),n = 20)
summary(data$na)
# Out:
# [1] 3435
# [1] 194
#  [1] 194 194 194 194 194 194 194 194 194 194 194 194 194 194 194 194 194 194 194
# [20] 194
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    2.00   10.00   27.88   23.00  194.00

# %%
#Found that 50 was a good cut off for dropping
drop <- data %>% 
  filter(na >= 50)
dim(drop)

data <- data %>%
  filter(na <= 50)

data <- subset(data, select = -na)

#Re-checking the NAs across columns
na <- apply(is.na(data),2,sum)
max(na)
print(na)
sort(na, decreasing = TRUE)
head(sort(na, decreasing = TRUE), n=25)
# Out:
# [1] 2522  201
# [1] 8360
#                                      stock
#                                          0
#                           nextyr_price_var
#                                          0
#                                      class
#                                          0
#                                       year
#                                          0
#                                     sector
#                                          0
#                                 sector_num
#                                          0
#                                    revenue
#                                          0
#                             revenue_growth
#                                         51
#                            cost_of_revenue
#                                          5
#                               gross_profit
#                                          0
#                               r&d_expenses
#                                          6
#                               sg&a_expense
#                                          4
#                         operating_expenses
#                                          0
#                           operating_income
#                                          0
#                           interest_expense
#                                          0
#                        earnings_before_tax
#                                          0
#                         income_tax_expense
#                                          1
#             net_income__noncontrolling_int
#                                          4
#               net_income__discontinued_ops
#                                          4
#                                 net_income
#                                          8
#                        preferred_dividends
#                                          4
#                             net_income_com
#                                          4
#                                        eps
#                                          8
#                                eps_diluted
#                                         21
#                   weighted_average_shs_out
#                                        135
#             weighted_average_shs_out_(dil)
#                                         54
#                         dividend_per_share
#                                          4
#                               gross_margin
#                                          0
#                              ebitda_margin
#                                        701
#                                ebit_margin
#                                          0
#                              profit_margin
#                                        700
#                      free_cash_flow_margin
#                                          6
#                                     ebitda
#                                          8
#                                       ebit
#                                          0
#                        consolidated_income
#                                          8
#                 earnings_before_tax_margin
#                                          0
#                  cash_and_cash_equivalents
#                                          0
#                      shortterm_investments
#                                        847
#             cash_and_shortterm_investments
#                                        828
#                                receivables
#                                          0
#                                inventories
#                                          0
#                       total_current_assets
#                                        855
#            property,_plant_&_equipment_net
#                                          0
#             goodwill_and_intangible_assets
#                                          0
#                       longterm_investments
#                                        789
#                                 tax_assets
#                                          7
#                    total_noncurrent_assets
#                                       4128
#                               total_assets
#                                          0
#                                   payables
#                                          0
#                             shortterm_debt
#                                        853
#                  total_current_liabilities
#                                        846
#                              longterm_debt
#                                        769
#                                 total_debt
#                                          7
#                           deferred_revenue
#                                          7
#                            tax_liabilities
#                                          7
#                        deposit_liabilities
#                                          7
#               total_noncurrent_liabilities
#                                       4138
#                          total_liabilities
#                                          0
#                 other_comprehensive_income
#                                          7
#                retained_earnings_(deficit)
#                                        111
#                  total_shareholders_equity
#                                          0
#                                investments
#                                          0
#                                   net_debt
#                                       5237
#                               other_assets
#                                       5148
#                          other_liabilities
#                                        853
#                depreciation_&_amortization
#                                          3
#                    stockbased_compensation
#                                          7
#                        operating_cash_flow
#                                          0
#                        capital_expenditure
#                                          2
#                 acquisitions_and_disposals
#                                          8
#             investment_purchases_and_sales
#                                          7
#                        investing_cash_flow
#                                          0
#               issuance_(repayment)_of_debt
#                                          1
#              issuance_(buybacks)_of_shares
#                                          3
#                          dividend_payments
#                                          3
#                        financing_cash_flow
#                                          0
#            effect_of_forex_changes_on_cash
#                                          7
#             net_cash_flow_/_change_in_cash
#                                          0
#                             free_cash_flow
#                                          7
#                         net_cash/marketcap
#                                       1079
#                         pricecashflowratio
#                                       4599
#                 priceearningstogrowthratio
#                                       6612
#                            pricesalesratio
#                                        924
#                    enterprisevaluemultiple
#                                       4540
#                             pricefairvalue
#                                       1176
#                             ebitperrevenue
#                                        869
#                                 ebtperebit
#                                       5638
#                                   niperebt
#                                       6444
#                          grossprofitmargin
#                                        869
#                      operatingprofitmargin
#                                        869
#                         pretaxprofitmargin
#                                        869
#                           effectivetaxrate
#                                       6444
#                             returnonassets
#                                       4139
#                    returnoncapitalemployed
#                                       4135
#                           payablesturnover
#                                       2460
#                          inventoryturnover
#                                         99
#                         fixedassetturnover
#                                        920
#                              assetturnover
#                                          0
#                               currentratio
#                                        866
#                                 quickratio
#                                        865
#                                  cashratio
#                                        865
#                     daysofsalesoutstanding
#                                          1
#                 daysofinventoryoutstanding
#                                          1
#                                  debtratio
#                                          5
#                            debtequityratio
#                                          5
#               longtermdebttocapitalization
#                                        409
#                  totaldebttocapitalization
#                                        327
#                        cashflowtodebtratio
#                                       4201
#                    companyequitymultiplier
#                                       1123
#                operatingcashflowsalesratio
#                                        869
#         freecashflowoperatingcashflowratio
#                                       4551
#                    shorttermcoverageratios
#                                       8360
#           capitalexpenditurecoverageratios
#                                       1431
#         dividendpaidandcapexcoverageratios
#                                        715
#                        dividendpayoutratio
#                                       6612
#                          revenue_per_share
#                                         58
#                       net_income_per_share
#                                         60
#                       book_value_per_share
#                                         56
#              tangible_book_value_per_share
#                                         56
#              shareholders_equity_per_share
#                                         56
#                    interest_debt_per_share
#                                         56
#                                 market_cap
#                                        789
#                           enterprise_value
#                                       2690
#                                ev_to_sales
#                                       2694
#               enterprise_value_over_ebitda
#                                       2690
#                  ev_to_operating_cash_flow
#                                       2690
#                       ev_to_free_cash_flow
#                                       2690
#                             earnings_yield
#                                          0
#                       free_cash_flow_yield
#                                        891
#                         net_debt_to_ebitda
#                                       5254
#                              current_ratio
#                                       4140
#                             income_quality
#                                          4
#                            sg&a_to_revenue
#                                          4
#                             r&d_to_revenue
#                                          6
#                intangibles_to_total_assets
#                                          1
#               capex_to_operating_cash_flow
#                                          0
#                           capex_to_revenue
#                                          0
#                      capex_to_depreciation
#                                          2
#         stockbased_compensation_to_revenue
#                                          7
#                              graham_number
#                                       2637
#                              graham_netnet
#                                        876
#                            working_capital
#                                       4135
#                       tangible_asset_value
#                                          1
#                    net_current_asset_value
#                                        836
#                           invested_capital
#                                          5
#                        average_receivables
#                                         97
#                           average_payables
#                                         95
#                          average_inventory
#                                         96
#                     days_sales_outstanding
#                                          1
#                  days_of_inventory_on_hand
#                                          1
#                       receivables_turnover
#                                        100
#                            capex_per_share
#                                         56
#                        gross_profit_growth
#                                         25
#                                ebit_growth
#                                         27
#                    operating_income_growth
#                                         25
#                          net_income_growth
#                                         59
#                                 eps_growth
#                                        121
#                         eps_diluted_growth
#                                        146
#             weighted_average_shares_growth
#                                        360
#     weighted_average_shares_diluted_growth
#                                       1833
#                 dividends_per_share_growth
#                                         86
#                 operating_cash_flow_growth
#                                         28
#                      free_cash_flow_growth
#                                         91
#             10y_revenue_growth_(per_share)
#                                       7030
#              5y_revenue_growth_(per_share)
#                                       3904
#              3y_revenue_growth_(per_share)
#                                       1970
#        10y_operating_cf_growth_(per_share)
#                                       6983
#         5y_operating_cf_growth_(per_share)
#                                       3881
#         3y_operating_cf_growth_(per_share)
#                                       1956
#          10y_net_income_growth_(per_share)
#                                       7030
#           5y_net_income_growth_(per_share)
#                                       3904
#           3y_net_income_growth_(per_share)
#                                       1970
# 10y_shareholders_equity_growth_(per_share)
#                                       7184
#  5y_shareholders_equity_growth_(per_share)
#                                       4126
#  3y_shareholders_equity_growth_(per_share)
#                                       2167
#  10y_dividend_per_share_growth_(per_share)
#                                       6683
#   5y_dividend_per_share_growth_(per_share)
#                                       3297
#   3y_dividend_per_share_growth_(per_share)
#                                       1344
#                         receivables_growth
#                                         98
#                           inventory_growth
#                                         97
#                               asset_growth
#                                         97
#                book_value_per_share_growth
#                                        410
#                                debt_growth
#                                        183
#                         r&d_expense_growth
#                                         82
#                       sg&a_expenses_growth
#                                         60
#                               payout_ratio
#                                         65
#                          interest_coverage
#                                          0
#                          net_profit_margin
#                                        855
#                             dividend_yield
#                                        725
#                                   pe_ratio
#                                          0
#                                 pfcf_ratio
#                                          0
#                                 pocf_ratio
#                                        891
#                       price_to_sales_ratio
#                                          5
#                  days_payables_outstanding
#                                          1
#                   free_cash_flow_per_share
#                                         56
#                                        roe
#                                          9
#                                  ptb_ratio
#                                       2633
#                                   pb_ratio
#                                       2633
#              operating_cash_flow_per_share
#                                         56
#                             cash_per_share
#                                         56
#                    shorttermcoverageratios
#                                       8360
# 10y_shareholders_equity_growth_(per_share)
#                                       7184
#             10y_revenue_growth_(per_share)
#                                       7030
#          10y_net_income_growth_(per_share)
#                                       7030
#        10y_operating_cf_growth_(per_share)
#                                       6983
#  10y_dividend_per_share_growth_(per_share)
#                                       6683
#                 priceearningstogrowthratio
#                                       6612
#                        dividendpayoutratio
#                                       6612
#                                   niperebt
#                                       6444
#                           effectivetaxrate
#                                       6444
#                                 ebtperebit
#                                       5638
#                         net_debt_to_ebitda
#                                       5254
#                                   net_debt
#                                       5237
#                               other_assets
#                                       5148
#                         pricecashflowratio
#                                       4599
#         freecashflowoperatingcashflowratio
#                                       4551
#                    enterprisevaluemultiple
#                                       4540
#                        cashflowtodebtratio
#                                       4201
#                              current_ratio
#                                       4140
#                             returnonassets
#                                       4139
#               total_noncurrent_liabilities
#                                       4138
#                    returnoncapitalemployed
#                                       4135
#                            working_capital
#                                       4135
#                    total_noncurrent_assets
#                                       4128
#  5y_shareholders_equity_growth_(per_share)
#                                       4126
#              5y_revenue_growth_(per_share)
#                                       3904
#           5y_net_income_growth_(per_share)
#                                       3904
#         5y_operating_cf_growth_(per_share)
#                                       3881
#   5y_dividend_per_share_growth_(per_share)
#                                       3297
#                                ev_to_sales
#                                       2694
#                           enterprise_value
#                                       2690
#               enterprise_value_over_ebitda
#                                       2690
#                  ev_to_operating_cash_flow
#                                       2690
#                       ev_to_free_cash_flow
#                                       2690
#                              graham_number
#                                       2637
#                                  ptb_ratio
#                                       2633
#                                   pb_ratio
#                                       2633
#                           payablesturnover
#                                       2460
#  3y_shareholders_equity_growth_(per_share)
#                                       2167
#              3y_revenue_growth_(per_share)
#                                       1970
#           3y_net_income_growth_(per_share)
#                                       1970
#         3y_operating_cf_growth_(per_share)
#                                       1956
#     weighted_average_shares_diluted_growth
#                                       1833
#           capitalexpenditurecoverageratios
#                                       1431
#   3y_dividend_per_share_growth_(per_share)
#                                       1344
#                             pricefairvalue
#                                       1176
#                    companyequitymultiplier
#                                       1123
#                         net_cash/marketcap
#                                       1079
#                            pricesalesratio
#                                        924
#                         fixedassetturnover
#                                        920
#                       free_cash_flow_yield
#                                        891
#                                 pocf_ratio
#                                        891
#                              graham_netnet
#                                        876
#                             ebitperrevenue
#                                        869
#                          grossprofitmargin
#                                        869
#                      operatingprofitmargin
#                                        869
#                         pretaxprofitmargin
#                                        869
#                operatingcashflowsalesratio
#                                        869
#                               currentratio
#                                        866
#                                 quickratio
#                                        865
#                                  cashratio
#                                        865
#                       total_current_assets
#                                        855
#                          net_profit_margin
#                                        855
#                             shortterm_debt
#                                        853
#                          other_liabilities
#                                        853
#                      shortterm_investments
#                                        847
#                  total_current_liabilities
#                                        846
#                    net_current_asset_value
#                                        836
#             cash_and_shortterm_investments
#                                        828
#                       longterm_investments
#                                        789
#                                 market_cap
#                                        789
#                              longterm_debt
#                                        769
#                             dividend_yield
#                                        725
#         dividendpaidandcapexcoverageratios
#                                        715
#                              ebitda_margin
#                                        701
#                              profit_margin
#                                        700
#                book_value_per_share_growth
#                                        410
#               longtermdebttocapitalization
#                                        409
#             weighted_average_shares_growth
#                                        360
#                  totaldebttocapitalization
#                                        327
#                                debt_growth
#                                        183
#                         eps_diluted_growth
#                                        146
#                   weighted_average_shs_out
#                                        135
#                                 eps_growth
#                                        121
#                retained_earnings_(deficit)
#                                        111
#                       receivables_turnover
#                                        100
#                          inventoryturnover
#                                         99
#                         receivables_growth
#                                         98
#                        average_receivables
#                                         97
#                           inventory_growth
#                                         97
#                               asset_growth
#                                         97
#                          average_inventory
#                                         96
#                           average_payables
#                                         95
#                      free_cash_flow_growth
#                                         91
#                 dividends_per_share_growth
#                                         86
#                         r&d_expense_growth
#                                         82
#                               payout_ratio
#                                         65
#                       net_income_per_share
#                                         60
#                       sg&a_expenses_growth
#                                         60
#                          net_income_growth
#                                         59
#                          revenue_per_share
#                                         58
#                       book_value_per_share
#                                         56
#              tangible_book_value_per_share
#                                         56
#              shareholders_equity_per_share
#                                         56
#                    interest_debt_per_share
#                                         56
#                            capex_per_share
#                                         56
#                   free_cash_flow_per_share
#                                         56
#              operating_cash_flow_per_share
#                                         56
#                             cash_per_share
#                                         56
#             weighted_average_shs_out_(dil)
#                                         54
#                             revenue_growth
#                                         51
#                 operating_cash_flow_growth
#                                         28
#                                ebit_growth
#                                         27
#                        gross_profit_growth
#                                         25
#                    operating_income_growth
#                                         25
#                                eps_diluted
#                                         21
#                                        roe
#                                          9
#                                 net_income
#                                          8
#                                        eps
#                                          8
#                                     ebitda
#                                          8
#                        consolidated_income
#                                          8
#                 acquisitions_and_disposals
#                                          8
#                                 tax_assets
#                                          7
#                                 total_debt
#                                          7
#                           deferred_revenue
#                                          7
#                            tax_liabilities
#                                          7
#                        deposit_liabilities
#                                          7
#                 other_comprehensive_income
#                                          7
#                    stockbased_compensation
#                                          7
#             investment_purchases_and_sales
#                                          7
#            effect_of_forex_changes_on_cash
#                                          7
#                             free_cash_flow
#                                          7
#         stockbased_compensation_to_revenue
#                                          7
#                               r&d_expenses
#                                          6
#                      free_cash_flow_margin
#                                          6
#                             r&d_to_revenue
#                                          6
#                            cost_of_revenue
#                                          5
#                                  debtratio
#                                          5
#                            debtequityratio
#                                          5
#                           invested_capital
#                                          5
#                       price_to_sales_ratio
#                                          5
#                               sg&a_expense
#                                          4
#             net_income__noncontrolling_int
#                                          4
#               net_income__discontinued_ops
#                                          4
#                        preferred_dividends
#                                          4
#                             net_income_com
#                                          4
#                         dividend_per_share
#                                          4
#                             income_quality
#                                          4
#                            sg&a_to_revenue
#                                          4
#                depreciation_&_amortization
#                                          3
#              issuance_(buybacks)_of_shares
#                                          3
#                          dividend_payments
#                                          3
#                        capital_expenditure
#                                          2
#                      capex_to_depreciation
#                                          2
#                         income_tax_expense
#                                          1
#               issuance_(repayment)_of_debt
#                                          1
#                     daysofsalesoutstanding
#                                          1
#                 daysofinventoryoutstanding
#                                          1
#                intangibles_to_total_assets
#                                          1
#                       tangible_asset_value
#                                          1
#                     days_sales_outstanding
#                                          1
#                  days_of_inventory_on_hand
#                                          1
#                  days_payables_outstanding
#                                          1
#                                      stock
#                                          0
#                           nextyr_price_var
#                                          0
#                                      class
#                                          0
#                                       year
#                                          0
#                                     sector
#                                          0
#                                 sector_num
#                                          0
#                                    revenue
#                                          0
#                               gross_profit
#                                          0
#                         operating_expenses
#                                          0
#                           operating_income
#                                          0
#                           interest_expense
#                                          0
#                        earnings_before_tax
#                                          0
#                               gross_margin
#                                          0
#                                ebit_margin
#                                          0
#                                       ebit
#                                          0
#                 earnings_before_tax_margin
#                                          0
#                  cash_and_cash_equivalents
#                                          0
#                                receivables
#                                          0
#                                inventories
#                                          0
#            property,_plant_&_equipment_net
#                                          0
#             goodwill_and_intangible_assets
#                                          0
#                               total_assets
#                                          0
#                                   payables
#                                          0
#                          total_liabilities
#                                          0
#                  total_shareholders_equity
#                                          0
#                                investments
#                                          0
#                        operating_cash_flow
#                                          0
#                        investing_cash_flow
#                                          0
#                        financing_cash_flow
#                                          0
#             net_cash_flow_/_change_in_cash
#                                          0
#                              assetturnover
#                                          0
#                             earnings_yield
#                                          0
#               capex_to_operating_cash_flow
#                                          0
#                           capex_to_revenue
#                                          0
#                          interest_coverage
#                                          0
#                                   pe_ratio
#                                          0
#                                 pfcf_ratio
#                                          0
#                    shorttermcoverageratios
#                                       8360
# 10y_shareholders_equity_growth_(per_share)
#                                       7184
#             10y_revenue_growth_(per_share)
#                                       7030
#          10y_net_income_growth_(per_share)
#                                       7030
#        10y_operating_cf_growth_(per_share)
#                                       6983
#  10y_dividend_per_share_growth_(per_share)
#                                       6683
#                 priceearningstogrowthratio
#                                       6612
#                        dividendpayoutratio
#                                       6612
#                                   niperebt
#                                       6444
#                           effectivetaxrate
#                                       6444
#                                 ebtperebit
#                                       5638
#                         net_debt_to_ebitda
#                                       5254
#                                   net_debt
#                                       5237
#                               other_assets
#                                       5148
#                         pricecashflowratio
#                                       4599
#         freecashflowoperatingcashflowratio
#                                       4551
#                    enterprisevaluemultiple
#                                       4540
#                        cashflowtodebtratio
#                                       4201
#                              current_ratio
#                                       4140
#                             returnonassets
#                                       4139
#               total_noncurrent_liabilities
#                                       4138
#                    returnoncapitalemployed
#                                       4135
#                            working_capital
#                                       4135
#                    total_noncurrent_assets
#                                       4128
#  5y_shareholders_equity_growth_(per_share)
#                                       4126

# %%
#Keeping only columns with less than ~25 percent missing
perc_miss <- function(x){sum(is.na(x))/length(x)*100}
perc <- apply(data,2,perc_miss)
max(perc)
print(perc)
#sort(perc, decreasing = TRUE)
head(sort(perc, decreasing = TRUE), n=25)

#Choosing to keep only variables with less than 15% missing data
data <- data[, which(apply(data,2,perc_miss) < 15.0)]
# Out:
# [1] 42.71626
#                                      stock
#                                0.000000000
#                           nextyr_price_var
#                                0.000000000
#                                      class
#                                0.000000000
#                                       year
#                                0.000000000
#                                     sector
#                                0.000000000
#                                 sector_num
#                                0.000000000
#                                    revenue
#                                0.000000000
#                             revenue_growth
#                                0.260589648
#                            cost_of_revenue
#                                0.025548005
#                               gross_profit
#                                0.000000000
#                               r&d_expenses
#                                0.030657606
#                               sg&a_expense
#                                0.020438404
#                         operating_expenses
#                                0.000000000
#                           operating_income
#                                0.000000000
#                           interest_expense
#                                0.000000000
#                        earnings_before_tax
#                                0.000000000
#                         income_tax_expense
#                                0.005109601
#             net_income__noncontrolling_int
#                                0.020438404
#               net_income__discontinued_ops
#                                0.020438404
#                                 net_income
#                                0.040876808
#                        preferred_dividends
#                                0.020438404
#                             net_income_com
#                                0.020438404
#                                        eps
#                                0.040876808
#                                eps_diluted
#                                0.107301620
#                   weighted_average_shs_out
#                                0.689796127
#             weighted_average_shs_out_(dil)
#                                0.275918451
#                         dividend_per_share
#                                0.020438404
#                               gross_margin
#                                0.000000000
#                              ebitda_margin
#                                3.581830259
#                                ebit_margin
#                                0.000000000
#                              profit_margin
#                                3.576720658
#                      free_cash_flow_margin
#                                0.030657606
#                                     ebitda
#                                0.040876808
#                                       ebit
#                                0.000000000
#                        consolidated_income
#                                0.040876808
#                 earnings_before_tax_margin
#                                0.000000000
#                  cash_and_cash_equivalents
#                                0.000000000
#                      shortterm_investments
#                                4.327831996
#             cash_and_shortterm_investments
#                                4.230749578
#                                receivables
#                                0.000000000
#                                inventories
#                                0.000000000
#                       total_current_assets
#                                4.368708804
#            property,_plant_&_equipment_net
#                                0.000000000
#             goodwill_and_intangible_assets
#                                0.000000000
#                       longterm_investments
#                                4.031475142
#                                 tax_assets
#                                0.035767207
#                    total_noncurrent_assets
#                               21.092432681
#                               total_assets
#                                0.000000000
#                                   payables
#                                0.000000000
#                             shortterm_debt
#                                4.358489602
#                  total_current_liabilities
#                                4.322722395
#                              longterm_debt
#                                3.929283123
#                                 total_debt
#                                0.035767207
#                           deferred_revenue
#                                0.035767207
#                            tax_liabilities
#                                0.035767207
#                        deposit_liabilities
#                                0.035767207
#               total_noncurrent_liabilities
#                               21.143528690
#                          total_liabilities
#                                0.000000000
#                 other_comprehensive_income
#                                0.035767207
#                retained_earnings_(deficit)
#                                0.567165704
#                  total_shareholders_equity
#                                0.000000000
#                                investments
#                                0.000000000
#                                   net_debt
#                               26.758980124
#                               other_assets
#                               26.304225640
#                          other_liabilities
#                                4.358489602
#                depreciation_&_amortization
#                                0.015328803
#                    stockbased_compensation
#                                0.035767207
#                        operating_cash_flow
#                                0.000000000
#                        capital_expenditure
#                                0.010219202
#                 acquisitions_and_disposals
#                                0.040876808
#             investment_purchases_and_sales
#                                0.035767207
#                        investing_cash_flow
#                                0.000000000
#               issuance_(repayment)_of_debt
#                                0.005109601
#              issuance_(buybacks)_of_shares
#                                0.015328803
#                          dividend_payments
#                                0.015328803
#                        financing_cash_flow
#                                0.000000000
#            effect_of_forex_changes_on_cash
#                                0.035767207
#             net_cash_flow_/_change_in_cash
#                                0.000000000
#                             free_cash_flow
#                                0.035767207
#                         net_cash/marketcap
#                                5.513259414
#                         pricecashflowratio
#                               23.499054724
#                 priceearningstogrowthratio
#                               33.784681416
#                            pricesalesratio
#                                4.721271269
#                    enterprisevaluemultiple
#                               23.197588268
#                             pricefairvalue
#                                6.008890706
#                             ebitperrevenue
#                                4.440243217
#                                 ebtperebit
#                               28.807930101
#                                   niperebt
#                               32.926268458
#                          grossprofitmargin
#                                4.440243217
#                      operatingprofitmargin
#                                4.440243217
#                         pretaxprofitmargin
#                                4.440243217
#                           effectivetaxrate
#                               32.926268458
#                             returnonassets
#                               21.148638291
#                    returnoncapitalemployed
#                               21.128199888
#                           payablesturnover
#                               12.569618313
#                          inventoryturnover
#                                0.505850493
#                         fixedassetturnover
#                                4.700832865
#                              assetturnover
#                                0.000000000
#                               currentratio
#                                4.424914414
#                                 quickratio
#                                4.419804813
#                                  cashratio
#                                4.419804813
#                     daysofsalesoutstanding
#                                0.005109601
#                 daysofinventoryoutstanding
#                                0.005109601
#                                  debtratio
#                                0.025548005
#                            debtequityratio
#                                0.025548005
#               longtermdebttocapitalization
#                                2.089826785
#                  totaldebttocapitalization
#                                1.670839507
#                        cashflowtodebtratio
#                               21.465433550
#                    companyequitymultiplier
#                                5.738081856
#                operatingcashflowsalesratio
#                                4.440243217
#         freecashflowoperatingcashflowratio
#                               23.253793879
#                    shorttermcoverageratios
#                               42.716263860
#           capitalexpenditurecoverageratios
#                                7.311838945
#         dividendpaidandcapexcoverageratios
#                                3.653364672
#                        dividendpayoutratio
#                               33.784681416
#                          revenue_per_share
#                                0.296356855
#                       net_income_per_share
#                                0.306576056
#                       book_value_per_share
#                                0.286137653
#              tangible_book_value_per_share
#                                0.286137653
#              shareholders_equity_per_share
#                                0.286137653
#                    interest_debt_per_share
#                                0.286137653
#                                 market_cap
#                                4.031475142
#                           enterprise_value
#                               13.744826529
#                                ev_to_sales
#                               13.765264933
#               enterprise_value_over_ebitda
#                               13.744826529
#                  ev_to_operating_cash_flow
#                               13.744826529
#                       ev_to_free_cash_flow
#                               13.744826529
#                             earnings_yield
#                                0.000000000
#                       free_cash_flow_yield
#                                4.552654438
#                         net_debt_to_ebitda
#                               26.845843340
#                              current_ratio
#                               21.153747892
#                             income_quality
#                                0.020438404
#                            sg&a_to_revenue
#                                0.020438404
#                             r&d_to_revenue
#                                0.030657606
#                intangibles_to_total_assets
#                                0.005109601
#               capex_to_operating_cash_flow
#                                0.000000000
#                           capex_to_revenue
#                                0.000000000
#                      capex_to_depreciation
#                                0.010219202
#         stockbased_compensation_to_revenue
#                                0.035767207
#                              graham_number
#                               13.474017679
#                              graham_netnet
#                                4.476010424
#                            working_capital
#                               21.128199888
#                       tangible_asset_value
#                                0.005109601
#                    net_current_asset_value
#                                4.271626386
#                           invested_capital
#                                0.025548005
#                        average_receivables
#                                0.495631291
#                           average_payables
#                                0.485412089
#                          average_inventory
#                                0.490521690
#                     days_sales_outstanding
#                                0.005109601
#                  days_of_inventory_on_hand
#                                0.005109601
#                       receivables_turnover
#                                0.510960094
#                            capex_per_share
#                                0.286137653
#                        gross_profit_growth
#                                0.127740024
#                                ebit_growth
#                                0.137959225
#                    operating_income_growth
#                                0.127740024
#                          net_income_growth
#                                0.301466455
#                                 eps_growth
#                                0.618261714
#                         eps_diluted_growth
#                                0.746001737
#             weighted_average_shares_growth
#                                1.839456338
#     weighted_average_shares_diluted_growth
#                                9.365898523
#                 dividends_per_share_growth
#                                0.439425681
#                 operating_cash_flow_growth
#                                0.143068826
#                      free_cash_flow_growth
#                                0.464973686
#             10y_revenue_growth_(per_share)
#                               35.920494609
#              5y_revenue_growth_(per_share)
#                               19.947882070
#              3y_revenue_growth_(per_share)
#                               10.065913852
#        10y_operating_cf_growth_(per_share)
#                               35.680343365
#         5y_operating_cf_growth_(per_share)
#                               19.830361249
#         3y_operating_cf_growth_(per_share)
#                                9.994379439
#          10y_net_income_growth_(per_share)
#                               35.920494609
#           5y_net_income_growth_(per_share)
#                               19.947882070
#           3y_net_income_growth_(per_share)
#                               10.065913852
# 10y_shareholders_equity_growth_(per_share)
#                               36.707373154
#  5y_shareholders_equity_growth_(per_share)
#                               21.082213479
#  3y_shareholders_equity_growth_(per_share)
#                               11.072505237
#  10y_dividend_per_share_growth_(per_share)
#                               34.147463083
#   5y_dividend_per_share_growth_(per_share)
#                               16.846354300
#   3y_dividend_per_share_growth_(per_share)
#                                6.867303664
#                         receivables_growth
#                                0.500740892
#                           inventory_growth
#                                0.495631291
#                               asset_growth
#                                0.495631291
#                book_value_per_share_growth
#                                2.094936385
#                                debt_growth
#                                0.935056972
#                         r&d_expense_growth
#                                0.418987277
#                       sg&a_expenses_growth
#                                0.306576056
#                               payout_ratio
#                                0.332124061
#                          interest_coverage
#                                0.000000000
#                          net_profit_margin
#                                4.368708804
#                             dividend_yield
#                                3.704460682
#                                   pe_ratio
#                                0.000000000
#                                 pfcf_ratio
#                                0.000000000
#                                 pocf_ratio
#                                4.552654438
#                       price_to_sales_ratio
#                                0.025548005
#                  days_payables_outstanding
#                                0.005109601
#                   free_cash_flow_per_share
#                                0.286137653
#                                        roe
#                                0.045986408
#                                  ptb_ratio
#                               13.453579275
#                                   pb_ratio
#                               13.453579275
#              operating_cash_flow_per_share
#                                0.286137653
#                             cash_per_share
#                                0.286137653
#                    shorttermcoverageratios
#                                   42.71626
# 10y_shareholders_equity_growth_(per_share)
#                                   36.70737
#             10y_revenue_growth_(per_share)
#                                   35.92049
#          10y_net_income_growth_(per_share)
#                                   35.92049
#        10y_operating_cf_growth_(per_share)
#                                   35.68034
#  10y_dividend_per_share_growth_(per_share)
#                                   34.14746
#                 priceearningstogrowthratio
#                                   33.78468
#                        dividendpayoutratio
#                                   33.78468
#                                   niperebt
#                                   32.92627
#                           effectivetaxrate
#                                   32.92627
#                                 ebtperebit
#                                   28.80793
#                         net_debt_to_ebitda
#                                   26.84584
#                                   net_debt
#                                   26.75898
#                               other_assets
#                                   26.30423
#                         pricecashflowratio
#                                   23.49905
#         freecashflowoperatingcashflowratio
#                                   23.25379
#                    enterprisevaluemultiple
#                                   23.19759
#                        cashflowtodebtratio
#                                   21.46543
#                              current_ratio
#                                   21.15375
#                             returnonassets
#                                   21.14864
#               total_noncurrent_liabilities
#                                   21.14353
#                    returnoncapitalemployed
#                                   21.12820
#                            working_capital
#                                   21.12820
#                    total_noncurrent_assets
#                                   21.09243
#  5y_shareholders_equity_growth_(per_share)
#                                   21.08221

# %%
library(missForest)
library(imputeMissings)

# %%
missing <- data[,-c(1:7)]

imputedm <- impute(missing, method = "median/mode")

# %%
#summary(imputedm)

# %%
#Combining the sets with the original data
imputedm <- cbind(data[,c(1:7)], imputedm)
dim(imputedm)
# Out:
# [1] 19571   171

# %%
na <- apply(is.na(imputedm),2,sum)
max(na)
# Out:
# [1] 0

# %% [markdown]
# ### Uniformity
# Are all variables measured using compatible units? Or are there monetary values in different forms of currency? Or something else entirely? If any of these issues are applicable to your data, design and implement a solution.

# %%
#Planning to implement scaling in the next stage

# %% [markdown]
# ### Additional Cleaning
# If your data set has any other issues you have noticed, you should handle them here.

# %%
#No additional cleaning was performed at this time

# %% [markdown]
# ## Save the Prepared Set

# %%
write_csv(data, "data/clean_financial.csv")
write_csv(imputedm, "data/imputedm_financial.csv")

# %% [markdown]
# ## Outcome
# At this point you should have an analytic data set prepared for data modeling. You should also be able to account for any changes you have made in the data. Do this now.

# %% [markdown]
# ##### The following changes were made to the data set:
#  - Duplicates: Any duplicate columns were removed from the data set. This was done by first using the duplicated function to identify identical columns. Then, I looked at the columns sums to identify additional duplicate variables. In the end, about 20 variables were duplicated.
#  - Variable Names: The variables names were cleaned up so that they were consistent. Spaces and dashes were removed, all letters were lower-cased, and underscores were added between most words.
#  - Categorical Encoding: A new variable "sector_num" was created as the numeric version of the categorical variable "sector" to aid in machine learning modeling.
#  - Missing Data: The missing data was cleaned in the following manner:
#       1. Any row with missing values greater than 50 was removed
#       2. Any column with missing values greater than 15% was removed
#       3. The remaining values were imputed using the median value for now
#       4. The plan is to use the complete data set to identify which variables are relevant first. Then I will impute on those variables and re-train my data set. Trying to use random forest to impute the missing values at this stage was far too time consuming in R at this stage.
