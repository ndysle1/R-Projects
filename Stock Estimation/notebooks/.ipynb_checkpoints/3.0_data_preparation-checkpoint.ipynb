# %% [markdown]
# # Data Preparation

# %% [markdown]
# ### Settings/Functions
# Read in settings and functions.

# %%
libraries <-c('here','missForest','stringr','imputeMissings')
suppressWarnings(lapply(libraries, require, character.only = TRUE))
suppressWarnings(source(here::here('Stock Estimation', 'settings.R')))
# Out:
# [[1]]
# [1] TRUE
#
# [[2]]
# [1] TRUE
#
# [[3]]
# [1] TRUE
#
# [[4]]
# [1] TRUE

# %% [markdown]
# ### Data
# Read in the final data set from the data preparation notebook.

# %%
data <- fread(paste0(dir$final_data,'combined_financial.csv'))

# %% [markdown]
# ## More Cleaning

# %% [markdown]
# ### Duplicates
# Deal with any duplicate rows/columns (or, contrarily, any empty rows/columns), if applicable.

# %%
#Checking for duplicate column sums
dups <- data[ , which(duplicated(t(data)))]
dups <- names(dups)
dups
# Out:
#  [1] "nIperEBT"                  "eBTperEBIT"
#  [3] "eBITperRevenue"            "cashFlowCoverageRatios"
#  [5] "Debt to Equity"            "Debt to Assets"
#  [7] "ROIC"                      "Return on Tangible Assets"
#  [9] "Payables Turnover"         "Inventory Turnover"

# %%
#Removing any duplicate column sums after verifying them
data <- data %>% dplyr::select(-c(dups))
dim(data)
# Out:
# [1] 22073   213

# %%
#Looking for missing values & evaluating list of variable names
na <- apply(is.na(data),2,sum)
max(na)
# NOTE: The following code has been commmented out due to the length of its output.
#print(na)
head(sort(na, decreasing = TRUE), n=25)
# Out:
# [1] 10744
#                    shortTermCoverageRatios
#                                      10744
# 10Y Shareholders Equity Growth (per Share)
#                                       9680
#             10Y Revenue Growth (per Share)
#                                       9532
#          10Y Net Income Growth (per Share)
#                                       9532
#        10Y Operating CF Growth (per Share)
#                                       9478
#  10Y Dividend per Share Growth (per Share)
#                                       9177
#                 priceEarningsToGrowthRatio
#                                       9079
#                        dividendPayoutRatio
#                                       9079
#                                   niperEBT
#                                       8595
#                           effectiveTaxRate
#                                       8595
#                                 ebtperEBIT
#                                       8007
#                         Net Debt to EBITDA
#                                       7715
#                         priceCashFlowRatio
#                                       7064
#                    enterpriseValueMultiple
#                                       6944
#                                   Net Debt
#                                       6859
#                               Other Assets
#                                       6756
#  5Y Shareholders Equity Growth (per Share)
#                                       6610
#         freeCashFlowOperatingCashFlowRatio
#                                       6588
#                             returnOnAssets
#                                       6535
#                              Current ratio
#                                       6516
#                            Working Capital
#                                       6510
#                    returnOnCapitalEmployed
#                                       6509
#              5Y Revenue Growth (per Share)
#                                       6401
#           5Y Net Income Growth (per Share)
#                                       6401
#         5Y Operating CF Growth (per Share)
#                                       6364

# %%
#Merging and dropping duplicated variable names
#view(data[, c("Payout Ratio", "payoutRatio")])
data <- Name_Changer(dat=data,x='Payout Ratio',y='payoutRatio')

#view(data[, c('interestCoverage', 'Interest Coverage')])
data <- Name_Changer(dat=data,x='Interest Coverage',y='interestCoverage')

#view(data[, c('netProfitMargin', 'Net Profit Margin')])
data <- Name_Changer(dat=data,x='Net Profit Margin',y='netProfitMargin')

#view(data[, c('Dividend Yield', 'dividendYield')])
data <- Name_Changer(dat=data,x='Dividend Yield',y='dividendYield')

#view(data[, c('PE ratio', 'priceEarningsRatio')])
data <- Name_Changer(dat=data,x='PE ratio',y='priceEarningsRatio')

#view(data[, c('priceToFreeCashFlowsRatio', 'PFCF ratio')])
data <- Name_Changer(dat=data,x='PFCF ratio',y='priceToFreeCashFlowsRatio')

#view(data[, c('priceToOperatingCashFlowsRatio', 'POCF ratio')])
data <- Name_Changer(dat=data,x='POCF ratio',y='priceToOperatingCashFlowsRatio')

#view(data[, c('priceToSalesRatio', 'Price to Sales Ratio')])
data <- Name_Changer(dat=data,x='Price to Sales Ratio',y='priceToSalesRatio')

#view(data[, c('Days Payables Outstanding', 'daysOfPayablesOutstanding')])
data <- Name_Changer(dat=data,x='Days Payables Outstanding',y='daysOfPayablesOutstanding')

#view(data[, c('Free Cash Flow per Share', 'freeCashFlowPerShare')])
data <- Name_Changer(dat=data,x='Free Cash Flow per Share',y='freeCashFlowPerShare')

#view(data[, c('ROE', 'returnOnEquity')])
data <- Name_Changer(dat=data,x='ROE',y='returnOnEquity')

#view(data[, c('priceToBookRatio', 'PTB ratio')])
data <- Name_Changer(dat=data,x='PTB ratio',y='priceToBookRatio')

#view(data[, c('priceBookValueRatio', 'PB ratio')])
data <- Name_Changer(dat=data,x='PB ratio',y='priceBookValueRatio')

#view(data[, c('operatingCashFlowPerShare', 'Operating Cash Flow per Share')])
data <- Name_Changer(dat=data,x='Operating Cash Flow per Share',y='operatingCashFlowPerShare')

#view(data[, c('Cash per Share', 'cashPerShare')])
data <- Name_Changer(dat=data,x='Cash per Share',y='cashPerShare')

dim(data)
# Out:
# [1] 22073   198

# %% [markdown]
# ### Variable Names
# Depending on your data set, variables may have names with strange symbols, which can making loading, saving, and subsetting data difficult. If applicable, you should deal with this now.

# %%
#Checking variable names
names(data)
# Out:
#   [1] "Stock"
#   [2] "nextYR_PRICE_VAR"
#   [3] "Class"
#   [4] "Year"
#   [5] "Sector"
#   [6] "Revenue"
#   [7] "Revenue Growth"
#   [8] "Cost of Revenue"
#   [9] "Gross Profit"
#  [10] "R&D Expenses"
#  [11] "SG&A Expense"
#  [12] "Operating Expenses"
#  [13] "Operating Income"
#  [14] "Interest Expense"
#  [15] "Earnings before Tax"
#  [16] "Income Tax Expense"
#  [17] "Net Income - Non-Controlling int"
#  [18] "Net Income - Discontinued ops"
#  [19] "Net Income"
#  [20] "Preferred Dividends"
#  [21] "Net Income Com"
#  [22] "EPS"
#  [23] "EPS Diluted"
#  [24] "Weighted Average Shs Out"
#  [25] "Weighted Average Shs Out (Dil)"
#  [26] "Dividend per Share"
#  [27] "Gross Margin"
#  [28] "EBITDA Margin"
#  [29] "EBIT Margin"
#  [30] "Profit Margin"
#  [31] "Free Cash Flow margin"
#  [32] "EBITDA"
#  [33] "EBIT"
#  [34] "Consolidated Income"
#  [35] "Earnings Before Tax Margin"
#  [36] "Cash and cash equivalents"
#  [37] "Short-term investments"
#  [38] "Cash and short-term investments"
#  [39] "Receivables"
#  [40] "Inventories"
#  [41] "Total current assets"
#  [42] "Property, Plant & Equipment Net"
#  [43] "Goodwill and Intangible Assets"
#  [44] "Long-term investments"
#  [45] "Tax assets"
#  [46] "Total non-current assets"
#  [47] "Total assets"
#  [48] "Payables"
#  [49] "Short-term debt"
#  [50] "Total current liabilities"
#  [51] "Long-term debt"
#  [52] "Total debt"
#  [53] "Deferred revenue"
#  [54] "Tax Liabilities"
#  [55] "Deposit Liabilities"
#  [56] "Total non-current liabilities"
#  [57] "Total liabilities"
#  [58] "Other comprehensive income"
#  [59] "Retained earnings (deficit)"
#  [60] "Total shareholders equity"
#  [61] "Investments"
#  [62] "Net Debt"
#  [63] "Other Assets"
#  [64] "Other Liabilities"
#  [65] "Depreciation & Amortization"
#  [66] "Stock-based compensation"
#  [67] "Operating Cash Flow"
#  [68] "Capital Expenditure"
#  [69] "Acquisitions and disposals"
#  [70] "Investment purchases and sales"
#  [71] "Investing Cash flow"
#  [72] "Issuance (repayment) of debt"
#  [73] "Issuance (buybacks) of shares"
#  [74] "Dividend payments"
#  [75] "Financing Cash Flow"
#  [76] "Effect of forex changes on cash"
#  [77] "Net cash flow / Change in cash"
#  [78] "Free Cash Flow"
#  [79] "Net Cash/Marketcap"
#  [80] "priceCashFlowRatio"
#  [81] "priceEarningsToGrowthRatio"
#  [82] "priceSalesRatio"
#  [83] "enterpriseValueMultiple"
#  [84] "priceFairValue"
#  [85] "ebitperRevenue"
#  [86] "ebtperEBIT"
#  [87] "niperEBT"
#  [88] "grossProfitMargin"
#  [89] "pretaxProfitMargin"
#  [90] "effectiveTaxRate"
#  [91] "returnOnAssets"
#  [92] "returnOnCapitalEmployed"
#  [93] "payablesTurnover"
#  [94] "inventoryTurnover"
#  [95] "fixedAssetTurnover"
#  [96] "assetTurnover"
#  [97] "currentRatio"
#  [98] "quickRatio"
#  [99] "cashRatio"
# [100] "daysOfSalesOutstanding"
# [101] "daysOfInventoryOutstanding"
# [102] "debtRatio"
# [103] "debtEquityRatio"
# [104] "longtermDebtToCapitalization"
# [105] "totalDebtToCapitalization"
# [106] "cashFlowToDebtRatio"
# [107] "companyEquityMultiplier"
# [108] "operatingCashFlowSalesRatio"
# [109] "freeCashFlowOperatingCashFlowRatio"
# [110] "shortTermCoverageRatios"
# [111] "capitalExpenditureCoverageRatios"
# [112] "dividendpaidAndCapexCoverageRatios"
# [113] "dividendPayoutRatio"
# [114] "Revenue per Share"
# [115] "Net Income per Share"
# [116] "Book Value per Share"
# [117] "Tangible Book Value per Share"
# [118] "Shareholders Equity per Share"
# [119] "Interest Debt per Share"
# [120] "Market Cap"
# [121] "Enterprise Value"
# [122] "EV to Sales"
# [123] "Enterprise Value over EBITDA"
# [124] "EV to Operating cash flow"
# [125] "EV to Free cash flow"
# [126] "Earnings Yield"
# [127] "Free Cash Flow Yield"
# [128] "Net Debt to EBITDA"
# [129] "Current ratio"
# [130] "Income Quality"
# [131] "SG&A to Revenue"
# [132] "R&D to Revenue"
# [133] "Intangibles to Total Assets"
# [134] "Capex to Operating Cash Flow"
# [135] "Capex to Revenue"
# [136] "Capex to Depreciation"
# [137] "Stock-based compensation to Revenue"
# [138] "Graham Number"
# [139] "Graham Net-Net"
# [140] "Working Capital"
# [141] "Tangible Asset Value"
# [142] "Net Current Asset Value"
# [143] "Invested Capital"
# [144] "Average Receivables"
# [145] "Average Payables"
# [146] "Average Inventory"
# [147] "Days Sales Outstanding"
# [148] "Days of Inventory on Hand"
# [149] "Receivables Turnover"
# [150] "Capex per Share"
# [151] "Gross Profit Growth"
# [152] "EBIT Growth"
# [153] "Operating Income Growth"
# [154] "Net Income Growth"
# [155] "EPS Growth"
# [156] "EPS Diluted Growth"
# [157] "Weighted Average Shares Growth"
# [158] "Weighted Average Shares Diluted Growth"
# [159] "Dividends per Share Growth"
# [160] "Operating Cash Flow growth"
# [161] "Free Cash Flow growth"
# [162] "10Y Revenue Growth (per Share)"
# [163] "5Y Revenue Growth (per Share)"
# [164] "3Y Revenue Growth (per Share)"
# [165] "10Y Operating CF Growth (per Share)"
# [166] "5Y Operating CF Growth (per Share)"
# [167] "3Y Operating CF Growth (per Share)"
# [168] "10Y Net Income Growth (per Share)"
# [169] "5Y Net Income Growth (per Share)"
# [170] "3Y Net Income Growth (per Share)"
# [171] "10Y Shareholders Equity Growth (per Share)"
# [172] "5Y Shareholders Equity Growth (per Share)"
# [173] "3Y Shareholders Equity Growth (per Share)"
# [174] "10Y Dividend per Share Growth (per Share)"
# [175] "5Y Dividend per Share Growth (per Share)"
# [176] "3Y Dividend per Share Growth (per Share)"
# [177] "Receivables growth"
# [178] "Inventory Growth"
# [179] "Asset Growth"
# [180] "Book Value per Share Growth"
# [181] "Debt Growth"
# [182] "R&D Expense Growth"
# [183] "SG&A Expenses Growth"
# [184] "Payout Ratio"
# [185] "Interest Coverage"
# [186] "Net Profit Margin"
# [187] "Dividend Yield"
# [188] "PE ratio"
# [189] "PFCF ratio"
# [190] "POCF ratio"
# [191] "Price to Sales Ratio"
# [192] "Days Payables Outstanding"
# [193] "Free Cash Flow per Share"
# [194] "ROE"
# [195] "PTB ratio"
# [196] "PB ratio"
# [197] "Operating Cash Flow per Share"
# [198] "Cash per Share"

# %%
#Changing all names to lower case and replacing spaces with "_"
#Amending various features to make more compatible models
names(data) <- str_trim(names(data), side = "both")
names(data) <- str_to_lower(names(data), locale = "en")
names(data) <- str_replace_all(names(data), " ", "_")
names(data) <- str_replace_all(names(data), "-", "")
names(data) <- str_replace_all(names(data), "&", ".")
names(data) <- str_replace_all(names(data), "\\(", "")
names(data) <- str_replace_all(names(data), "\\)", "")
names(data) <- str_replace_all(names(data), "3y", "three_yr")
names(data) <- str_replace_all(names(data), "5y", "five_yr")
names(data) <- str_replace_all(names(data), "10y", "ten_yr")
names(data) <- str_replace_all(names(data), "\\\\", "")
names(data) <- str_replace_all(names(data), "////", "_")
names(data) <- str_replace_all(names(data), ",", "")
names(data) <- str_replace_all(names(data), "_._", "_")
names(data) <- str_replace_all(names(data), "/", "_")
names(data)
# Out:
#   [1] "stock"
#   [2] "nextyr_price_var"
#   [3] "class"
#   [4] "year"
#   [5] "sector"
#   [6] "revenue"
#   [7] "revenue_growth"
#   [8] "cost_of_revenue"
#   [9] "gross_profit"
#  [10] "r.d_expenses"
#  [11] "sg.a_expense"
#  [12] "operating_expenses"
#  [13] "operating_income"
#  [14] "interest_expense"
#  [15] "earnings_before_tax"
#  [16] "income_tax_expense"
#  [17] "net_income__noncontrolling_int"
#  [18] "net_income__discontinued_ops"
#  [19] "net_income"
#  [20] "preferred_dividends"
#  [21] "net_income_com"
#  [22] "eps"
#  [23] "eps_diluted"
#  [24] "weighted_average_shs_out"
#  [25] "weighted_average_shs_out_dil"
#  [26] "dividend_per_share"
#  [27] "gross_margin"
#  [28] "ebitda_margin"
#  [29] "ebit_margin"
#  [30] "profit_margin"
#  [31] "free_cash_flow_margin"
#  [32] "ebitda"
#  [33] "ebit"
#  [34] "consolidated_income"
#  [35] "earnings_before_tax_margin"
#  [36] "cash_and_cash_equivalents"
#  [37] "shortterm_investments"
#  [38] "cash_and_shortterm_investments"
#  [39] "receivables"
#  [40] "inventories"
#  [41] "total_current_assets"
#  [42] "property_plant_equipment_net"
#  [43] "goodwill_and_intangible_assets"
#  [44] "longterm_investments"
#  [45] "tax_assets"
#  [46] "total_noncurrent_assets"
#  [47] "total_assets"
#  [48] "payables"
#  [49] "shortterm_debt"
#  [50] "total_current_liabilities"
#  [51] "longterm_debt"
#  [52] "total_debt"
#  [53] "deferred_revenue"
#  [54] "tax_liabilities"
#  [55] "deposit_liabilities"
#  [56] "total_noncurrent_liabilities"
#  [57] "total_liabilities"
#  [58] "other_comprehensive_income"
#  [59] "retained_earnings_deficit"
#  [60] "total_shareholders_equity"
#  [61] "investments"
#  [62] "net_debt"
#  [63] "other_assets"
#  [64] "other_liabilities"
#  [65] "depreciation_amortization"
#  [66] "stockbased_compensation"
#  [67] "operating_cash_flow"
#  [68] "capital_expenditure"
#  [69] "acquisitions_and_disposals"
#  [70] "investment_purchases_and_sales"
#  [71] "investing_cash_flow"
#  [72] "issuance_repayment_of_debt"
#  [73] "issuance_buybacks_of_shares"
#  [74] "dividend_payments"
#  [75] "financing_cash_flow"
#  [76] "effect_of_forex_changes_on_cash"
#  [77] "net_cash_flow_change_in_cash"
#  [78] "free_cash_flow"
#  [79] "net_cash_marketcap"
#  [80] "pricecashflowratio"
#  [81] "priceearningstogrowthratio"
#  [82] "pricesalesratio"
#  [83] "enterprisevaluemultiple"
#  [84] "pricefairvalue"
#  [85] "ebitperrevenue"
#  [86] "ebtperebit"
#  [87] "niperebt"
#  [88] "grossprofitmargin"
#  [89] "pretaxprofitmargin"
#  [90] "effectivetaxrate"
#  [91] "returnonassets"
#  [92] "returnoncapitalemployed"
#  [93] "payablesturnover"
#  [94] "inventoryturnover"
#  [95] "fixedassetturnover"
#  [96] "assetturnover"
#  [97] "currentratio"
#  [98] "quickratio"
#  [99] "cashratio"
# [100] "daysofsalesoutstanding"
# [101] "daysofinventoryoutstanding"
# [102] "debtratio"
# [103] "debtequityratio"
# [104] "longtermdebttocapitalization"
# [105] "totaldebttocapitalization"
# [106] "cashflowtodebtratio"
# [107] "companyequitymultiplier"
# [108] "operatingcashflowsalesratio"
# [109] "freecashflowoperatingcashflowratio"
# [110] "shorttermcoverageratios"
# [111] "capitalexpenditurecoverageratios"
# [112] "dividendpaidandcapexcoverageratios"
# [113] "dividendpayoutratio"
# [114] "revenue_per_share"
# [115] "net_income_per_share"
# [116] "book_value_per_share"
# [117] "tangible_book_value_per_share"
# [118] "shareholders_equity_per_share"
# [119] "interest_debt_per_share"
# [120] "market_cap"
# [121] "enterprise_value"
# [122] "ev_to_sales"
# [123] "enterprise_value_over_ebitda"
# [124] "ev_to_operating_cash_flow"
# [125] "ev_to_free_cash_flow"
# [126] "earnings_yield"
# [127] "free_cash_flow_yield"
# [128] "net_debt_to_ebitda"
# [129] "current_ratio"
# [130] "income_quality"
# [131] "sg.a_to_revenue"
# [132] "r.d_to_revenue"
# [133] "intangibles_to_total_assets"
# [134] "capex_to_operating_cash_flow"
# [135] "capex_to_revenue"
# [136] "capex_to_depreciation"
# [137] "stockbased_compensation_to_revenue"
# [138] "graham_number"
# [139] "graham_netnet"
# [140] "working_capital"
# [141] "tangible_asset_value"
# [142] "net_current_asset_value"
# [143] "invested_capital"
# [144] "average_receivables"
# [145] "average_payables"
# [146] "average_inventory"
# [147] "days_sales_outstanding"
# [148] "days_of_inventory_on_hand"
# [149] "receivables_turnover"
# [150] "capex_per_share"
# [151] "gross_profit_growth"
# [152] "ebit_growth"
# [153] "operating_income_growth"
# [154] "net_income_growth"
# [155] "eps_growth"
# [156] "eps_diluted_growth"
# [157] "weighted_average_shares_growth"
# [158] "weighted_average_shares_diluted_growth"
# [159] "dividends_per_share_growth"
# [160] "operating_cash_flow_growth"
# [161] "free_cash_flow_growth"
# [162] "ten_yr_revenue_growth_per_share"
# [163] "five_yr_revenue_growth_per_share"
# [164] "three_yr_revenue_growth_per_share"
# [165] "ten_yr_operating_cf_growth_per_share"
# [166] "five_yr_operating_cf_growth_per_share"
# [167] "three_yr_operating_cf_growth_per_share"
# [168] "ten_yr_net_income_growth_per_share"
# [169] "five_yr_net_income_growth_per_share"
# [170] "three_yr_net_income_growth_per_share"
# [171] "ten_yr_shareholders_equity_growth_per_share"
# [172] "five_yr_shareholders_equity_growth_per_share"
# [173] "three_yr_shareholders_equity_growth_per_share"
# [174] "ten_yr_dividend_per_share_growth_per_share"
# [175] "five_yr_dividend_per_share_growth_per_share"
# [176] "three_yr_dividend_per_share_growth_per_share"
# [177] "receivables_growth"
# [178] "inventory_growth"
# [179] "asset_growth"
# [180] "book_value_per_share_growth"
# [181] "debt_growth"
# [182] "r.d_expense_growth"
# [183] "sg.a_expenses_growth"
# [184] "payout_ratio"
# [185] "interest_coverage"
# [186] "net_profit_margin"
# [187] "dividend_yield"
# [188] "pe_ratio"
# [189] "pfcf_ratio"
# [190] "pocf_ratio"
# [191] "price_to_sales_ratio"
# [192] "days_payables_outstanding"
# [193] "free_cash_flow_per_share"
# [194] "roe"
# [195] "ptb_ratio"
# [196] "pb_ratio"
# [197] "operating_cash_flow_per_share"
# [198] "cash_per_share"

# %% [markdown]
# ### Categorical Encoding
# Are there any categorical variables in your data? If so, transform them so that they can be used to train a machine learning algorithm.

# %%
#Categorical Encoding
data[, sector := as.factor(sector)]
data[, sector_num := as.numeric(sector)]

#Reordering data to put "sector" with "sector_num"
data <- data %>%
  dplyr::select('stock','nextyr_price_var','class','year','sector','sector_num', everything())

# %% [markdown]
# ### Missing Data
# If missing data is present (ie, NaN values), what is the best way to deal with it? Should values be imputed (and if so, how)? Or should they simply be filled? How will each option will affect the ultimate outcome of your model? Design and implement a solution.

# %%
na <- apply(is.na(data),2,sum)
#print(na)
max(na)
#sort(na, decreasing = TRUE)
head(sort(na, decreasing = TRUE), n=25)
summary(na)
# Out:
# [1] 10744
#                      shorttermcoverageratios
#                                        10744
#  ten_yr_shareholders_equity_growth_per_share
#                                         9680
#              ten_yr_revenue_growth_per_share
#                                         9532
#           ten_yr_net_income_growth_per_share
#                                         9532
#         ten_yr_operating_cf_growth_per_share
#                                         9478
#   ten_yr_dividend_per_share_growth_per_share
#                                         9177
#                   priceearningstogrowthratio
#                                         9079
#                          dividendpayoutratio
#                                         9079
#                                     niperebt
#                                         8595
#                             effectivetaxrate
#                                         8595
#                                   ebtperebit
#                                         8007
#                           net_debt_to_ebitda
#                                         7715
#                           pricecashflowratio
#                                         7064
#                      enterprisevaluemultiple
#                                         6944
#                                     net_debt
#                                         6859
#                                 other_assets
#                                         6756
# five_yr_shareholders_equity_growth_per_share
#                                         6610
#           freecashflowoperatingcashflowratio
#                                         6588
#                               returnonassets
#                                         6535
#                                current_ratio
#                                         6516
#                              working_capital
#                                         6510
#                      returnoncapitalemployed
#                                         6509
#             five_yr_revenue_growth_per_share
#                                         6401
#          five_yr_net_income_growth_per_share
#                                         6401
#        five_yr_operating_cf_growth_per_share
#                                         6364
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       0    1835    2315    3069    3197   10744

# %%
#Checking how many rows are complete
sum(complete.cases(data))

#Checking for NA across rows
data$na <- rowSums(is.na(data))
max(data$na)
head(sort(data$na, decreasing = TRUE),n = 20)
summary(data$na)
# Out:
# [1] 3454
# [1] 193
#  [1] 193 193 193 193 193 193 193 193 193 193 193 193 193 193 193 193 193 193 193
# [20] 193
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.00    2.00   10.00   27.67   23.00  193.00

# %%
#Found that 50 was a good cut off for dropping rows
drop <- data %>% 
  filter(na >= 50)
dim(drop)

data <- data %>%
  filter(na <= 50)

data <- dplyr::select(data, -c(na))

#Re-checking the NAs across columns
na <- apply(is.na(data),2,sum)
max(na)
# NOTE: The following code has been commmented out due to the length of its output.
#print(na)
#sort(na, decreasing = TRUE)
head(sort(na, decreasing = TRUE), n=25)
# Out:
# [1] 2500  200
# [1] 8380
#                      shorttermcoverageratios
#                                         8380
#  ten_yr_shareholders_equity_growth_per_share
#                                         7209
#              ten_yr_revenue_growth_per_share
#                                         7055
#           ten_yr_net_income_growth_per_share
#                                         7055
#         ten_yr_operating_cf_growth_per_share
#                                         7008
#   ten_yr_dividend_per_share_growth_per_share
#                                         6708
#                   priceearningstogrowthratio
#                                         6636
#                          dividendpayoutratio
#                                         6636
#                                     niperebt
#                                         6466
#                             effectivetaxrate
#                                         6466
#                                   ebtperebit
#                                         5656
#                           net_debt_to_ebitda
#                                         5270
#                                     net_debt
#                                         5253
#                                 other_assets
#                                         5164
#                           pricecashflowratio
#                                         4623
#           freecashflowoperatingcashflowratio
#                                         4569
#                      enterprisevaluemultiple
#                                         4559
#                          cashflowtodebtratio
#                                         4215
# five_yr_shareholders_equity_growth_per_share
#                                         4151
#                                current_ratio
#                                         4141
#                               returnonassets
#                                         4140
#                 total_noncurrent_liabilities
#                                         4139
#                      returnoncapitalemployed
#                                         4136
#                              working_capital
#                                         4136
#                      total_noncurrent_assets
#                                         4129

# %%
#Keeping only columns with less than ~15 percent missing
perc <- apply(data,2,Perc_Missing)
max(perc)
# NOTE: The following code has been commmented out due to the length of its output.
#print(perc)
#sort(perc, decreasing = TRUE)
head(sort(perc, decreasing = TRUE), n=25)

#Choosing to only keep variables with less than 15% missing data
data <- data[, which(apply(data,2,Perc_Missing) < 15.0)]
# Out:
# [1] 42.77256
#                      shorttermcoverageratios
#                                     42.77256
#  ten_yr_shareholders_equity_growth_per_share
#                                     36.79563
#              ten_yr_revenue_growth_per_share
#                                     36.00960
#           ten_yr_net_income_growth_per_share
#                                     36.00960
#         ten_yr_operating_cf_growth_per_share
#                                     35.76970
#   ten_yr_dividend_per_share_growth_per_share
#                                     34.23846
#                   priceearningstogrowthratio
#                                     33.87097
#                          dividendpayoutratio
#                                     33.87097
#                                     niperebt
#                                     33.00327
#                             effectivetaxrate
#                                     33.00327
#                                   ebtperebit
#                                     28.86893
#                           net_debt_to_ebitda
#                                     26.89873
#                                     net_debt
#                                     26.81196
#                                 other_assets
#                                     26.35770
#                           pricecashflowratio
#                                     23.59637
#           freecashflowoperatingcashflowratio
#                                     23.32074
#                      enterprisevaluemultiple
#                                     23.26970
#                          cashflowtodebtratio
#                                     21.51388
# five_yr_shareholders_equity_growth_per_share
#                                     21.18722
#                                current_ratio
#                                     21.13618
#                               returnonassets
#                                     21.13107
#                 total_noncurrent_liabilities
#                                     21.12597
#                      returnoncapitalemployed
#                                     21.11066
#                              working_capital
#                                     21.11066
#                      total_noncurrent_assets
#                                     21.07493

# %%
missing <- select(data, -c('stock','nextyr_price_var','class','year','sector','sector_num'))

imputedm <- impute(missing, method = "median/mode")

# %%
summary(imputedm)
# Out:
#     revenue           revenue_growth     cost_of_revenue
#  Min.   :-6.276e+08   Min.   :   -3.46   Min.   :-2.987e+09
#  1st Qu.: 6.704e+07   1st Qu.:   -0.01   1st Qu.: 3.136e+06
#  Median : 4.689e+08   Median :    0.06   Median : 1.512e+08
#  Mean   : 4.807e+09   Mean   :    3.65   Mean   : 2.899e+09
#  3rd Qu.: 2.338e+09   3rd Qu.:    0.18   3rd Qu.: 1.150e+09
#  Max.   : 5.003e+11   Max.   :42138.66   Max.   : 3.771e+11
#   gross_profit         r.d_expenses         sg.a_expense
#  Min.   :-1.281e+10   Min.   :-1.098e+08   Min.   :-1.402e+08
#  1st Qu.: 3.406e+07   1st Qu.: 0.000e+00   1st Qu.: 1.816e+07
#  Median : 2.075e+08   Median : 0.000e+00   Median : 8.164e+07
#  Mean   : 1.904e+09   Mean   : 9.809e+07   Mean   : 8.503e+08
#  3rd Qu.: 9.022e+08   3rd Qu.: 1.205e+07   3rd Qu.: 3.651e+08
#  Max.   : 1.269e+11   Max.   : 2.884e+10   Max.   : 1.065e+11
#  operating_expenses   operating_income     interest_expense
#  Min.   :-5.496e+09   Min.   :-1.934e+10   Min.   :-5.095e+08
#  1st Qu.: 3.694e+07   1st Qu.:-4.524e+06   1st Qu.: 0.000e+00
#  Median : 1.589e+08   Median : 3.844e+07   Median : 3.678e+06
#  Mean   : 1.342e+09   Mean   : 5.664e+08   Mean   : 9.057e+07
#  3rd Qu.: 6.175e+08   3rd Qu.: 2.611e+08   3rd Qu.: 4.874e+07
#  Max.   : 1.065e+11   Max.   : 7.123e+10   Max.   : 1.845e+10
#  earnings_before_tax  income_tax_expense   net_income__noncontrolling_int
#  Min.   :-2.177e+10   Min.   :-1.471e+10   Min.   :-1.587e+09
#  1st Qu.:-8.791e+06   1st Qu.: 0.000e+00   1st Qu.: 0.000e+00
#  Median : 2.524e+07   Median : 3.588e+06   Median : 0.000e+00
#  Mean   : 4.880e+08   Mean   : 1.276e+08   Mean   : 1.337e+07
#  3rd Qu.: 2.028e+08   3rd Qu.: 4.495e+07   3rd Qu.: 0.000e+00
#  Max.   : 7.290e+10   Max.   : 2.939e+10   Max.   : 6.431e+09
#  net_income__discontinued_ops   net_income         preferred_dividends
#  Min.   :-1.591e+10           Min.   :-2.236e+10   Min.   :-161000000
#  1st Qu.: 0.000e+00           1st Qu.:-9.230e+06   1st Qu.:         0
#  Median : 0.000e+00           Median : 1.881e+07   Median :         0
#  Mean   :-2.733e+06           Mean   : 3.604e+08   Mean   :   4668664
#  3rd Qu.: 0.000e+00           3rd Qu.: 1.569e+08   3rd Qu.:         0
#  Max.   : 8.368e+09           Max.   : 5.953e+10   Max.   :2741588000
#  net_income_com            eps              eps_diluted
#  Min.   :-2.280e+10   Min.   :-101870898   Min.   :-101870898
#  1st Qu.:-9.987e+06   1st Qu.:         0   1st Qu.:         0
#  Median : 1.807e+07   Median :         1   Median :         1
#  Mean   : 3.557e+08   Mean   :    -11299   Mean   :    -11387
#  3rd Qu.: 1.543e+08   3rd Qu.:         2   3rd Qu.:         2
#  Max.   : 5.953e+10   Max.   :   8028004   Max.   :   6624003
#  weighted_average_shs_out weighted_average_shs_out_dil dividend_per_share
#  Min.   :0.000e+00        Min.   :0.000e+00            Min.   :    0.000
#  1st Qu.:1.762e+07        1st Qu.:1.627e+07            1st Qu.:    0.000
#  Median :4.397e+07        Median :4.240e+07            Median :    0.000
#  Mean   :2.582e+08        Mean   :2.616e+08            Mean   :    1.226
#  3rd Qu.:1.178e+08        3rd Qu.:1.148e+08            3rd Qu.:    0.720
#  Max.   :1.113e+11        Max.   :1.113e+11            Max.   :10100.664
#   gross_margin      ebitda_margin         ebit_margin
#  Min.   :-74.3191   Min.   :-24207.000   Min.   :-24242.000
#  1st Qu.:  0.2513   1st Qu.:     0.027   1st Qu.:     0.000
#  Median :  0.4546   Median :     0.129   Median :     0.082
#  Mean   :  0.4833   Mean   :    -8.395   Mean   :    -7.562
#  3rd Qu.:  0.7802   3rd Qu.:     0.290   3rd Qu.:     0.212
#  Max.   :  4.2531   Max.   :  1060.404   Max.   :  1056.466
#  profit_margin        free_cash_flow_margin     ebitda
#  Min.   :-24414.000   Min.   :-23256.000    Min.   :-1.648e+10
#  1st Qu.:    -0.033   1st Qu.:    -0.036    1st Qu.: 1.604e+06
#  Median :     0.043   Median :     0.045    Median : 7.168e+07
#  Mean   :    -8.820   Mean   :    -6.332    Mean   : 8.646e+08
#  3rd Qu.:     0.126   3rd Qu.:     0.152    3rd Qu.: 4.089e+08
#  Max.   :   940.041   Max.   :   689.830    Max.   : 8.381e+10
#       ebit            consolidated_income  earnings_before_tax_margin
#  Min.   :-1.871e+10   Min.   :-2.244e+10   Min.   :-24202.000
#  1st Qu.:-3.880e+06   1st Qu.:-9.204e+06   1st Qu.:    -0.026
#  Median : 3.923e+07   Median : 1.999e+07   Median :     0.060
#  Mean   : 5.804e+08   Mean   : 3.739e+08   Mean   :    -7.640
#  3rd Qu.: 2.681e+08   3rd Qu.: 1.641e+08   3rd Qu.:     0.173
#  Max.   : 7.290e+10   Max.   : 5.953e+10   Max.   :  1056.466
#  cash_and_cash_equivalents shortterm_investments cash_and_shortterm_investments
#  Min.   :0.000e+00         Min.   :0.000e+00     Min.   :0.000e+00
#  1st Qu.:1.873e+07         1st Qu.:0.000e+00     1st Qu.:2.430e+07
#  Median :7.443e+07         Median :0.000e+00     Median :9.411e+07
#  Mean   :1.552e+09         Mean   :1.228e+09     Mean   :2.566e+09
#  3rd Qu.:2.970e+08         3rd Qu.:1.306e+07     3rd Qu.:3.403e+08
#  Max.   :5.123e+11         Max.   :8.000e+11     Max.   :9.854e+11
#   receivables         inventories        total_current_assets
#  Min.   :0.000e+00   Min.   :0.000e+00   Min.   :0.000e+00
#  1st Qu.:2.196e+06   1st Qu.:0.000e+00   1st Qu.:7.445e+07
#  Median :4.466e+07   Median :1.560e+06   Median :2.790e+08
#  Mean   :8.614e+08   Mean   :4.074e+08   Mean   :4.849e+09
#  3rd Qu.:2.866e+08   3rd Qu.:1.036e+08   3rd Qu.:1.082e+09
#  Max.   :1.624e+11   Max.   :9.120e+11   Max.   :1.181e+12
#  property_plant_equipment_net goodwill_and_intangible_assets
#  Min.   :0.000e+00            Min.   :0.000e+00
#  1st Qu.:9.187e+06            1st Qu.:0.000e+00
#  Median :9.581e+07            Median :3.845e+07
#  Mean   :2.446e+09            Mean   :1.653e+09
#  3rd Qu.:8.544e+08            3rd Qu.:4.846e+08
#  Max.   :2.822e+11            Max.   :2.931e+11
#  longterm_investments   tax_assets         total_assets
#  Min.   :-8.000e+07   Min.   :0.000e+00   Min.   :2.809e+04
#  1st Qu.: 0.000e+00   1st Qu.:0.000e+00   1st Qu.:2.112e+08
#  Median : 0.000e+00   Median :0.000e+00   Median :1.174e+09
#  Mean   : 2.849e+09   Mean   :1.434e+08   Mean   :1.808e+10
#  3rd Qu.: 4.600e+07   3rd Qu.:1.566e+07   3rd Qu.:5.094e+09
#  Max.   : 9.970e+11   Max.   :4.262e+10   Max.   :2.634e+12
#     payables          shortterm_debt       total_current_liabilities
#  Min.   :-2.059e+10   Min.   :-1.375e+09   Min.   :-2.108e+10
#  1st Qu.: 2.830e+06   1st Qu.: 0.000e+00   1st Qu.: 3.165e+07
#  Median : 2.642e+07   Median : 1.535e+06   Median : 1.791e+08
#  Mean   : 8.377e+08   Mean   : 5.164e+08   Mean   : 7.123e+09
#  3rd Qu.: 1.798e+08   3rd Qu.: 3.258e+07   3rd Qu.: 9.103e+08
#  Max.   : 2.136e+11   Max.   : 2.192e+11   Max.   : 2.095e+12
#  longterm_debt          total_debt         deferred_revenue
#  Min.   :-8.446e+09   Min.   :-9.290e+09   Min.   :-2.364e+07
#  1st Qu.: 1.226e+06   1st Qu.: 5.952e+06   1st Qu.: 0.000e+00
#  Median : 1.395e+08   Median : 2.068e+08   Median : 0.000e+00
#  Mean   : 2.686e+09   Mean   : 4.124e+09   Mean   : 6.892e+11
#  3rd Qu.: 1.118e+09   3rd Qu.: 1.465e+09   3rd Qu.: 4.306e+06
#  Max.   : 7.330e+11   Max.   : 1.014e+12   Max.   : 1.350e+16
#  tax_liabilities      deposit_liabilities total_liabilities
#  Min.   :-1.784e+09   Min.   :0.000e+00   Min.   :-7.872e+09
#  1st Qu.: 0.000e+00   1st Qu.:0.000e+00   1st Qu.: 7.376e+07
#  Median : 3.450e+05   Median :0.000e+00   Median : 6.430e+08
#  Mean   : 2.524e+11   Mean   :5.073e+09   Mean   : 1.457e+10
#  3rd Qu.: 5.086e+07   3rd Qu.:0.000e+00   3rd Qu.: 3.316e+09
#  Max.   : 4.938e+15   Max.   :1.471e+12   Max.   : 2.434e+12
#  other_comprehensive_income retained_earnings_deficit total_shareholders_equity
#  Min.   :-9.478e+10         Min.   :-2.800e+11        Min.   :-1.324e+10
#  1st Qu.:-2.138e+07         1st Qu.:-1.175e+08        1st Qu.: 7.358e+07
#  Median :-2.550e+05         Median : 2.326e+07        Median : 3.602e+08
#  Mean   : 8.705e+10         Mean   : 1.987e+09        Mean   : 3.353e+09
#  3rd Qu.: 0.000e+00         3rd Qu.: 5.299e+08        3rd Qu.: 1.534e+09
#  Max.   : 1.709e+15         Max.   : 4.217e+11        Max.   : 2.671e+11
#   investments         other_liabilities    depreciation_amortization
#  Min.   :-1.614e+09   Min.   :-9.923e+10   Min.   :-8.336e+07
#  1st Qu.: 0.000e+00   1st Qu.: 9.609e+06   1st Qu.: 2.051e+06
#  Median : 1.373e+07   Median : 6.660e+07   Median : 2.040e+07
#  Mean   : 9.148e+09   Mean   : 5.833e+09   Mean   : 3.251e+08
#  3rd Qu.: 3.920e+08   3rd Qu.: 4.099e+08   3rd Qu.: 1.224e+08
#  Max.   : 2.080e+12   Max.   : 1.866e+12   Max.   : 7.510e+11
#  stockbased_compensation operating_cash_flow  capital_expenditure
#  Min.   :-137000000      Min.   :-1.127e+11   Min.   :-9.662e+10
#  1st Qu.:    500000      1st Qu.: 1.307e+06   1st Qu.:-1.254e+08
#  Median :   3824000      Median : 5.995e+07   Median :-1.689e+07
#  Mean   :  29292785      Mean   : 8.265e+08   Mean   :-3.462e+08
#  3rd Qu.:  14894750      3rd Qu.: 3.378e+08   3rd Qu.:-1.363e+06
#  Max.   :9353000000      Max.   : 9.600e+11   Max.   : 5.823e+09
#  acquisitions_and_disposals investment_purchases_and_sales investing_cash_flow
#  Min.   :-5.100e+10         Min.   :-1.930e+11             Min.   :-1.980e+11
#  1st Qu.:-1.169e+07         1st Qu.:-1.061e+07             1st Qu.:-2.867e+08
#  Median : 0.000e+00         Median : 0.000e+00             Median :-4.892e+07
#  Mean   :-1.097e+08         Mean   :-1.701e+08             Mean   :-6.422e+08
#  3rd Qu.: 0.000e+00         3rd Qu.: 0.000e+00             3rd Qu.:-1.914e+06
#  Max.   : 6.987e+10         Max.   : 1.499e+11             Max.   : 1.446e+11
#  issuance_repayment_of_debt issuance_buybacks_of_shares dividend_payments
#  Min.   :-8.488e+10         Min.   :-7.207e+10          Min.   :-1.603e+10
#  1st Qu.:-8.601e+06         1st Qu.:-8.552e+06          1st Qu.:-5.043e+07
#  Median : 0.000e+00         Median : 0.000e+00          Median : 0.000e+00
#  Mean   : 1.313e+08         Mean   :-1.150e+08          Mean   :-1.826e+08
#  3rd Qu.: 5.172e+07         3rd Qu.: 6.308e+06          3rd Qu.: 0.000e+00
#  Max.   : 6.268e+10         Max.   : 1.444e+11          Max.   : 0.000e+00
#  financing_cash_flow  effect_of_forex_changes_on_cash
#  Min.   :-1.875e+11   Min.   :-4.300e+10
#  1st Qu.:-7.735e+07   1st Qu.:-2.572e+05
#  Median : 0.000e+00   Median : 0.000e+00
#  Mean   :-4.932e+07   Mean   :-4.687e+06
#  3rd Qu.: 5.773e+07   3rd Qu.: 0.000e+00
#  Max.   : 2.260e+11   Max.   : 9.993e+09
#  net_cash_flow_change_in_cash free_cash_flow       net_cash_marketcap
#  Min.   :-1.525e+11           Min.   :-1.042e+11   Min.   :-4943.553
#  1st Qu.:-1.678e+07           1st Qu.:-1.004e+07   1st Qu.:   -0.402
#  Median : 7.226e+05           Median : 1.891e+07   Median :   -0.064
#  Mean   : 8.002e+07           Mean   : 4.370e+08   Mean   :   -0.862
#  3rd Qu.: 2.939e+07           3rd Qu.: 1.765e+08   3rd Qu.:    0.098
#  Max.   : 4.050e+11           Max.   : 9.415e+10   Max.   :  501.780
#  pricesalesratio    pricefairvalue     ebitperrevenue       grossprofitmargin
#  Min.   :     0.0   Min.   :       0   Min.   :-24242.000   Min.   :-223.4828
#  1st Qu.:     0.7   1st Qu.:       1   1st Qu.:     0.002   1st Qu.:   0.2894
#  Median :     1.8   Median :       2   Median :     0.090   Median :   0.4772
#  Mean   :    74.6   Mean   :   10550   Mean   :    -7.562   Mean   :   0.4905
#  3rd Qu.:     3.7   3rd Qu.:       3   3rd Qu.:     0.212   3rd Qu.:   0.7795
#  Max.   :377315.8   Max.   :94309693   Max.   :  1056.466   Max.   :  34.8107
#  pretaxprofitmargin   payablesturnover   inventoryturnover  fixedassetturnover
#  Min.   :-24577.000   Min.   : -41.096   Min.   :    0.00   Min.   :  -383.6
#  1st Qu.:    -0.001   1st Qu.:   1.119   1st Qu.:    0.00   1st Qu.:     1.3
#  Median :     0.087   Median :   2.612   Median :    3.22   Median :     4.1
#  Mean   :    -7.850   Mean   :   5.759   Mean   :   31.51   Mean   :    87.3
#  3rd Qu.:     0.201   3rd Qu.:   4.587   3rd Qu.:   10.39   3rd Qu.:    10.1
#  Max.   :   198.684   Max.   :8650.316   Max.   :95827.71   Max.   :446511.9
#  assetturnover        currentratio        quickratio         cashratio
#  Min.   : -0.08338   Min.   :  -1.439   Min.   :     0.0   Min.   :     0.00
#  1st Qu.:  0.12463   1st Qu.:   0.989   1st Qu.:     0.7   1st Qu.:     0.15
#  Median :  0.48335   Median :   1.757   Median :     1.2   Median :     0.46
#  Mean   :  0.69651   Mean   :   4.044   Mean   :    67.2   Mean   :    18.41
#  3rd Qu.:  0.96460   3rd Qu.:   3.072   3rd Qu.:     2.3   3rd Qu.:     1.17
#  Max.   :134.36590   Max.   :5719.167   Max.   :486211.3   Max.   :164465.79
#  daysofsalesoutstanding daysofinventoryoutstanding   debtratio
#  Min.   :-5182867       Min.   :-165044.9          Min.   : -0.4536
#  1st Qu.:     -70       1st Qu.:     10.7          1st Qu.:  0.0335
#  Median :      -6       Median :     45.5          Median :  0.1958
#  Mean   :    -359       Mean   :    189.8          Mean   :  0.2728
#  3rd Qu.:       0       3rd Qu.:     72.6          3rd Qu.:  0.3890
#  Max.   :     976       Max.   :1504680.2          Max.   :133.6571
#  debtequityratio      longtermdebttocapitalization totaldebttocapitalization
#  Min.   :-2586.4359   Min.   :-1.9310              Min.   :  -2.7361
#  1st Qu.:    0.0105   1st Qu.: 0.0004              1st Qu.:   0.0272
#  Median :    0.4369   Median : 0.2596              Median :   0.3063
#  Mean   :    0.5860   Mean   : 0.3513              Mean   :   0.4430
#  3rd Qu.:    1.0772   3rd Qu.: 0.4913              3rd Qu.:   0.5306
#  Max.   : 2131.5128   Max.   :91.0381              Max.   :1040.0474
#  companyequitymultiplier operatingcashflowsalesratio
#  Min.   :      0         Min.   :-27566.00
#  1st Qu.:      2         1st Qu.:     0.03
#  Median :      2         Median :     0.12
#  Mean   :   1179         Mean   :    -3.33
#  3rd Qu.:      4         3rd Qu.:     0.26
#  Max.   :8740761         Max.   : 57805.09
#  capitalexpenditurecoverageratios dividendpaidandcapexcoverageratios
#  Min.   :-46880.00                Min.   :-46880.00
#  1st Qu.:     0.49                1st Qu.:     0.35
#  Median :     2.00                Median :     1.40
#  Mean   :   -12.08                Mean   :   -32.54
#  3rd Qu.:     5.02                3rd Qu.:     2.82
#  Max.   :313315.67                Max.   : 64384.91
#  revenue_per_share   net_income_per_share book_value_per_share
#  Min.   :       -3   Min.   :-12724878    Min.   :  -642647
#  1st Qu.:        4   1st Qu.:        0    1st Qu.:        4
#  Median :       11   Median :        1    Median :       10
#  Mean   :   151274   Mean   :    12680    Mean   :    57301
#  3rd Qu.:       32   3rd Qu.:        2    3rd Qu.:       20
#  Max.   :226232495   Max.   : 29790472    Max.   :616362319
#  tangible_book_value_per_share shareholders_equity_per_share
#  Min.   :0.000e+00             Min.   :  -660561
#  1st Qu.:7.000e+00             1st Qu.:        4
#  Median :2.000e+01             Median :       11
#  Mean   :1.092e+05             Mean   :   199906
#  3rd Qu.:5.400e+01             3rd Qu.:       22
#  Max.   :1.095e+09             Max.   :258351242
#  interest_debt_per_share   market_cap        enterprise_value
#  Min.   :      -20       Min.   :0.000e+00   Min.   :-1.488e+11
#  1st Qu.:        0       1st Qu.:2.158e+08   1st Qu.: 2.952e+08
#  Median :        6       Median :9.249e+08   Median : 1.182e+09
#  Mean   :   313175       Mean   :2.962e+10   Mean   : 7.504e+09
#  3rd Qu.:       19       3rd Qu.:3.629e+09   3rd Qu.: 3.907e+09
#  Max.   :419924841       Max.   :9.619e+13   Max.   : 1.146e+12
#   ev_to_sales        enterprise_value_over_ebitda ev_to_operating_cash_flow
#  Min.   : -4324.81   Min.   :    0.00             Min.   :-94684.2
#  1st Qu.:     1.09   1st Qu.:    5.11             1st Qu.:     5.5
#  Median :     2.33   Median :    9.95             Median :    12.1
#  Mean   :    46.53   Mean   :   20.08             Mean   :    36.9
#  3rd Qu.:     4.82   3rd Qu.:   14.37             3rd Qu.:    18.5
#  Max.   :185096.30   Max.   :35296.20             Max.   :512579.0
#  ev_to_free_cash_flow earnings_yield      free_cash_flow_yield
#  Min.   :-467933.3    Min.   :-9992.020   Min.   :-25896.708
#  1st Qu.:     -2.7    1st Qu.:   -0.044   1st Qu.:    -0.036
#  Median :     12.7    Median :    0.032   Median :     0.034
#  Mean   :    -14.8    Mean   :    0.886   Mean   :    -1.663
#  3rd Qu.:     23.0    3rd Qu.:    0.060   3rd Qu.:     0.071
#  Max.   :  84994.9    Max.   :12673.441   Max.   :   293.818
#  income_quality      sg.a_to_revenue     r.d_to_revenue
#  Min.   :-2719.500   Min.   :  -58.798   Min.   :   -0.732
#  1st Qu.:    0.389   1st Qu.:    0.098   1st Qu.:    0.000
#  Median :    1.198   Median :    0.227   Median :    0.000
#  Mean   :    2.745   Mean   :    3.546   Mean   :    4.486
#  3rd Qu.:    2.041   3rd Qu.:    0.465   3rd Qu.:    0.042
#  Max.   :17675.500   Max.   :15246.000   Max.   :12991.000
#  intangibles_to_total_assets capex_to_operating_cash_flow capex_to_revenue
#  Min.   :0.0000              Min.   :    0.000            Min.   :-4310.000
#  1st Qu.:0.0000              1st Qu.:    0.000            1st Qu.:    0.011
#  Median :0.0445              Median :    0.177            Median :    0.032
#  Mean   :0.1558              Mean   :    1.395            Mean   :    0.117
#  3rd Qu.:0.2556              3rd Qu.:    0.533            3rd Qu.:    0.085
#  Max.   :0.9953              Max.   :11850.172            Max.   :  773.667
#  capex_to_depreciation stockbased_compensation_to_revenue graham_number
#  Min.   :-28088.98     Min.   :  -5.591                   Min.   :      0
#  1st Qu.:    -1.48     1st Qu.:   0.002                   1st Qu.:      0
#  Median :    -0.82     Median :   0.007                   Median :     12
#  Mean   :    -5.44     Mean   :   1.088                   Mean   :    643
#  3rd Qu.:    -0.38     3rd Qu.:   0.024                   3rd Qu.:     25
#  Max.   : 35298.33     Max.   :3700.000                   Max.   :8851966
#  graham_netnet       tangible_asset_value net_current_asset_value
#  Min.   :-5474.441   Min.   :-5.852e+09   Min.   :-1.378e+12
#  1st Qu.:   -0.824   1st Qu.: 1.707e+08   1st Qu.:-1.457e+09
#  Median :   -0.158   Median : 9.086e+08   Median :-9.870e+07
#  Mean   :   -1.531   Mean   : 1.620e+10   Mean   :-7.319e+09
#  3rd Qu.:    0.085   3rd Qu.: 3.997e+09   3rd Qu.: 2.553e+07
#  Max.   :  283.039   Max.   : 2.568e+12   Max.   : 8.051e+10
#  invested_capital     average_receivables average_payables
#  Min.   :-8.263e+15   Min.   :0.000e+00   Min.   :-2.037e+10
#  1st Qu.: 9.651e+07   1st Qu.:2.515e+06   1st Qu.: 2.949e+06
#  Median : 8.689e+08   Median :4.373e+07   Median : 2.610e+07
#  Mean   :-4.041e+11   Mean   :8.511e+08   Mean   : 9.470e+08
#  3rd Qu.: 4.451e+09   3rd Qu.:2.785e+08   3rd Qu.: 1.757e+08
#  Max.   : 3.053e+12   Max.   :1.614e+11   Max.   : 7.124e+11
#  average_inventory   days_sales_outstanding days_of_inventory_on_hand
#  Min.   :0.000e+00   Min.   :-165044.9      Min.   :-5182867
#  1st Qu.:0.000e+00   1st Qu.:     10.7      1st Qu.:     -70
#  Median :1.668e+06   Median :     45.5      Median :      -6
#  Mean   :3.783e+08   Mean   :    189.8      Mean   :    -359
#  3rd Qu.:9.905e+07   3rd Qu.:     72.6      3rd Qu.:       0
#  Max.   :4.560e+11   Max.   :1504680.2      Max.   :     976
#  receivables_turnover capex_per_share     gross_profit_growth
#  Min.   :   -27.99    Min.   :-73354000   Min.   :  -224.5
#  1st Qu.:     2.78    1st Qu.:       -2   1st Qu.:     0.0
#  Median :     5.98    Median :        0   Median :     0.1
#  Mean   :    45.70    Mean   :   -18907   Mean   :    19.7
#  3rd Qu.:     9.85    3rd Qu.:        0   3rd Qu.:     0.2
#  Max.   :164428.50    Max.   :   736000   Max.   :336767.8
#   ebit_growth         operating_income_growth net_income_growth
#  Min.   :-16888.000   Min.   :-18881.000      Min.   :-33777.00
#  1st Qu.:    -0.290   1st Qu.:    -0.262      1st Qu.:    -0.41
#  Median :     0.060   Median :     0.058      Median :     0.06
#  Mean   :     0.825   Mean   :     0.437      Mean   :    -2.24
#  3rd Qu.:     0.418   3rd Qu.:     0.362      3rd Qu.:     0.53
#  Max.   : 20598.429   Max.   : 13545.339      Max.   :  3159.00
#    eps_growth        eps_diluted_growth weighted_average_shares_growth
#  Min.   :-2125.000   Min.   :   -2125   Min.   :    -1.00
#  1st Qu.:   -0.311   1st Qu.:       0   1st Qu.:     0.00
#  Median :    0.098   Median :       0   Median :     0.01
#  Mean   :    0.242   Mean   :    2026   Mean   :    12.99
#  3rd Qu.:    0.567   3rd Qu.:       1   3rd Qu.:     0.08
#  Max.   : 4378.049   Max.   :39679767   Max.   :223089.50
#  weighted_average_shares_diluted_growth dividends_per_share_growth
#  Min.   :     -1                        Min.   : -1.0000
#  1st Qu.:      0                        1st Qu.:  0.0000
#  Median :      0                        Median :  0.0000
#  Mean   :    176                        Mean   :  0.1583
#  3rd Qu.:      0                        3rd Qu.:  0.0414
#  Max.   :3378329                        Max.   :372.5714
#  operating_cash_flow_growth free_cash_flow_growth
#  Min.   :-5831.500          Min.   :-83431.43
#  1st Qu.:   -0.275          1st Qu.:    -0.47
#  Median :    0.048          Median :     0.03
#  Mean   :   -0.432          Mean   :    -3.54
#  3rd Qu.:    0.407          3rd Qu.:     0.59
#  Max.   : 5496.639          Max.   :  8030.33
#  three_yr_revenue_growth_per_share three_yr_operating_cf_growth_per_share
#  Min.   :-1.00000                  Min.   :-1.00000
#  1st Qu.:-0.02140                  1st Qu.: 0.00000
#  Median : 0.03300                  Median : 0.00000
#  Mean   : 0.03995                  Mean   : 0.05779
#  3rd Qu.: 0.09462                  3rd Qu.: 0.10720
#  Max.   :43.91950                  Max.   : 9.69610
#  three_yr_net_income_growth_per_share
#  Min.   :-1.00000
#  1st Qu.: 0.00000
#  Median : 0.00000
#  Mean   : 0.06503
#  3rd Qu.: 0.09150
#  Max.   :17.02820
#  three_yr_shareholders_equity_growth_per_share
#  Min.   :-0.98100
#  1st Qu.:-0.01590
#  Median : 0.02660
#  Mean   : 0.04541
#  3rd Qu.: 0.08900
#  Max.   :20.03670
#  three_yr_dividend_per_share_growth_per_share receivables_growth
#  Min.   :-1.00000                             Min.   :   -1.000
#  1st Qu.: 0.00000                             1st Qu.:   -0.047
#  Median : 0.00000                             Median :    0.010
#  Mean   : 0.01142                             Mean   :    2.043
#  3rd Qu.: 0.02665                             3rd Qu.:    0.199
#  Max.   : 5.40050                             Max.   :14414.584
#  inventory_growth     asset_growth      book_value_per_share_growth
#  Min.   : -1.00000   Min.   :  -1.000   Min.   :-3963.131
#  1st Qu.:  0.00000   1st Qu.:  -0.030   1st Qu.:   -0.099
#  Median :  0.00000   Median :   0.048   Median :    0.032
#  Mean   :  0.15905   Mean   :   1.087   Mean   :    0.768
#  3rd Qu.:  0.05752   3rd Qu.:   0.176   3rd Qu.:    0.138
#  Max.   :293.47300   Max.   :5468.426   Max.   : 7039.326
#   debt_growth        r.d_expense_growth  sg.a_expenses_growth
#  Min.   :   -1.051   Min.   :  -2.6622   Min.   :  -2.3699
#  1st Qu.:   -0.065   1st Qu.:   0.0000   1st Qu.:  -0.0134
#  Median :    0.000   Median :   0.0000   Median :   0.0609
#  Mean   :    3.709   Mean   :   0.2935   Mean   :   0.3571
#  3rd Qu.:    0.147   3rd Qu.:   0.0000   3rd Qu.:   0.1847
#  Max.   :17646.823   Max.   :1542.6110   Max.   :2042.0000
#   payout_ratio       interest_coverage   net_profit_margin
#  Min.   :-137.1540   Min.   :-223603.0   Min.   :-24414.000
#  1st Qu.:   0.0000   1st Qu.:      0.0   1st Qu.:    -0.026
#  Median :   0.0000   Median :      0.9   Median :     0.044
#  Mean   :   0.3239   Mean   :    -33.8   Mean   :    -7.561
#  3rd Qu.:   0.3430   3rd Qu.:      6.4   3rd Qu.:     0.135
#  Max.   : 479.5700   Max.   : 361207.4   Max.   :  1056.466
#  dividend_yield        pe_ratio           pfcf_ratio         pocf_ratio
#  Min.   : 0.00000   Min.   :     0.00   Min.   :    0.00   Min.   :-108768.7
#  1st Qu.: 0.00000   1st Qu.:     0.00   1st Qu.:    0.00   1st Qu.:      2.2
#  Median : 0.00000   Median :    13.02   Median :    8.96   Median :      9.0
#  Mean   : 0.02062   Mean   :    37.71   Mean   :   36.02   Mean   :     52.6
#  3rd Qu.: 0.02180   3rd Qu.:    23.43   3rd Qu.:   20.37   3rd Qu.:     15.5
#  Max.   :14.55000   Max.   :105828.71   Max.   :60328.77   Max.   : 554660.0
#  price_to_sales_ratio days_payables_outstanding free_cash_flow_per_share
#  Min.   :     0.0     Min.   :-207232.5         Min.   :-35588921
#  1st Qu.:     0.7     1st Qu.:     10.4         1st Qu.:        0
#  Median :     1.9     Median :     26.7         Median :        1
#  Mean   :    88.2     Mean   :    335.3         Mean   :     1724
#  3rd Qu.:     4.3     3rd Qu.:     55.5         3rd Qu.:        2
#  Max.   :377315.8     Max.   :1043413.3         Max.   : 31932634
#       roe             ptb_ratio            pb_ratio
#  Min.   :  -34772   Min.   :        0   Min.   :        0
#  1st Qu.:       0   1st Qu.:        1   1st Qu.:        1
#  Median :       0   Median :        2   Median :        2
#  Mean   :    1658   Mean   :    17741   Mean   :    17743
#  3rd Qu.:       0   3rd Qu.:        4   3rd Qu.:        3
#  Max.   :11141142   Max.   :108458749   Max.   :108458749
#  operating_cash_flow_per_share cash_per_share
#  Min.   :-24942284             Min.   :        0
#  1st Qu.:        0             1st Qu.:        1
#  Median :        2             Median :        2
#  Mean   :    23224             Mean   :    81442
#  3rd Qu.:        4             3rd Qu.:        5
#  Max.   : 45351079             Max.   :212722714

# %%
#Combining the sets with the original data
imputedm <- cbind(data[, c('stock','nextyr_price_var','class','year','sector','sector_num')], imputedm)
dim(imputedm)
# Out:
# [1] 19592   170

# %%
max(apply(is.na(imputedm),2,sum))
# Out:
# [1] 0

# %% [markdown]
# ### Uniformity
# Are all variables measured using compatible units? Or are there monetary values in different forms of currency? Or something else entirely? If any of these issues are applicable to your data, design and implement a solution.

# %%
#Implementing scaling in the modeling notebook

# %% [markdown]
# ### Additional Cleaning
# If your data set has any other issues you have noticed, you should handle them here.

# %%
#No additional cleaning was performed in this notebook

# %% [markdown]
# ## Save the Prepared Set

# %%
fwrite(data, paste0(dir$final_data,'clean_financial.csv'))
fwrite(imputedm, paste0(dir$final_data,'imputedm_financial.csv'))

# %% [markdown]
# ## Outcome
# At this point you should have an analytic data set prepared for data modeling. You should also be able to account for any changes you have made in the data. Do this now.

# %% [markdown]
# ##### The following changes were made to the data set:
#  - Duplicates: Any duplicate columns were removed from the data set. This was done by first using the duplicated function to identify identical columns. Then, I looked at the columns sums to identify additional duplicate variables. In the end, about 20 variables were duplicated.
#  - Variable Names: The variables names were cleaned up so that they were consistent. Spaces and dashes were removed, all letters were lower-cased, and underscores were added between most words.
#  - Categorical Encoding: A new variable "sector_num" was created as the numeric version of the categorical variable "sector" to aid in machine learning modeling.
#  - Missing Data: The missing data was cleaned in the following manner:
#       1. Any row with missing values greater than 50 was removed
#       2. Any column with missing values greater than 15% was removed
#       3. The remaining values were imputed using the median value for now
#       4. The plan is to use the complete data set to identify which variables are relevant first. Then I will impute on those variables and re-train my data set. Trying to use random forest to impute the missing values at this stage was far too time consuming in R at this stage.
#  - Outliers: The outliers in the data set were removed in the previous notebook using Cook's Distance. Only four rows were identified as extreme outliers and were thus removed from the data set.
